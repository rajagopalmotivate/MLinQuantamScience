# %% [markdown]
# <a href="https://colab.research.google.com/github/rajagopalmotivate/MLinQuantamScience/blob/main/Nandri_Nandri_DM21_plot_energy_vs_bond_lenght_ver_J400_12_Jun_2022_WORKS_Well_C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Simple comparision of DFT vs NN
# ## Hypothesis: NN performs as good as DFT
# ## Experiment: Compare

# %%
EXPNO ='ENERGYVsBOND_0003_C'

dictPeriodicTable = {'C': 6}
 
elementname ='C'

# %%
firstTimeorRestart = True

# %% [markdown]
# #  basis set and as per DM21 authors
# For all benchmarking, we use the large aug'-def2-QZVP basis set
#
# During training,
# For all the atoms and diatomic molecules in the regression set we generate the features for
# the SCF loss at PySCF grid level 2 and use the largest basis set in the aug-pc-X family such
# that the number of basis functions is less than 128.
# For larger neutral molecules we use grid
# level 1 and the largest basis set with less than 128 basis functions from cc-pCV(Q+d)Z, ccpCV(T+d)Z, cc-pV(T+d)Z or cc-pV(D+d)Z

# %%
listBasisSet = ['6-21g' , 'cc-pvqz' , 'def2-qzvp'  ]

listBasisSet = ['def2-QZVP' , 'cc-pCVTZ' ,  'aug-pc-3' , 'aug-cc-pV(Q+d)Z', 'aug-cc-pCV5Z', 'aug-ccpwCV5Z', '6-21g']

listBasisSet = ['cc-pCVDZ' , 'def2-QZVP' , 'cc-pCVTZ' ,  'aug-pc-3' , 'aug-cc-pV(Q+d)Z', 'aug-cc-pCV5Z', 'aug-ccpwCV5Z', '6-31g', 'STO-3G' , 'def2-QZVPPD' ]

listBasisSet = ['def2-QZVP' , 'cc-pCVTZ', 'cc-pVQZ' , 'cc-pVXZ', 'aug-cc-pV(Q+d)Z' , '6-31g' ]

listBasisSet = [   'cc-pVQZ' , 'def2-QZVP' , 'cc-pCVTZ',  'cc-pVXZ' , '6-31g' ]

listBasisSet = [   'cc-pVQZ' , 'def2-QZVP' , 'cc-pCVQZ'  ]

listBasisSet = [   'cc-pVQZ' , 'cc-pVTZ', 'cc-pVDZ',  'cc-pCVQZ', 'cc-pCV5Z',  'def2-QZVP', 'def2-TCVPPD', '6-31g' ,'STO-3G'   ]

listBasisSet = [   'cc-pVQZ', 'def2-QZVP']

listBasisSet = [  'cc-pV7Z', 'cc-pV6Z',  'cc-pVQZ' , 'cc-pVDZ' , 'cc-pCVQZ',    'def2-QZVP', 'def2-7CVPPD', '6-31g' ,'STO-3G'   ]


listBasisSet = [ 'cc-pVQZ' , 'cc-pVDZ' , "aug'-def2-QZVP", '6-31g' , 'aug-pcJ-4', 'cc-pCV(Q+d)Z']

listBasisSet = [ 'cc-pVQZ' , 'cc-pVDZ' , 'def2-QZVP', '6-31g' ]


listBasisSet = [   'cc-pVDZ' ]


#listBasisSet = [ 'cc-pVQZ' , "aug'-def2-QZVP"]

# %%
#dictPeriodicTable = {'H': 1, 'He': 2, 'Li': 3, 'Be': 4, 'B': 5, 'C': 6, 'N': 7, 'O': 8, 'F': 9, 'Ne': 10 }

#dictPeriodicTable = {'H': 1, 'He': 2, 'Li': 3, 'Be': 4, 'B': 5, 'C': 6, 'N': 7, 'O': 8, 'F': 9, 'Ne': 10 , 'Na':11, 'Mg':12 , 'Al':13, 'Si':14, 'P':15, 'S':16 , 'Cl':17, 'Ar':18}

 
dictPeriodicTableSpinValues = {'H': 1,  'He': 0, 'Li': 1, 'Be': 0, 'B': 1, 'C': 0, 'N': 1, 'O': 0, 'F': 1, 'Ne': 0 }



print(str( 'Weight'  + ' ' +   ' \t Element     \t  SPIN'    ))
# Out:
# Weight  	 Element     	  SPIN

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Step 1: Install

# %%
#!pip install git+git://github.com/deepmind/deepmind-research.git#subdirectory=density_functional_approximation_dm21

# %%
# !git clone https://github.com/deepmind/deepmind-research.git
# Out:
# Cloning into 'deepmind-research'...
# remote: Enumerating objects: 2581, done.
# remote: Counting objects: 100% (209/209), done.
# remote: Compressing objects: 100% (155/155), done.
# remote: Total 2581 (delta 55), reused 201 (delta 54), pack-reused 2372
# Receiving objects: 100% (2581/2581), 92.04 MiB | 36.40 MiB/s, done.
# Resolving deltas: 100% (1206/1206), done.

# %%
cd deepmind-research/density_functional_approximation_dm21
# Out:
# /content/deepmind-research/density_functional_approximation_dm21

# %%
pwd
# Out:
# '/content/deepmind-research/density_functional_approximation_dm21'

# %%
# !pip install .
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/deepmind-research/density_functional_approximation_dm21
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from density-functional-approximation-dm21==0.1) (1.1.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from density-functional-approximation-dm21==0.1) (21.4.0)
# Requirement already satisfied: h5py<3.3.0 in /usr/local/lib/python3.7/dist-packages (from density-functional-approximation-dm21==0.1) (3.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from density-functional-approximation-dm21==0.1) (1.21.6)
# Collecting pyscf
#   Downloading pyscf-2.0.1-cp37-cp37m-manylinux1_x86_64.whl (37.5 MB)
#      |████████████████████████████████| 37.5 MB 346 kB/s
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.7/dist-packages (from density-functional-approximation-dm21==0.1) (2.8.2+zzzcolab20220527125636)
# Requirement already satisfied: tensorflow_hub in /usr/local/lib/python3.7/dist-packages (from density-functional-approximation-dm21==0.1) (0.12.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py<3.3.0->density-functional-approximation-dm21==0.1) (1.5.2)
# Requirement already satisfied: scipy!=1.5.0,!=1.5.1 in /usr/local/lib/python3.7/dist-packages (from pyscf->density-functional-approximation-dm21==0.1) (1.4.1)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (1.6.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (4.2.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (2.8.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (14.0.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (1.1.2)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (1.15.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (2.8.0)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (0.5.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (57.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (3.3.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (0.26.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (1.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (1.46.3)
# Requirement already satisfied: tensorflow-estimator<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (2.8.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (3.17.3)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (0.2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow->density-functional-approximation-dm21==0.1) (0.37.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (2.23.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (1.0.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (1.35.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (3.3.7)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (1.8.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (2022.5.18.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (3.2.0)
# Building wheels for collected packages: density-functional-approximation-dm21
#   Building wheel for density-functional-approximation-dm21 (setup.py) ... done
#   Created wheel for density-functional-approximation-dm21: filename=density_functional_approximation_dm21-0.1-py3-none-any.whl size=6085418 sha256=73ea60bb41a7499f117eef0e3a88fd83065eeb8ba6803e096d94728f8b531747
#   Stored in directory: /tmp/pip-ephem-wheel-cache-86wqelgr/wheels/3b/c5/70/0200d858561857222265157381fd4ad73ce078117b4821cd36
# Successfully built density-functional-approximation-dm21
# Installing collected packages: pyscf, density-functional-approximation-dm21
# Successfully installed density-functional-approximation-dm21-0.1 pyscf-2.0.1

# %% [markdown]
# ## Step 2: Configure RAM optionally

# %%
from pyscf import gto
from pyscf import dft

from pyscf import __config__
MAX_MEMORY = getattr(__config__, 'MAX_MEMORY')
MAX_MEMORY
# Out:
# 4000

# %%
import psutil
systemresources = psutil.virtual_memory()

MAX_MEMORY = round( systemresources.available  * 0.000009)
PYSCF_MAX_MEMORY  = MAX_MEMORY

print('Configured to use max RAM resources of  ' + str(MAX_MEMORY))
# Out:
# Configured to use max RAM resources of  111188

# %%
setattr(__config__, 'MAX_MEMORY', PYSCF_MAX_MEMORY)

setattr(__config__, 'PYSCF_MAX_MEMORY', PYSCF_MAX_MEMORY)

# %%
MAX_MEMORY = getattr(__config__, 'MAX_MEMORY')
MAX_MEMORY
# Out:
# 111188

# %% [markdown]
# ## Step 3:
#
# ### 3.1 Define the periodic table (Define atomic weight and periodic weight for each element)
#
# ### 3.2 Define the spin value for each element
#
# ### 3.3 You can load any new basis function.  Just visit the Basics Exchange and get a new Basis Function URL .
# #### here we download a basis set full defintion file from an URL and then use it to construct a molecule
#
# #### To get a web URL, just visit https://www.basissetexchange.org/

# %% [markdown]
# http://vergil.chemistry.gatech.edu/courses/chem6485/pdf/basis-sets.pdf
#
# https://youtu.be/irQ_c_fW5f8?t=971
#
#
# 1.   cc-pCVXZ or aug-cc-pCVXZ basis sets;  you should use basis sets like this if you do not freeze core
# 2.   cc-pVQZ is great for CCSD(T)

# %%
def trydownloadingBasisSet(ElementsinMolecule, BasisSet, versionno):  
    target_url = 'https://www.basissetexchange.org/api/basis/' + str(BasisSet) +  '/format/nwchem/?version='+ str( versionno)+'&elements=' + str(ElementsinMolecule) 
    #print(target_url)
    try:
      textfile = urllib.request.urlopen(target_url)    
      mydownloadedfile = ""
      for line in textfile:
          #print(line.decode('utf-8')) #utf-8 or iso8859-1 or whatever the page encoding scheme is
          mydownloadedfile += line.decode('utf-8') 
      return True    
    except:
      return False

# %%
import urllib   # the lib that handles the url stuff
import urllib.request  # the lib that handles the url stuff


def getValidBasisSet(MoleculeList):
  ValidatedBasisSet = []
  ValBSSetVersionNumberDict = {}
  errorproneBasisSet = []
  for BasisSet in listBasisSet:
    didnotworkatallforanyversion = True
    for versionno in range(0,4):
      isworking = trydownloadingBasisSet(MoleculeList, BasisSet, versionno)
      if isworking == True:
        didnotworkatallforanyversion = False
        ValBSSetVersionNumberDict[BasisSet] = versionno
        ValidatedBasisSet.append(BasisSet)
        break
    if didnotworkatallforanyversion == True:
      errorproneBasisSet.append(BasisSet)
  return ValidatedBasisSet

# %%
def downloadBasisSetAutoVersion(ElementsinMolecule, BasisSet):  
    for versionumber in range (0,4):
      target_url = 'https://www.basissetexchange.org/api/basis/' + str(BasisSet) +  '/format/nwchem/?version='+ str( versionumber)+'&elements=' + str(ElementsinMolecule) 
      try:
        textfile = urllib.request.urlopen(target_url)    
        mydownloadedfile = ""
        for line in textfile:
            #print(line.decode('utf-8')) #utf-8 or iso8859-1 or whatever the page encoding scheme is
            mydownloadedfile += line.decode('utf-8') 
        return mydownloadedfile    
      except:
        return None

# %%
PerdiocTableNumber = dictPeriodicTable [elementname]
ValidatedBasisSet = getValidBasisSet(PerdiocTableNumber)
len(ValidatedBasisSet)
ValidatedBasisSet
# Out:
# ['cc-pVDZ']

# %%
basisSethandpicked =[  ]

# %%
#listBasisSet = basisSet652

# %%
try:
  print("Hello")
except:
  print("Something went wrong")
else:
  print("Nothing went wrong")
# Out:
# Hello
# Nothing went wrong

# %%
#downloadBasisSetAutoVersion(1,'3-21G')

# %% [markdown]
# geomtery optimization

# %%
!	pip install -U pyberny
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyberny
#   Downloading pyberny-0.6.3-py3-none-any.whl (27 kB)
# Requirement already satisfied: numpy<2.0,>=1.15 in /usr/local/lib/python3.7/dist-packages (from pyberny) (1.21.6)
# Installing collected packages: pyberny
# Successfully installed pyberny-0.6.3

# %%
from pyscf import gto
from pyscf import scf
from pyscf import cc
from pyscf.cc import ccsd_t_lambda_slow as ccsd_t_lambda
from pyscf.grad import ccsd_t as ccsd_t_grad
from pyscf.geomopt import berny_solver

def f_usefforberny_solver(mol):
    # Compute CCSD(T) energy
    mf = scf.RHF(mol).run()
    mycc = cc.CCSD(mf).run()
    et_correction = mycc.ccsd_t()
    e_tot = mycc.e_tot + et_correction

    # Compute CCSD(T) gradients
    g = ccsd_t_grad.Gradients(mycc).kernel()
    print('CCSD(T) nuclear gradients:')
    print(g)
    return e_tot, g

# %%
 hashLookUpMolecules = dict()

# %%
def GetoptimizedMolecule(randomMol):
  global hashLookUpMolecules
  print('****************************************************************GEOMENTRY OPTIMIZATION Starts***********************************************')  
  print('MOLECULE KEY is')
  print([randomMol.basis])
  if randomMol in hashLookUpMolecules:
    saved_mol = hashLookUpMolecules[randomMol]
    print('****************************************************************GEOMENTRY looked up from Hashtable***********************************************')  
    return saved_mol
  fake_method = berny_solver.as_pyscf_method(randomMol, f_usefforberny_solver)
  new_mol = berny_solver.optimize(fake_method , maxsteps=400)
  print('Old geometry (Bohr)')
  print(randomMol.atom_coords())  
  print('New geometry (Bohr)')
  print(new_mol.atom_coords())  
  hashLookUpMolecules[randomMol] = new_mol
  print('****************************************************************GEOMENTRY OPTIMIZATION Ends***********************************************')  
  return new_mol

# %% [markdown]
# DM21

# %%
import density_functional_approximation_dm21 as dm21
from pyscf import gto
from pyscf import dft
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
import pandas as pd
import numpy as np

# %%
GlobalBONDLENGTH = 0.0001

# %%
def buildaMoleculeSpin(elementname, elementname2, mydownloadedfile, mydownloadedfile2, trythisspin ):
      global GlobalBONDLENGTH
      mol = gto.Mole()

      #mol.unit = 'B'
      mol.unit = 'Angstrom'
      
      mol.atom = [[elementname, ( 0, 0, GlobalBONDLENGTH)], [elementname2, (0, 0, -1* GlobalBONDLENGTH)] ]
      mol.spin =  trythisspin
      mol.symmetry = True
      mol.basis = { elementname: gto.parse(mydownloadedfile)  ,     elementname2: gto.parse(mydownloadedfile2)        }
      #mol.max_memory = PYSCF_MAX_MEMORY
      mol.build()
      return mol

# %% [markdown]
# Geometry for C2 (Carbon diatomic) 1Σg+ D*H
#
#
# https://cccbdb.nist.gov/geom3x.asp?method=63&basis=25
# ```
# CCSD(T)=FULL/cc-pVQZ
#
# Atom	X	Y	Z
# C	0.0000000	0.0000000	0.6210880
# C	0.0000000	0.0000000	-0.6210880
#
#
#
# CCSD(T)=FULL/cc-pVDZ
#
# Atom	Internal
# x (Å)	y (Å)	z (Å)
# C1	0.0000	0.0000	0.6211
# C2	0.0000	0.0000	-0.6211

# %%
def buildaMoleculeTryMOLECULEELEMENTCOUNT2(elementname, elementname2, mydownloadedfile , mydownloadedfile2 ):
  molecule = None 
  for spinvaluecheckthis in range(5):
    try:
      molecule = buildaMoleculeSpin(elementname,elementname2, mydownloadedfile, mydownloadedfile2, spinvaluecheckthis )      
      return molecule, spinvaluecheckthis
      break
    except:
      tempexcept = True
      #print('SPIN is not correct. Auto matically trying another spin value...')
    else:
      tempelse = True
      #print('TRYING SPIN')
  return molecule, spinvaluecheckthis

# %%
def buildaMoleculeSpinMOLECULEELEMENTCOUNT1(elementname, mydownloadedfile,  trythisspin ):
      mol = gto.Mole()
      #mol.atom = '''H 0 0 0'''
      mol.atom = [[elementname, (0, 0, 0)] ]
      mol.spin =  trythisspin
      mol.basis = { elementname: gto.parse(mydownloadedfile)       }
      mol.build()
      return mol

# %%
def buildaMoleculeTryMOLECULEELEMENTCOUNT1(elementname,  mydownloadedfile ):
  molecule = None 
  for spinvaluecheckthis in range(5):
    try:
      molecule = buildaMoleculeSpinMOLECULEELEMENTCOUNT1(elementname, mydownloadedfile, spinvaluecheckthis )      
      return molecule, spinvaluecheckthis
      break
    except:
      tempexcept = True
      #print('SPIN is not correct. Auto matically trying another spin value...')
    else:
      tempelse = True
      #print('TRYING SPIN')
  return molecule, spinvaluecheckthis

# %% [markdown]
# ## Step 4: Expected format of output table

# %% [markdown]
# ## Step 5. Input values to be considered in this computation

# %% [markdown]
# ## Step 6. Compute Results
# ## Run the computation for the above input values

# %%
functionalsList = ['b3lyp','M06-2X' , 'SCAN'    ,'wB97X-V',  'PW6B95' , 'pbe']

functionalsList = ['b3lyp','M06-2X' , 'SCAN'    ,'wB97X-V',  'PW6B95' ,  'pbe' ,  'pbe0']

functionalsList = [ 'b3lyp', 'SCAN'  , 'wB97X-V'  , 'pbe']


#functionalsList = ['b3lyp']

# %%
from pyscf import dft

# DFT computation of SCF energy  
def SCFenergyFunctionalsbasedonDFTGOLD(mol , functionals ):
  if mol.spin == 0:
    mf = dft.RKS(mol)
  else:
    mf = dft.UKS(mol)
  # functional.
  #mf.xc = 'B3LYP'
  mf.max_memory = PYSCF_MAX_MEMORY
  mf.xc = functionals
  # Run the DFT calculation.
  answerDFT = mf.kernel()
  return answerDFT

# %%
# DFT computation of SCF energy  
def SCFenergyFunctionalsbasedonDFT(mol , functionals ):
    mf = mol.KS()
   # mf.xc = 'b3lyp'
   # mf.xc = 'pbe0'
   # mf.xc = 'M06-2X'
   # mf.xc = 'SCAN'    
   # mf.xc = 'wB97X-V'
   # mf.xc = 'PW6B95'
    mf.xc = functionals
    # Run the DFT calculation.
    answerDFT = mf.kernel()
    return answerDFT

# %%
def SCFenergyFunctionalsbasedonNNGOLD(mol,  NNfunctionals ):
    if mol.spin == 0:
      mf = dft.RKS(mol)
    else:
      mf = dft.UKS(mol)
    #mf._numint = dm21.NeuralNumInt(dm21.Functional.DM21m )
    mf._numint = dm21.NeuralNumInt(NNfunctionals)
    mf.max_memory = PYSCF_MAX_MEMORY
    # Run the DFT calculation.
    answerNN = mf.kernel()
    return answerNN

# %%
def SCFenergyFunctionalsbasedonNN(mol,  NNfunctionals, functionals='b3lyp'):
    mf = mol.KS()
    mf.xc = functionals
    #mf._numint = dm21.NeuralNumInt(dm21.Functional.DM21m )
    mf._numint = dm21.NeuralNumInt(NNfunctionals)
    # Run the DFT calculation.
    answerNN = mf.kernel()
    return answerNN

# %%
# DFT computation of SCF energy  
def SCFenergybasedonDFT(mol):
    mf = dft.RKS(mol)
    # Run the DFT calculation.
    answerDFT = mf.kernel()
    return answerDFT

# %%
# Neural network based prediction of SCF energy   
def SCFenergybasedonNN(mol):
    mf = dft.RKS(mol)
    mf._numint = dm21.NeuralNumInt(dm21.Functional.DM21)
    # Run the DFT calculation.
    answerNN = mf.kernel()
    return answerNN

# %%
# CCSD computation 
def SCFenergybasedonCCSD(mol):
  ccsdanswer = mol.apply('CCSD').run().e_tot
  return ccsdanswer

# %%
from pyscf import  scf, cc

# CCSD-T computation 
def SCFenergybasedonCCSDTGOLD(mol):
  try:
    mf = scf.HF(mol).run()
    mf.max_memory = PYSCF_MAX_MEMORY
    mycc = cc.CCSD(mf).run()
    #print('CCSD  energy', mycc.e_tot)
    et = mycc.ccsd_t()
    CCSDTotal = mycc.e_tot + et
  except ZeroDivisionError:
    print('000000000000000000000000000000000000000-------CCSDT Error------------00000000000000000000000. Using CCSD')
    return SCFenergybasedonCCSD(mol)
  #print('CCSD(T) total energy', mycc.e_tot + et)
  return CCSDTotal

# %%
import urllib   # the lib that handles the url stuff
import urllib.request  # the lib that handles the url stuff
import numpy
from google.colab import files


print( 'No'  + '        ' + 'Element' + '    \t  \t \t ' +  'Basis Set')
# Out:
# No        Element    	  	 	 Basis Set

# %%
ValidatedBasisSetSOURCE = getValidBasisSet(PerdiocTableNumber)

# %%
def compute1Mol1BasisSet(elementname, ValidatedBasisSetStart , df):
  if True:
    PerdiocTableNumber = dictPeriodicTable [elementname]
    ValidatedBasisSet = ValidatedBasisSetSOURCE[ValidatedBasisSetStart:ValidatedBasisSetStart+1]
    for BasisSet in ValidatedBasisSet:    
      print('***********************************************************')
      print('***********************************************************')
      print('***********************************************************')

      mydownloadedfile = downloadBasisSetAutoVersion(PerdiocTableNumber,BasisSet)      
      molUnoptimized, myspin = buildaMoleculeTryMOLECULEELEMENTCOUNT2(elementname, elementname, mydownloadedfile , mydownloadedfile )
      if molUnoptimized == None:
        return df

      print('.............................................Molecule details......................................................')
      print(molUnoptimized)
      print('In Bohr')
      print(molUnoptimized.atom_coords(unit='Bohr'))
      print('In angstrom')
      print(molUnoptimized.atom_coords(unit='ANG'))


     # mol = GetoptimizedMolecule(molUnoptimized)
      mol = molUnoptimized
        
      print(mol.atom)
      print(mol.atom_coords(unit='Bohr'))
      print(mol.basis)
      print(str( PerdiocTableNumber)  + '        ' + str(elementname) + '    \t  \t \t ' + str(BasisSet))     
      print('.............................................COMPUTING SCF energy......................................................')

      aResultDict = computePart(mol )


      aResultDict['BasisSet'] = [BasisSet]

      dfforOneElement = pd.DataFrame(aResultDict )
      df = df.append(dfforOneElement, ignore_index = True)

      return df


    #  files.download('ComputedEnergy'+str(ValidatedBasisSetStart)+'.csv')

# %%
def computePart(mol):
  global DFT_energies 
  global NN_engeries 
  global CCSD_energies 
  global CCSD_Tenergies 
  global fci_energies 
  global bond_lengths 
  global Mole_bond_defintions 


  if True:
      aResultDict = {}
      aResultDict['bond_lenght'] = GlobalBONDLENGTH * 2.0
      aResultDict['Weight'] = PerdiocTableNumber
      aResultDict['Element'] = [elementname]
      aResultDict['Molecule'] = [mol.atom]
      aResultDict['Spin'] = [mol.spin]
      aResultDict['BuiltMolecule'] = [  mol.basis   ]

      print('++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++')
      # Run the CCSD calculation.
     # CCSDenergy = SCFenergybasedonCCSD(mol)
     # print('ENERGY Computing using CCSD appoach is = ' + str(CCSDenergy ))
      print('++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++')
      CCSDTenergy = SCFenergybasedonCCSDTGOLD(mol)
      print('ENERGY Computing using CCSD T appoach is = ' + str(CCSDTenergy ))


      #aResultDict['DFTApproach'] = answerDFT
      #aResultDict['NNApproach'] = answerNN
     # aResultDict['CCSD'] = CCSDenergy
      aResultDict['CCSDT'] = CCSDTenergy
     # CCSD_energies += [CCSDenergy]
      CCSD_Tenergies += [CCSDTenergy]

      print('++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++')
      for afunctionals in functionalsList:
        ans = SCFenergyFunctionalsbasedonDFTGOLD(mol, afunctionals)
        aResultDict['DFT-'+str(afunctionals)] = ans    
        DFT_energies += [ans]


      print('++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++')
      for aDMFunctionalvalue in dm21.Functional:
        #if str(aDMFunctionalvalue) ==  'Functional.DM21m' :           
        if True:
          ans = SCFenergyFunctionalsbasedonNNGOLD(mol, aDMFunctionalvalue)
          aResultDict['NN-'+str(aDMFunctionalvalue)] = ans    
          NN_engeries += [ans]


      return aResultDict

# %%
if firstTimeorRestart == True:
  df = pd.DataFrame(columns = ['Weight', 'Element', 'Molecule', 'BasisSet','Spin', 'BuiltMolecule' ])

# %%
DFT_energies = []
NN_engeries = []
CCSD_energies = []
CCSD_Tenergies = []
fci_energies = []
bond_lengths = []
Mole_bond_defintions = []

# %%
n_points = 48
bond_length_interval = 3.0 / n_points

# %%
for i in range(0, len(ValidatedBasisSetSOURCE)):
  try:
    for elementname in dictPeriodicTable.keys():
      for point in range(1, n_points + 1):
        print('************************************##############################################*############################### ' + str(point))
        bond_length = bond_length_interval * float(point) + 0.2
        bond_lengths += [bond_length]
        GlobalBONDLENGTH = bond_length/2.0
        df = compute1Mol1BasisSet(elementname, ValidatedBasisSetStart=i , df=df)
  except:
    print('Exception.. continuing')
# Out:
# ************************************##############################################*############################### 1
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f55dfb0b1d0>
# In Bohr
# [[ 0.          0.          0.24802655]
#  [ 0.          0.         -0.24802655]]
# In angstrom
# [[ 0.       0.       0.13125]
#  [ 0.       0.      -0.13125]]
# [['C', (0, 0, 0.13125)], ['C', (0, 0, -0.13125)]]
# [[ 0.          0.          0.24802655]
#  [ 0.          0.         -0.24802655]]
# {'C': [[0, [6665.0, 0.000692, -0.000146, 0.0], [1000.0, 0.005329, -0.001154, 0.0], [228.0, 0.027077, -0.005725, 0.0], [64.71, 0.101718, -0.023312, 0.0], [21.06, 0.27474, -0.063955, 0.0], [7.495, 0.448564, -0.149981, 0.0], [2.797, 0.285074, -0.127262, 0.0], [0.5215, 0.015204, 0.544529, 0.0], [0.1596, -0.003191, 0.580496, 1.0]], [1, [9.439, 0.038109, 0.0], [2.002, 0.20948, 0.0], [0.5456, 0.508557, 0.0], [0.1517, 0.468842, 1.0]], [2, [0.55, 1.0]]]}
# 6        C    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -53.5137580485247
# E(CCSD) = -53.64516811180336  E_corr = -0.131410063278815
# CCSD(T) correction = -0.00144790411664379
# ENERGY Computing using CCSD T appoach is = -53.64661601592001
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -53.8992472988215
# converged SCF energy = -53.90640360808
# converged SCF energy = -53.9310174114662
# converged SCF energy = -53.8062112030943
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_hub/saved_model_lib.py:111: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# converged SCF energy = -53.9342149919503
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -53.9625651943334
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -53.9594350321563
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -53.9716525473129
# ************************************##############################################*############################### 2
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f55711f5ad0>
# In Bohr
# [[ 0.         0.         0.3070805]
#  [ 0.         0.        -0.3070805]]
# In angstrom
# [[ 0.      0.      0.1625]
#  [ 0.      0.     -0.1625]]
# [['C', (0, 0, 0.1625)], ['C', (0, 0, -0.1625)]]
# [[ 0.         0.         0.3070805]
#  [ 0.         0.        -0.3070805]]
# {'C': [[0, [6665.0, 0.000692, -0.000146, 0.0], [1000.0, 0.005329, -0.001154, 0.0], [228.0, 0.027077, -0.005725, 0.0], [64.71, 0.101718, -0.023312, 0.0], [21.06, 0.27474, -0.063955, 0.0], [7.495, 0.448564, -0.149981, 0.0], [2.797, 0.285074, -0.127262, 0.0], [0.5215, 0.015204, 0.544529, 0.0], [0.1596, -0.003191, 0.580496, 1.0]], [1, [9.439, 0.038109, 0.0], [2.002, 0.20948, 0.0], [0.5456, 0.508557, 0.0], [0.1517, 0.468842, 1.0]], [2, [0.55, 1.0]]]}
# 6        C    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -61.8307896492463
# E(CCSD) = -61.97116543639756  E_corr = -0.1403757871513736
# CCSD(T) correction = -0.00167831648795584
# ENERGY Computing using CCSD T appoach is = -61.97284375288551
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -62.2094047288356
# converged SCF energy = -62.2203576913008
# converged SCF energy = -62.2484074108962
# converged SCF energy = -62.1186646878408
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -62.2430113130298
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -62.266160506885
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -62.2659304143692
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -62.2738315317702
# ************************************##############################################*############################### 3
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f54ea3d53d0>
# In Bohr
# [[ 0.          0.          0.36613444]
#  [ 0.          0.         -0.36613444]]
# In angstrom
# [[ 0.       0.       0.19375]
#  [ 0.       0.      -0.19375]]
# [['C', (0, 0, 0.19375)], ['C', (0, 0, -0.19375)]]
# [[ 0.          0.          0.36613444]
#  [ 0.          0.         -0.36613444]]
# {'C': [[0, [6665.0, 0.000692, -0.000146, 0.0], [1000.0, 0.005329, -0.001154, 0.0], [228.0, 0.027077, -0.005725, 0.0], [64.71, 0.101718, -0.023312, 0.0], [21.06, 0.27474, -0.063955, 0.0], [7.495, 0.448564, -0.149981, 0.0], [2.797, 0.285074, -0.127262, 0.0], [0.5215, 0.015204, 0.544529, 0.0], [0.1596, -0.003191, 0.580496, 1.0]], [1, [9.439, 0.038109, 0.0], [2.002, 0.20948, 0.0], [0.5456, 0.508557, 0.0], [0.1517, 0.468842, 1.0]], [2, [0.55, 1.0]]]}
# 6        C    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -66.4148789107085
# E(CCSD) = -66.56575771095675  E_corr = -0.150878800248288
# CCSD(T) correction = -0.00205795488264959
# ENERGY Computing using CCSD T appoach is = -66.56781566583939
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -66.7935272286321
# converged SCF energy = -66.8046730884486
# converged SCF energy = -66.839462507905
# converged SCF energy = -66.7067442593864
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -66.8239165513855
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -66.8438273436516
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -66.8408155322138
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -66.8467358371176
# ************************************##############################################*############################### 4
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f55664f5bd0>
# In Bohr
# [[ 0.          0.          0.42518838]
#  [ 0.          0.         -0.42518838]]
# In angstrom
# [[ 0.     0.     0.225]
#  [ 0.     0.    -0.225]]
# [['C', (0, 0, 0.225)], ['C', (0, 0, -0.225)]]
# [[ 0.          0.          0.42518838]
#  [ 0.          0.         -0.42518838]]
# {'C': [[0, [6665.0, 0.000692, -0.000146, 0.0], [1000.0, 0.005329, -0.001154, 0.0], [228.0, 0.027077, -0.005725, 0.0], [64.71, 0.101718, -0.023312, 0.0], [21.06, 0.27474, -0.063955, 0.0], [7.495, 0.448564, -0.149981, 0.0], [2.797, 0.285074, -0.127262, 0.0], [0.5215, 0.015204, 0.544529, 0.0], [0.1596, -0.003191, 0.580496, 1.0]], [1, [9.439, 0.038109, 0.0], [2.002, 0.20948, 0.0], [0.5456, 0.508557, 0.0], [0.1517, 0.468842, 1.0]], [2, [0.55, 1.0]]]}
# 6        C    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -69.1445098800964
# E(CCSD) = -69.30677907936359  E_corr = -0.162269199267172
# CCSD(T) correction = -0.00272317166764075
# ENERGY Computing using CCSD T appoach is = -69.30950225103123
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -69.5254231310889
# converged SCF energy = -69.5367881212839
# converged SCF energy = -69.5779541843494
# converged SCF energy = -69.4428624686311
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -69.5519087604961
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -69.5712553672202
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -69.5626198646756
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -69.5703531708963
# ************************************##############################################*############################### 5
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f5550016dd0>
# In Bohr
# [[ 0.          0.          0.48424232]
#  [ 0.          0.         -0.48424232]]
# In angstrom
# [[ 0.       0.       0.25625]
#  [ 0.       0.      -0.25625]]
# [['C', (0, 0, 0.25625)], ['C', (0, 0, -0.25625)]]
# [[ 0.          0.          0.48424232]
#  [ 0.          0.         -0.48424232]]
# {'C': [[0, [6665.0, 0.000692, -0.000146, 0.0], [1000.0, 0.005329, -0.001154, 0.0], [228.0, 0.027077, -0.005725, 0.0], [64.71, 0.101718, -0.023312, 0.0], [21.06, 0.27474, -0.063955, 0.0], [7.495, 0.448564, -0.149981, 0.0], [2.797, 0.285074, -0.127262, 0.0], [0.5215, 0.015204, 0.544529, 0.0], [0.1596, -0.003191, 0.580496, 1.0]], [1, [9.439, 0.038109, 0.0], [2.002, 0.20948, 0.0], [0.5456, 0.508557, 0.0], [0.1517, 0.468842, 1.0]], [2, [0.55, 1.0]]]}
# 6        C    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -70.9092734069491
# E(CCSD) = -71.08540603175732  E_corr = -0.176132624808246
# CCSD(T) correction = -0.0041356863594416
# ENERGY Computing using CCSD T appoach is = -71.08954171811676
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -71.2957190548966
# converged SCF energy = -71.3067204334825
# converged SCF energy = -71.353061128236
# converged SCF energy = -71.2172361223952
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -71.3195697367364
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -71.3531378659005
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -71.3311087144298
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -71.335410760026
# ************************************##############################################*############################### 6
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f54ea5b5750>
# In Bohr
# [[ 0.          0.          0.54329626]
#  [ 0.          0.         -0.54329626]]
# In angstrom
# [[ 0.      0.      0.2875]
#  [ 0.      0.     -0.2875]]
# [['C', (0, 0, 0.2875)], ['C', (0, 0, -0.2875)]]
# [[ 0.          0.          0.54329626]
#  [ 0.          0.         -0.54329626]]
# {'C': [[0, [6665.0, 0.000692, -0.000146, 0.0], [1000.0, 0.005329, -0.001154, 0.0], [228.0, 0.027077, -0.005725, 0.0], [64.71, 0.101718, -0.023312, 0.0], [21.06, 0.27474, -0.063955, 0.0], [7.495, 0.448564, -0.149981, 0.0], [2.797, 0.285074, -0.127262, 0.0], [0.5215, 0.015204, 0.544529, 0.0], [0.1596, -0.003191, 0.580496, 1.0]], [1, [9.439, 0.038109, 0.0], [2.002, 0.20948, 0.0], [0.5456, 0.508557, 0.0], [0.1517, 0.468842, 1.0]], [2, [0.55, 1.0]]]}
# 6        C    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -72.1521157119765
# E(CCSD) = -72.34908705671505  E_corr = -0.1969713447385692
# CCSD(T) correction = -0.00752445852620426
# ENERGY Computing using CCSD T appoach is = -72.35661151524126
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -72.5501863105501
# converged SCF energy = -72.5583832406985
# converged SCF energy = -72.60871069877
# converged SCF energy = -72.4762172773743
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -72.5733631165739
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -72.6077858999388
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -72.5815010266025
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -72.5877093204052
# ************************************##############################################*############################### 7
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f55667bded0>
# In Bohr
# [[ 0.         0.         0.6023502]
#  [ 0.         0.        -0.6023502]]
# In angstrom
# [[ 0.       0.       0.31875]
#  [ 0.       0.      -0.31875]]
# [['C', (0, 0, 0.31875)], ['C', (0, 0, -0.31875)]]
# [[ 0.         0.         0.6023502]
#  [ 0.         0.        -0.6023502]]
# {'C': [[0, [6665.0, 0.000692, -0.000146, 0.0], [1000.0, 0.005329, -0.001154, 0.0], [228.0, 0.027077, -0.005725, 0.0], [64.71, 0.101718, -0.023312, 0.0], [21.06, 0.27474, -0.063955, 0.0], [7.495, 0.448564, -0.149981, 0.0], [2.797, 0.285074, -0.127262, 0.0], [0.5215, 0.015204, 0.544529, 0.0], [0.1596, -0.003191, 0.580496, 1.0]], [1, [9.439, 0.038109, 0.0], [2.002, 0.20948, 0.0], [0.5456, 0.508557, 0.0], [0.1517, 0.468842, 1.0]], [2, [0.55, 1.0]]]}
# 6        C    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -73.0815767247198
# E(CCSD) = -73.30744937927005  E_corr = -0.2258726545502314
# CCSD(T) correction = -0.0141872053323609
# ENERGY Computing using CCSD T appoach is = -73.32163658460242
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -73.4944399310083
# converged SCF energy = -73.4987304811635
# converged SCF energy = -73.5512006280904
# converged SCF energy = -73.4251153692177
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -73.4444045616698
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -73.5492172119037
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -73.5271286627058
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -73.5284858208246
# ************************************##############################################*############################### 8
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f54ea694890>
# In Bohr
# [[ 0.          0.          0.66140414]
#  [ 0.          0.         -0.66140414]]
# In angstrom
# [[ 0.    0.    0.35]
#  [ 0.    0.   -0.35]]
# [['C', (0, 0, 0.35)], ['C', (0, 0, -0.35)]]
# [[ 0.          0.          0.66140414]
#  [ 0.          0.         -0.66140414]]
# {'C': [[0, [6665.0, 0.000692, -0.000146, 0.0], [1000.0, 0.005329, -0.001154, 0.0], [228.0, 0.027077, -0.005725, 0.0], [64.71, 0.101718, -0.023312, 0.0], [21.06, 0.27474, -0.063955, 0.0], [7.495, 0.448564, -0.149981, 0.0], [2.797, 0.285074, -0.127262, 0.0], [0.5215, 0.015204, 0.544529, 0.0], [0.1596, -0.003191, 0.580496, 1.0]], [1, [9.439, 0.038109, 0.0], [2.002, 0.20948, 0.0], [0.5456, 0.508557, 0.0], [0.1517, 0.468842, 1.0]], [2, [0.55, 1.0]]]}
# 6        C    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -73.7833220670603
# E(CCSD) = -74.03737357254961  E_corr = -0.2540515054893818
# CCSD(T) correction = -0.0217593024332061
# ENERGY Computing using CCSD T appoach is = -74.05913287498282
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -74.2085347854274
# converged SCF energy = -74.2100771908514
# converged SCF energy = -74.2634801405798
# converged SCF energy = -74.1436022753635
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -74.1746585761821
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -74.2664907638329
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -74.245252929073
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -74.2391782172086
# ************************************##############################################*############################### 9
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f54ea58ced0>
# In Bohr
# [[ 0.          0.          0.72045808]
#  [ 0.          0.         -0.72045808]]
# In angstrom
# [[ 0.       0.       0.38125]
#  [ 0.       0.      -0.38125]]
# [['C', (0, 0, 0.38125)], ['C', (0, 0, -0.38125)]]
# [[ 0.          0.          0.72045808]
#  [ 0.          0.         -0.72045808]]
# {'C': [[0, [6665.0, 0.000692, -0.000146, 0.0], [1000.0, 0.005329, -0.001154, 0.0], [228.0, 0.027077, -0.005725, 0.0], [64.71, 0.101718, -0.023312, 0.0], [21.06, 0.27474, -0.063955, 0.0], [7.495, 0.448564, -0.149981, 0.0], [2.797, 0.285074, -0.127262, 0.0], [0.5215, 0.015204, 0.544529, 0.0], [0.1596, -0.003191, 0.580496, 1.0]], [1, [9.439, 0.038109, 0.0], [2.002, 0.20948, 0.0], [0.5456, 0.508557, 0.0], [0.1517, 0.468842, 1.0]], [2, [0.55, 1.0]]]}
# 6        C    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -74.3024561635175
# E(CCSD) = -74.57642413137765  E_corr = -0.2739679678601485
# CCSD(T) correction = -0.0261749889320738
# ENERGY Computing using CCSD T appoach is = -74.60259912030972
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -74.7362750668887
# converged SCF energy = -74.7374011892732
# converged SCF energy = -74.7903192100464
# converged SCF energy = -74.6751889247126
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -74.7144965744761
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -74.7915602557587
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -74.7763445432714
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -74.7671163187543
# ************************************##############################################*############################### 10
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f55711f5ad0>
# In Bohr
# [[ 0.          0.          0.77951203]
#  [ 0.          0.         -0.77951203]]
# In angstrom
# [[ 0.      0.      0.4125]
#  [ 0.      0.     -0.4125]]
# [['C', (0, 0, 0.4125)], ['C', (0, 0, -0.4125)]]
# [[ 0.          0.          0.77951203]
#  [ 0.          0.         -0.77951203]]
# {'C': [[0, [6665.0, 0.000692, -0.000146, 0.0], [1000.0, 0.005329, -0.001154, 0.0], [228.0, 0.027077, -0.005725, 0.0], [64.71, 0.101718, -0.023312, 0.0], [21.06, 0.27474, -0.063955, 0.0], [7.495, 0.448564, -0.149981, 0.0], [2.797, 0.285074, -0.127262, 0.0], [0.5215, 0.015204, 0.544529, 0.0], [0.1596, -0.003191, 0.580496, 1.0]], [1, [9.439, 0.038109, 0.0], [2.002, 0.20948, 0.0], [0.5456, 0.508557, 0.0], [0.1517, 0.468842, 1.0]], [2, [0.55, 1.0]]]}
# 6        C    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -74.6771211099748
# E(CCSD) = -74.96337802245229  E_corr = -0.2862569124774432
# CCSD(T) correction = -0.0274224911147161
# ENERGY Computing using CCSD T appoach is = -74.99080051356701
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -75.116794678844
# converged SCF energy = -75.1184299540231
# converged SCF energy = -75.1707067690435
# converged SCF energy = -75.0590556994088
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -75.0869146937591
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -75.1722971958108
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -75.1574559957208
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -75.1475055459559
# ************************************##############################################*############################### 11
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f55668d9e10>
# In Bohr
# [[ 0.          0.          0.83856597]
#  [ 0.          0.         -0.83856597]]
# In angstrom
# [[ 0.       0.       0.44375]
#  [ 0.       0.      -0.44375]]
# [['C', (0, 0, 0.44375)], ['C', (0, 0, -0.44375)]]
# [[ 0.          0.          0.83856597]
#  [ 0.          0.         -0.83856597]]
# {'C': [[0, [6665.0, 0.000692, -0.000146, 0.0], [1000.0, 0.005329, -0.001154, 0.0], [228.0, 0.027077, -0.005725, 0.0], [64.71, 0.101718, -0.023312, 0.0], [21.06, 0.27474, -0.063955, 0.0], [7.495, 0.448564, -0.149981, 0.0], [2.797, 0.285074, -0.127262, 0.0], [0.5215, 0.015204, 0.544529, 0.0], [0.1596, -0.003191, 0.580496, 1.0]], [1, [9.439, 0.038109, 0.0], [2.002, 0.20948, 0.0], [0.5456, 0.508557, 0.0], [0.1517, 0.468842, 1.0]], [2, [0.55, 1.0]]]}
# 6        C    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -74.9412078515251
# E(CCSD) = -75.23525690285888  E_corr = -0.2940490513337339
# CCSD(T) correction = -0.0272504321265468
# ENERGY Computing using CCSD T appoach is = -75.26250733498543
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -75.3850867192318
# converged SCF energy = -75.387532702593
# converged SCF energy = -75.4393153289637
# converged SCF energy = -75.3302995064188
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -75.4256635025629
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -75.4413882691957
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -75.4287774933404
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -75.4176414546439
# ************************************##############################################*############################### 12
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f5566cdf210>
# In Bohr
# [[ 0.          0.          0.89761991]
#  [ 0.          0.         -0.89761991]]
# In angstrom
# [[ 0.     0.     0.475]
#  [ 0.     0.    -0.475]]
# [['C', (0, 0, 0.475)], ['C', (0, 0, -0.475)]]
# [[ 0.          0.          0.89761991]
#  [ 0.          0.         -0.89761991]]
# {'C': [[0, [6665.0, 0.000692, -0.000146, 0.0], [1000.0, 0.005329, -0.001154, 0.0], [228.0, 0.027077, -0.005725, 0.0], [64.71, 0.101718, -0.023312, 0.0], [21.06, 0.27474, -0.063955, 0.0], [7.495, 0.448564, -0.149981, 0.0], [2.797, 0.285074, -0.127262, 0.0], [0.5215, 0.015204, 0.544529, 0.0], [0.1596, -0.003191, 0.580496, 1.0]], [1, [9.439, 0.038109, 0.0], [2.002, 0.20948, 0.0], [0.5456, 0.508557, 0.0], [0.1517, 0.468842, 1.0]], [2, [0.55, 1.0]]]}
# 6        C    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -75.1225495562595
# E(CCSD) = -75.42210082358817  E_corr = -0.2995512673286805
# CCSD(T) correction = -0.0268003526212495
# ENERGY Computing using CCSD T appoach is = -75.44890117620942
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -75.5696949813713
# converged SCF energy = -75.5728676299276
# converged SCF energy = -75.6244726823508
# converged SCF energy = -75.5175788088222
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -75.6136497794071
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -75.6233279421052
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -75.6174754833673
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -75.607099230406
# ************************************##############################################*############################### 13
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f54ea3a8110>
# In Bohr
# [[ 0.          0.          0.95667385]
#  [ 0.          0.         -0.95667385]]
# In angstrom
# [[ 0.       0.       0.50625]
#  [ 0.       0.      -0.50625]]
# [['C', (0, 0, 0.50625)], ['C', (0, 0, -0.50625)]]
# [[ 0.          0.          0.95667385]
#  [ 0.          0.         -0.95667385]]
# {'C': [[0, [6665.0, 0.000692, -0.000146, 0.0], [1000.0, 0.005329, -0.001154, 0.0], [228.0, 0.027077, -0.005725, 0.0], [64.71, 0.101718, -0.023312, 0.0], [21.06, 0.27474, -0.063955, 0.0], [7.495, 0.448564, -0.149981, 0.0], [2.797, 0.285074, -0.127262, 0.0], [0.5215, 0.015204, 0.544529, 0.0], [0.1596, -0.003191, 0.580496, 1.0]], [1, [9.439, 0.038109, 0.0], [2.002, 0.20948, 0.0], [0.5456, 0.508557, 0.0], [0.1517, 0.468842, 1.0]], [2, [0.55, 1.0]]]}
# 6        C    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -75.2428335374835
# E(CCSD) = -75.546725468676  E_corr = -0.3038919311924999
# CCSD(T) correction = -0.0265251478710293
# ENERGY Computing using CCSD T appoach is = -75.57325061654703
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -75.6927236208706
# converged SCF energy = -75.6965874980143
# converged SCF energy = -75.748099792904
# converged SCF energy = -75.6430170093781
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -75.7398400903818
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -75.7425963870507
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -75.7259555033912
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -75.7368814128307
# ************************************##############################################*############################### 14
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f54ea3f4f10>
# In Bohr
# [[ 0.          0.          1.01572779]
#  [ 0.          0.         -1.01572779]]
# In angstrom
# [[ 0.      0.      0.5375]
#  [ 0.      0.     -0.5375]]
# [['C', (0, 0, 0.5375)], ['C', (0, 0, -0.5375)]]
# [[ 0.          0.          1.01572779]
#  [ 0.          0.         -1.01572779]]
# {'C': [[0, [6665.0, 0.000692, -0.000146, 0.0], [1000.0, 0.005329, -0.001154, 0.0], [228.0, 0.027077, -0.005725, 0.0], [64.71, 0.101718, -0.023312, 0.0], [21.06, 0.27474, -0.063955, 0.0], [7.495, 0.448564, -0.149981, 0.0], [2.797, 0.285074, -0.127262, 0.0], [0.5215, 0.015204, 0.544529, 0.0], [0.1596, -0.003191, 0.580496, 1.0]], [1, [9.439, 0.038109, 0.0], [2.002, 0.20948, 0.0], [0.5456, 0.508557, 0.0], [0.1517, 0.468842, 1.0]], [2, [0.55, 1.0]]]}
# 6        C    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -75.3185310288227
# E(CCSD) = -75.62610531911562  E_corr = -0.3075742902928725
# CCSD(T) correction = -0.0265371015061238
# ENERGY Computing using CCSD T appoach is = -75.65264242062175
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -75.7708494164209
# converged SCF energy = -75.7751928369501
# converged SCF energy = -75.826759274509
# converged SCF energy = -75.7232992989822
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -75.8205952409488
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -75.821679032483
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -75.8415837782339
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -75.8313243862498
# ************************************##############################################*############################### 15
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f54ea1e5e90>
# In Bohr
# [[ 0.          0.          1.07478173]
#  [ 0.          0.         -1.07478173]]
# In angstrom
# [[ 0.       0.       0.56875]
#  [ 0.       0.      -0.56875]]
# [['C', (0, 0, 0.56875)], ['C', (0, 0, -0.56875)]]
# [[ 0.          0.          1.07478173]
#  [ 0.          0.         -1.07478173]]
# {'C': [[0, [6665.0, 0.000692, -0.000146, 0.0], [1000.0, 0.005329, -0.001154, 0.0], [228.0, 0.027077, -0.005725, 0.0], [64.71, 0.101718, -0.023312, 0.0], [21.06, 0.27474, -0.063955, 0.0], [7.495, 0.448564, -0.149981, 0.0], [2.797, 0.285074, -0.127262, 0.0], [0.5215, 0.015204, 0.544529, 0.0], [0.1596, -0.003191, 0.580496, 1.0]], [1, [9.439, 0.038109, 0.0], [2.002, 0.20948, 0.0], [0.5456, 0.508557, 0.0], [0.1517, 0.468842, 1.0]], [2, [0.55, 1.0]]]}
# 6        C    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -75.3620084153267
# E(CCSD) = -75.6728124924779  E_corr = -0.3108040771512054
# CCSD(T) correction = -0.0268206551798163
# ENERGY Computing using CCSD T appoach is = -75.69963314765772
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -75.8165292462028
# converged SCF energy = -75.82146198799
# converged SCF energy = -75.8728345335596
# converged SCF energy = -75.7708754997002
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -75.8681607911965
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -75.8694754223186
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -75.8824350298916
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -75.8825380211732
# ************************************##############################################*############################### 16
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f555043d450>
# In Bohr
# [[ 0.          0.          1.13383567]
#  [ 0.          0.         -1.13383567]]
# In angstrom
# [[ 0.   0.   0.6]
#  [ 0.   0.  -0.6]]
# [['C', (0, 0, 0.6)], ['C', (0, 0, -0.6)]]
# [[ 0.          0.          1.13383567]
#  [ 0.          0.         -1.13383567]]
# {'C': [[0, [6665.0, 0.000692, -0.000146, 0.0], [1000.0, 0.005329, -0.001154, 0.0], [228.0, 0.027077, -0.005725, 0.0], [64.71, 0.101718, -0.023312, 0.0], [21.06, 0.27474, -0.063955, 0.0], [7.495, 0.448564, -0.149981, 0.0], [2.797, 0.285074, -0.127262, 0.0], [0.5215, 0.015204, 0.544529, 0.0], [0.1596, -0.003191, 0.580496, 1.0]], [1, [9.439, 0.038109, 0.0], [2.002, 0.20948, 0.0], [0.5456, 0.508557, 0.0], [0.1517, 0.468842, 1.0]], [2, [0.55, 1.0]]]}
# 6        C    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -75.3825037696398
# E(CCSD) = -75.69616124255845  E_corr = -0.3136574729186055
# CCSD(T) correction = -0.0273217010391841
# ENERGY Computing using CCSD T appoach is = -75.72348294359763
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -75.8390299182281
# converged SCF energy = -75.8445339731894
# converged SCF energy = -75.8955469108
# converged SCF energy = -75.7950013786953
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -75.8918752324976
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -75.8927987540097
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -75.8954224719859
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -75.9029797913918
# ************************************##############################################*############################### 17
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f5566d81710>
# In Bohr
# [[ 0.          0.          1.19288962]
#  [ 0.          0.         -1.19288962]]
# In angstrom
# [[ 0.       0.       0.63125]
#  [ 0.       0.      -0.63125]]
# [['C', (0, 0, 0.63125)], ['C', (0, 0, -0.63125)]]
# [[ 0.          0.          1.19288962]
#  [ 0.          0.         -1.19288962]]
# {'C': [[0, [6665.0, 0.000692, -0.000146, 0.0], [1000.0, 0.005329, -0.001154, 0.0], [228.0, 0.027077, -0.005725, 0.0], [64.71, 0.101718, -0.023312, 0.0], [21.06, 0.27474, -0.063955, 0.0], [7.495, 0.448564, -0.149981, 0.0], [2.797, 0.285074, -0.127262, 0.0], [0.5215, 0.015204, 0.544529, 0.0], [0.1596, -0.003191, 0.580496, 1.0]], [1, [9.439, 0.038109, 0.0], [2.002, 0.20948, 0.0], [0.5456, 0.508557, 0.0], [0.1517, 0.468842, 1.0]], [2, [0.55, 1.0]]]}
# 6        C    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -75.3868986575593
# E(CCSD) = -75.7030619427572  E_corr = -0.3161632851979352
# CCSD(T) correction = -0.0279813824285952
# ENERGY Computing using CCSD T appoach is = -75.7310433251858
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -75.8452371590202
# converged SCF energy = -75.8511203914527
# converged SCF energy = -75.9017564980277
# SCF not converged.
# SCF energy = -75.7061127553801
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -75.898716277995
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -75.8987868330952
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -75.9081202145838
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -75.9009880734677
# ************************************##############################################*############################### 18
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f5566d816d0>
# In Bohr
# [[ 0.          0.          1.25194356]
#  [ 0.          0.         -1.25194356]]
# In angstrom
# [[ 0.      0.      0.6625]
#  [ 0.      0.     -0.6625]]
# [['C', (0, 0, 0.6625)], ['C', (0, 0, -0.6625)]]
# [[ 0.          0.          1.25194356]
#  [ 0.          0.         -1.25194356]]
# {'C': [[0, [6665.0, 0.000692, -0.000146, 0.0], [1000.0, 0.005329, -0.001154, 0.0], [228.0, 0.027077, -0.005725, 0.0], [64.71, 0.101718, -0.023312, 0.0], [21.06, 0.27474, -0.063955, 0.0], [7.495, 0.448564, -0.149981, 0.0], [2.797, 0.285074, -0.127262, 0.0], [0.5215, 0.015204, 0.544529, 0.0], [0.1596, -0.003191, 0.580496, 1.0]], [1, [9.439, 0.038109, 0.0], [2.002, 0.20948, 0.0], [0.5456, 0.508557, 0.0], [0.1517, 0.468842, 1.0]], [2, [0.55, 1.0]]]}
# 6        C    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -75.3802996077078
# E(CCSD) = -75.69864527377531  E_corr = -0.318345666067454
# CCSD(T) correction = -0.0287495841144828
# ENERGY Computing using CCSD T appoach is = -75.72739485788979
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -75.8402608089274
# SCF not converged.
# SCF energy = -75.7919940928522
# converged SCF energy = -75.8965614951719
# SCF not converged.
# SCF energy = -75.722366364547
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -75.8940052014524
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -75.8942227263126
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -75.897346474864
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -75.8876307980468
# ************************************##############################################*############################### 19
# ***********************************************************
# ***********************************************************
# ***********************************************************
# ...
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f5566a3ecd0>
# In Bohr
# [[ 0.          0.          2.72829209]
#  [ 0.          0.         -2.72829209]]
# In angstrom
# [[ 0.       0.       1.44375]
#  [ 0.       0.      -1.44375]]
# [['C', (0, 0, 1.44375)], ['C', (0, 0, -1.44375)]]
# [[ 0.          0.          2.72829209]
#  [ 0.          0.         -2.72829209]]
# {'C': [[0, [6665.0, 0.000692, -0.000146, 0.0], [1000.0, 0.005329, -0.001154, 0.0], [228.0, 0.027077, -0.005725, 0.0], [64.71, 0.101718, -0.023312, 0.0], [21.06, 0.27474, -0.063955, 0.0], [7.495, 0.448564, -0.149981, 0.0], [2.797, 0.285074, -0.127262, 0.0], [0.5215, 0.015204, 0.544529, 0.0], [0.1596, -0.003191, 0.580496, 1.0]], [1, [9.439, 0.038109, 0.0], [2.002, 0.20948, 0.0], [0.5456, 0.508557, 0.0], [0.1517, 0.468842, 1.0]], [2, [0.55, 1.0]]]}
# 6        C    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -75.0718617770401
# E(CCSD) = -75.48318986317773  E_corr = -0.411328086137585
# CCSD(T) correction = -0.0721628487464061
# ENERGY Computing using CCSD T appoach is = -75.55535271192413
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -75.5758096242416
# converged SCF energy = -75.5796206035433
# SCF not converged.
# SCF energy = -75.5927514694402
# SCF not converged.
# SCF energy = -75.5378860255033
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -75.5465314678831
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -75.5887534205518
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -75.5559046728235
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -75.5845006364709
# ************************************##############################################*############################### 44
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f5550400490>
# In Bohr
# [[ 0.          0.          2.78734603]
#  [ 0.          0.         -2.78734603]]
# In angstrom
# [[ 0.     0.     1.475]
#  [ 0.     0.    -1.475]]
# [['C', (0, 0, 1.475)], ['C', (0, 0, -1.475)]]
# [[ 0.          0.          2.78734603]
#  [ 0.          0.         -2.78734603]]
# {'C': [[0, [6665.0, 0.000692, -0.000146, 0.0], [1000.0, 0.005329, -0.001154, 0.0], [228.0, 0.027077, -0.005725, 0.0], [64.71, 0.101718, -0.023312, 0.0], [21.06, 0.27474, -0.063955, 0.0], [7.495, 0.448564, -0.149981, 0.0], [2.797, 0.285074, -0.127262, 0.0], [0.5215, 0.015204, 0.544529, 0.0], [0.1596, -0.003191, 0.580496, 1.0]], [1, [9.439, 0.038109, 0.0], [2.002, 0.20948, 0.0], [0.5456, 0.508557, 0.0], [0.1517, 0.468842, 1.0]], [2, [0.55, 1.0]]]}
# 6        C    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -75.0618876393864
# E(CCSD) = -75.48258210854875  E_corr = -0.4206944691624004
# CCSD(T) correction = -0.0771616286586534
# ENERGY Computing using CCSD T appoach is = -75.55974373720741
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -75.5697666494593
# converged SCF energy = -75.5740423552052
# SCF not converged.
# SCF energy = -75.5841687401479
# SCF not converged.
# SCF energy = -75.5327055757183
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -75.5306155038958
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -75.5821197528431
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -75.5482380311799
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -75.5781904127415
# ************************************##############################################*############################### 45
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f5566b3b3d0>
# In Bohr
# [[ 0.          0.          2.84639998]
#  [ 0.          0.         -2.84639998]]
# In angstrom
# [[ 0.       0.       1.50625]
#  [ 0.       0.      -1.50625]]
# [['C', (0, 0, 1.50625)], ['C', (0, 0, -1.50625)]]
# [[ 0.          0.          2.84639998]
#  [ 0.          0.         -2.84639998]]
# {'C': [[0, [6665.0, 0.000692, -0.000146, 0.0], [1000.0, 0.005329, -0.001154, 0.0], [228.0, 0.027077, -0.005725, 0.0], [64.71, 0.101718, -0.023312, 0.0], [21.06, 0.27474, -0.063955, 0.0], [7.495, 0.448564, -0.149981, 0.0], [2.797, 0.285074, -0.127262, 0.0], [0.5215, 0.015204, 0.544529, 0.0], [0.1596, -0.003191, 0.580496, 1.0]], [1, [9.439, 0.038109, 0.0], [2.002, 0.20948, 0.0], [0.5456, 0.508557, 0.0], [0.1517, 0.468842, 1.0]], [2, [0.55, 1.0]]]}
# 6        C    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -75.0523783140733
# E(CCSD) = -75.48219751376308  E_corr = -0.4298191996897587
# CCSD(T) correction = -0.0820814385542027
# ENERGY Computing using CCSD T appoach is = -75.56427895231728
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -75.5640867169853
# converged SCF energy = -75.568819183196
# SCF not converged.
# SCF energy = -75.5759781006709
# SCF not converged.
# SCF energy = -75.5278646413403
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -75.5473313646094
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -75.5758762977085
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -75.5409005302912
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -75.5722695071772
# ************************************##############################################*############################### 46
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f5566a9f1d0>
# In Bohr
# [[ 0.          0.          2.90545392]
#  [ 0.          0.         -2.90545392]]
# In angstrom
# [[ 0.      0.      1.5375]
#  [ 0.      0.     -1.5375]]
# [['C', (0, 0, 1.5375)], ['C', (0, 0, -1.5375)]]
# [[ 0.          0.          2.90545392]
#  [ 0.          0.         -2.90545392]]
# {'C': [[0, [6665.0, 0.000692, -0.000146, 0.0], [1000.0, 0.005329, -0.001154, 0.0], [228.0, 0.027077, -0.005725, 0.0], [64.71, 0.101718, -0.023312, 0.0], [21.06, 0.27474, -0.063955, 0.0], [7.495, 0.448564, -0.149981, 0.0], [2.797, 0.285074, -0.127262, 0.0], [0.5215, 0.015204, 0.544529, 0.0], [0.1596, -0.003191, 0.580496, 1.0]], [1, [9.439, 0.038109, 0.0], [2.002, 0.20948, 0.0], [0.5456, 0.508557, 0.0], [0.1517, 0.468842, 1.0]], [2, [0.55, 1.0]]]}
# 6        C    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -75.0433106995961
# E(CCSD) = -75.48197236139207  E_corr = -0.4386616617959327
# CCSD(T) correction = -0.0868786896014649
# ENERGY Computing using CCSD T appoach is = -75.56885105099353
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -75.5587483239251
# converged SCF energy = -75.5639320761917
# SCF not converged.
# SCF energy = -75.5681592913822
# SCF not converged.
# SCF energy = -75.5233429402748
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -75.5532292134278
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -75.5699846641104
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -75.5339012210879
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -75.5667156713333
# ************************************##############################################*############################### 47
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f55666eb610>
# In Bohr
# [[ 0.          0.          2.96450786]
#  [ 0.          0.         -2.96450786]]
# In angstrom
# [[ 0.       0.       1.56875]
#  [ 0.       0.      -1.56875]]
# [['C', (0, 0, 1.56875)], ['C', (0, 0, -1.56875)]]
# [[ 0.          0.          2.96450786]
#  [ 0.          0.         -2.96450786]]
# {'C': [[0, [6665.0, 0.000692, -0.000146, 0.0], [1000.0, 0.005329, -0.001154, 0.0], [228.0, 0.027077, -0.005725, 0.0], [64.71, 0.101718, -0.023312, 0.0], [21.06, 0.27474, -0.063955, 0.0], [7.495, 0.448564, -0.149981, 0.0], [2.797, 0.285074, -0.127262, 0.0], [0.5215, 0.015204, 0.544529, 0.0], [0.1596, -0.003191, 0.580496, 1.0]], [1, [9.439, 0.038109, 0.0], [2.002, 0.20948, 0.0], [0.5456, 0.508557, 0.0], [0.1517, 0.468842, 1.0]], [2, [0.55, 1.0]]]}
# 6        C    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -75.0346625783158
# E(CCSD) = -75.48186823047405  E_corr = -0.4472056521582892
# CCSD(T) correction = -0.0915203861904806
# ENERGY Computing using CCSD T appoach is = -75.57338861666453
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -75.55373088745
# converged SCF energy = -75.5593620483569
# SCF not converged.
# SCF energy = -75.5606922473688
# SCF not converged.
# SCF energy = -75.5191208642658
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -75.5376784154595
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -75.5644230882473
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -75.5271766482224
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -75.5615065089276
# ************************************##############################################*############################### 48
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f55664846d0>
# In Bohr
# [[ 0.         0.         3.0235618]
#  [ 0.         0.        -3.0235618]]
# In angstrom
# [[ 0.   0.   1.6]
#  [ 0.   0.  -1.6]]
# [['C', (0, 0, 1.6)], ['C', (0, 0, -1.6)]]
# [[ 0.         0.         3.0235618]
#  [ 0.         0.        -3.0235618]]
# {'C': [[0, [6665.0, 0.000692, -0.000146, 0.0], [1000.0, 0.005329, -0.001154, 0.0], [228.0, 0.027077, -0.005725, 0.0], [64.71, 0.101718, -0.023312, 0.0], [21.06, 0.27474, -0.063955, 0.0], [7.495, 0.448564, -0.149981, 0.0], [2.797, 0.285074, -0.127262, 0.0], [0.5215, 0.015204, 0.544529, 0.0], [0.1596, -0.003191, 0.580496, 1.0]], [1, [9.439, 0.038109, 0.0], [2.002, 0.20948, 0.0], [0.5456, 0.508557, 0.0], [0.1517, 0.468842, 1.0]], [2, [0.55, 1.0]]]}
# 6        C    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -75.0264123668634
# E(CCSD) = -75.48185033397287  E_corr = -0.4554379671094401
# CCSD(T) correction = -0.0959813240823008
# ENERGY Computing using CCSD T appoach is = -75.57783165805517
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -75.5490150361116
# converged SCF energy = -75.5550919741744
# SCF not converged.
# SCF energy = -75.5535583009056
# SCF not converged.
# SCF energy = -75.5151786022206
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -75.5481350024955
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -75.5585571935565
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -75.5207691515903
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -75.5566019395894

# %%
df.to_csv('/content/drive/My Drive/DeepMind' + EXPNO+ 'CE-Final-.csv' )

# %%
df2 = df.copy()

# %%
df.drop(columns=['Weight', 'Element', 'Molecule', 'BasisSet', 'Spin','BuiltMolecule'])
# Out:
#     bond_lenght      CCSDT  DFT-b3lyp   DFT-SCAN  DFT-wB97X-V    DFT-pbe  \
# 0        0.2625 -53.646616 -53.899247 -53.906404   -53.931017 -53.806211
# 1        0.3250 -61.972844 -62.209405 -62.220358   -62.248407 -62.118665
# 2        0.3875 -66.567816 -66.793527 -66.804673   -66.839463 -66.706744
# 3        0.4500 -69.309502 -69.525423 -69.536788   -69.577954 -69.442862
# 4        0.5125 -71.089542 -71.295719 -71.306720   -71.353061 -71.217236
# 5        0.5750 -72.356612 -72.550186 -72.558383   -72.608711 -72.476217
# 6        0.6375 -73.321637 -73.494440 -73.498730   -73.551201 -73.425115
# 7        0.7000 -74.059133 -74.208535 -74.210077   -74.263480 -74.143602
# 8        0.7625 -74.602599 -74.736275 -74.737401   -74.790319 -74.675189
# 9        0.8250 -74.990801 -75.116795 -75.118430   -75.170707 -75.059056
# 10       0.8875 -75.262507 -75.385087 -75.387533   -75.439315 -75.330300
# 11       0.9500 -75.448901 -75.569695 -75.572868   -75.624473 -75.517579
# 12       1.0125 -75.573251 -75.692724 -75.696587   -75.748100 -75.643017
# 13       1.0750 -75.652642 -75.770849 -75.775193   -75.826759 -75.723299
# 14       1.1375 -75.699633 -75.816529 -75.821462   -75.872835 -75.770875
# 15       1.2000 -75.723483 -75.839030 -75.844534   -75.895547 -75.795001
# 16       1.2625 -75.731043 -75.845237 -75.851120   -75.901756 -75.706113
# 17       1.3250 -75.727395 -75.840261 -75.791994   -75.896561 -75.722366
# 18       1.3875 -75.716307 -75.827879 -75.817769   -75.883739 -75.736727
# 19       1.4500 -75.700571 -75.810866 -75.798617   -75.866068 -75.753917
# 20       1.5125 -75.682243 -75.791233 -75.801409   -75.845571 -75.737686
# 21       1.5750 -75.662822 -75.800577 -75.758472   -75.823696 -75.732295
# 22       1.6375 -75.645386 -75.788881 -75.783145   -75.857006 -75.694334
# 23       1.7000 -75.634367 -75.775995 -75.770731   -75.842219 -75.672842
# 24       1.7625 -75.622993 -75.762496 -75.757695   -75.826615 -75.652826
# 25       1.8250 -75.611685 -75.748779 -75.744436   -75.810626 -75.691210
# 26       1.8875 -75.600739 -75.735112 -75.731225   -75.794555 -75.679098
# 27       1.9500 -75.590361 -75.721672 -75.718245   -75.778606 -75.667137
# 28       2.0125 -75.580698 -75.708571 -75.705606   -75.762919 -75.655448
# 29       2.0750 -75.571864 -75.695882 -75.693381   -75.747587 -75.644109
# 30       2.1375 -75.563960 -75.683652 -75.681627   -75.732674 -75.633171
# 31       2.2000 -75.557071 -75.671908 -75.670364   -75.718223 -75.622671
# 32       2.2625 -75.551283 -75.660670 -75.659615   -75.704264 -75.612631
# 33       2.3250 -75.546669 -75.649948 -75.649386   -75.690816 -75.603065
# 34       2.3875 -75.543289 -75.639747 -75.639677   -75.677891 -75.593983
# 35       2.4500 -75.541171 -75.630065 -75.630490   -75.665493 -75.585385
# 36       2.5125 -75.540307 -75.620896 -75.621812   -75.653620 -75.577266
# 37       2.5750 -75.540635 -75.612228 -75.613638   -75.642266 -75.569618
# 38       2.6375 -75.542050 -75.604047 -75.605947   -75.631418 -75.562428
# 39       2.7000 -75.544404 -75.596335 -75.598722   -75.621061 -75.555680
# 40       2.7625 -75.547522 -75.589072 -75.591938   -75.611177 -75.549353
# 41       2.8250 -75.551228 -75.582238 -75.585579   -75.601747 -75.543429
# 42       2.8875 -75.555353 -75.575810 -75.579621   -75.592751 -75.537886
# 43       2.9500 -75.559744 -75.569767 -75.574042   -75.584169 -75.532706
# 44       3.0125 -75.564279 -75.564087 -75.568819   -75.575978 -75.527865
# 45       3.0750 -75.568851 -75.558748 -75.563932   -75.568159 -75.523343
# 46       3.1375 -75.573389 -75.553731 -75.559362   -75.560692 -75.519121
# 47       3.2000 -75.577832 -75.549015 -75.555092   -75.553558 -75.515179
#
#     NN-Functional.DM21  NN-Functional.DM21m  NN-Functional.DM21mc  \
# 0           -53.934215           -53.962565            -53.959435
# 1           -62.243011           -62.266161            -62.265930
# 2           -66.823917           -66.843827            -66.840816
# 3           -69.551909           -69.571255            -69.562620
# 4           -71.319570           -71.353138            -71.331109
# 5           -72.573363           -72.607786            -72.581501
# 6           -73.444405           -73.549217            -73.527129
# 7           -74.174659           -74.266491            -74.245253
# 8           -74.714497           -74.791560            -74.776345
# 9           -75.086915           -75.172297            -75.157456
# 10          -75.425664           -75.441388            -75.428777
# 11          -75.613650           -75.623328            -75.617475
# 12          -75.739840           -75.742596            -75.725956
# 13          -75.820595           -75.821679            -75.841584
# 14          -75.868161           -75.869475            -75.882435
# 15          -75.891875           -75.892799            -75.895422
# 16          -75.898716           -75.898787            -75.908120
# 17          -75.894005           -75.894223            -75.897346
# 18          -75.881746           -75.880615            -75.877359
# 19          -75.864741           -75.860430            -75.851488
# 20          -75.845056           -75.824230            -75.825334
# 21          -75.816010           -75.814719            -75.800786
# 22          -75.804005           -75.803169            -75.777658
# 23          -75.790771           -75.790540            -75.785445
# 24          -75.776882           -75.777372            -75.770778
# 25          -75.762779           -75.764016            -75.755898
# 26          -75.748780           -75.750706            -75.740952
# 27          -75.735161           -75.737633            -75.726196
# 28          -75.722179           -75.725026            -75.711665
# 29          -75.710189           -75.712961            -75.697430
# 30          -75.531135           -75.701298            -75.683586
# 31          -75.517575           -75.689830            -75.670156
# 32          -75.535738           -75.678653            -75.657207
# 33          -75.534526           -75.667821            -75.644765
# 34          -75.407955           -75.657302            -75.632844
# 35          -75.592283           -75.647212            -75.621471
# 36          -75.542225           -75.637537            -75.610638
# 37          -75.521969           -75.628301            -75.600317
# 38          -75.543937           -75.619526            -75.590517
# 39          -75.544862           -75.611184            -75.581209
# 40          -75.527918           -75.603279            -75.572356
# 41          -75.640098           -75.595807            -75.563947
# 42          -75.546531           -75.588753            -75.555905
# 43          -75.530616           -75.582120            -75.548238
# 44          -75.547331           -75.575876            -75.540901
# 45          -75.553229           -75.569985            -75.533901
# 46          -75.537678           -75.564423            -75.527177
# 47          -75.548135           -75.558557            -75.520769
#
#     NN-Functional.DM21mu
# 0             -53.971653
# 1             -62.273832
# 2             -66.846736
# 3             -69.570353
# 4             -71.335411
# 5             -72.587709
# 6             -73.528486
# 7             -74.239178
# 8             -74.767116
# 9             -75.147506
# 10            -75.417641
# 11            -75.607099
# 12            -75.736881
# 13            -75.831324
# 14            -75.882538
# 15            -75.902980
# 16            -75.900988
# 17            -75.887631
# 18            -75.865392
# 19            -75.839406
# 20            -75.816659
# 21            -75.815242
# 22            -75.803073
# 23            -75.789670
# 24            -75.775703
# 25            -75.761741
# 26            -75.748125
# 27            -75.734801
# 28            -75.721741
# 29            -75.708930
# 30            -75.696502
# 31            -75.684501
# 32            -75.672994
# 33            -75.661978
# 34            -75.651416
# 35            -75.641356
# 36            -75.631812
# 37            -75.622745
# 38            -75.614182
# 39            -75.606080
# 40            -75.598438
# 41            -75.591245
# 42            -75.584501
# 43            -75.578190
# 44            -75.572270
# 45            -75.566716
# 46            -75.561507
# 47            -75.556602

# %%
type(df['bond_lenght'].to_numpy() )
# Out:
# numpy.ndarray

# %%
df['bond_lenght'].to_numpy()
# Out:
# array([0.2625, 0.325 , 0.3875, 0.45  , 0.5125, 0.575 , 0.6375, 0.7   ,
#        0.7625, 0.825 , 0.8875, 0.95  , 1.0125, 1.075 , 1.1375, 1.2   ,
#        1.2625, 1.325 , 1.3875, 1.45  , 1.5125, 1.575 , 1.6375, 1.7   ,
#        1.7625, 1.825 , 1.8875, 1.95  , 2.0125, 2.075 , 2.1375, 2.2   ,
#        2.2625, 2.325 , 2.3875, 2.45  , 2.5125, 2.575 , 2.6375, 2.7   ,
#        2.7625, 2.825 , 2.8875, 2.95  , 3.0125, 3.075 , 3.1375, 3.2   ])

# %%
import  matplotlib.font_manager

flist = matplotlib.font_manager.get_fontconfig_fonts()
names = [matplotlib.font_manager.FontProperties(fname=fname).get_name() for fname in flist]
print(names)
# Out:
# ['Liberation Sans', 'Liberation Mono', 'Liberation Sans Narrow', 'Liberation Sans Narrow', 'Liberation Sans', 'Liberation Mono', 'Liberation Serif', 'Liberation Sans', 'Liberation Serif', 'Liberation Sans', 'Liberation Sans Narrow', 'Liberation Serif', 'Liberation Sans Narrow', 'Humor Sans', 'Liberation Mono', 'Liberation Serif', 'Liberation Mono']

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def plotNand(choiceDFT , myfigsize=(12, 10), myfontsize=20):
  plt.figure(0)


  plt.figure(figsize=myfigsize)
  plt.rcParams["font.family"] = "Liberation Serif"



  lengendlist =[]

  if 'CCSDT' in choiceDFT:
    plt.plot(df['bond_lenght'].to_numpy() , df['CCSDT'].to_numpy()  , 'o-')
    lengendlist.append('CCSD(T)')



  for afunctionals in functionalsList:
    if afunctionals in choiceDFT:
      plt.plot(df['bond_lenght'].to_numpy() , df['DFT-'+str(afunctionals)].to_numpy() , 'x-' )
      lengendlist.append(str(afunctionals))

  for aDMFunctionalvalue in dm21.Functional:
    if str(aDMFunctionalvalue) in choiceDFT:
      plt.plot(df['bond_lenght'].to_numpy() , df['NN-'+str(aDMFunctionalvalue)].to_numpy()  )
      lengendlist.append(str(aDMFunctionalvalue))



  plt.legend(lengendlist,  fontsize = myfontsize)
  plt.rc('xtick',labelsize=myfontsize-1)
  plt.rc('ytick',labelsize=myfontsize-2)
  plt.ylabel('Energy in Hartree', fontsize = myfontsize)
  plt.xlabel('Bond length in angstrom', fontsize = myfontsize)
  plt.title(ValidatedBasisSet, fontsize = myfontsize)
  plt.show()

# %%
choiceDFT = ['CCSDT', 'b3lyp' , 'Functional.DM21m']
plotNand(choiceDFT , myfigsize=(12, 10), myfontsize=20)

# %%
choiceDFT = ['CCSDT', 'b3lyp' , 'SCAN' , 'wB97X-V', 'pbe' , 'Functional.DM21m', 'Functional.DM21mc' , 'Functional.DM21mu']
plotNand(choiceDFT , myfigsize=(12, 10), myfontsize=20)

# %%
choiceDFT = ['CCSDT',   'SCAN' , 'Functional.DM21m',  'Functional.DM21mu']
plotNand(choiceDFT , myfigsize=(20, 20), myfontsize=20)

# %%
choiceDFT = ['CCSDT',   'b3lyp' ,    'Functional.DM21m']
plotNand(choiceDFT , myfigsize=(20, 20), myfontsize=20)

# %%
choiceDFT = ['CCSDT',   'pbe' ,    'Functional.DM21m']
plotNand(choiceDFT , myfigsize=(20, 20), myfontsize=20)

# %%
choiceDFT = ['CCSDT',   'pbe' ,    'Functional.DM21m']
plotNand(choiceDFT , myfigsize=(20, 20), myfontsize=20)

# %%
choiceDFT = ['CCSDT', 'b3lyp' , 'Functional.DM21m']
plotNand(choiceDFT , myfigsize=(20, 16), myfontsize=20)

# %%
choiceDFT = ['CCSDT', 'wB97X-V' , 'Functional.DM21m']
plotNand(choiceDFT , myfigsize=(20, 16), myfontsize=20)

# %%
def plotNandZOOM(choiceDFT , myfigsize=(12, 10), myfontsize=20, ylimits=[-170,-10], xlimits=[0, 4]):
  plt.figure(0)


  plt.figure(figsize=myfigsize)
  plt.rcParams["font.family"] = "Liberation Serif"

  axes = plt.axes()
  axes.set_ylim(ylimits  )
  axes.set_xlim(xlimits )

  lengendlist =[]

  if 'CCSDT' in choiceDFT:
    plt.plot(df['bond_lenght'].to_numpy() , df['CCSDT'].to_numpy()  , 'o-')
    lengendlist.append('CCSD(T)')



  for afunctionals in functionalsList:
    if afunctionals in choiceDFT:
      plt.plot(df['bond_lenght'].to_numpy() , df['DFT-'+str(afunctionals)].to_numpy() , 'x-' )
      lengendlist.append(str(afunctionals))

  for aDMFunctionalvalue in dm21.Functional:
    if str(aDMFunctionalvalue) in choiceDFT:
      plt.plot(df['bond_lenght'].to_numpy() , df['NN-'+str(aDMFunctionalvalue)].to_numpy()  )
      lengendlist.append(str(aDMFunctionalvalue))



  plt.legend(lengendlist,  fontsize = myfontsize)
  plt.rc('xtick',labelsize=myfontsize-1)
  plt.rc('ytick',labelsize=myfontsize-2)
  plt.ylabel('Energy in Hartree', fontsize = myfontsize)
  plt.xlabel('Bond length in angstrom', fontsize = myfontsize)
  plt.title(ValidatedBasisSet, fontsize = myfontsize)
  plt.show()

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-00cf07b74dcd> in <module>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %% [markdown]
# #validate the energy against NIST bechmarks ..
# manually just the ball park number some be matcoed
#
# https://cccbdb.nist.gov/bseenergy2x.asp shows
# or  http://www.begdb.org/index.php
#
# For C,
# *   CCSD = -75.7656956
# *   CCST(T)/cc-pVQZ is -75.8552316
