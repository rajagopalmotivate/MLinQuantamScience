# %% [markdown]
# <a href="https://colab.research.google.com/github/rajagopalmotivate/MLinQuantamScience/blob/main/Copy_of_Nandri_Nandri_DM21_plot_energy_vs_bond_lenght_ver_J400_12_Jun_2022_WORKS_Well_O.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Simple comparision of DFT vs NN
# ## Hypothesis: NN performs as good as DFT
# ## Experiment: Compare

# %%
EXPNO ='ENERGYVsBOND_0004_O'

dictPeriodicTable = {'O': 8}
 
elementname ='O'

# %%
firstTimeorRestart = True

# %% [markdown]
# #  basis set and as per DM21 authors
# For all benchmarking, we use the large aug'-def2-QZVP basis set
#
# During training,
# For all the atoms and diatomic molecules in the regression set we generate the features for
# the SCF loss at PySCF grid level 2 and use the largest basis set in the aug-pc-X family such
# that the number of basis functions is less than 128.
# For larger neutral molecules we use grid
# level 1 and the largest basis set with less than 128 basis functions from cc-pCV(Q+d)Z, ccpCV(T+d)Z, cc-pV(T+d)Z or cc-pV(D+d)Z

# %%
listBasisSet = ['6-21g' , 'cc-pvqz' , 'def2-qzvp'  ]

listBasisSet = ['def2-QZVP' , 'cc-pCVTZ' ,  'aug-pc-3' , 'aug-cc-pV(Q+d)Z', 'aug-cc-pCV5Z', 'aug-ccpwCV5Z', '6-21g']

listBasisSet = ['cc-pCVDZ' , 'def2-QZVP' , 'cc-pCVTZ' ,  'aug-pc-3' , 'aug-cc-pV(Q+d)Z', 'aug-cc-pCV5Z', 'aug-ccpwCV5Z', '6-31g', 'STO-3G' , 'def2-QZVPPD' ]

listBasisSet = ['def2-QZVP' , 'cc-pCVTZ', 'cc-pVQZ' , 'cc-pVXZ', 'aug-cc-pV(Q+d)Z' , '6-31g' ]

listBasisSet = [   'cc-pVQZ' , 'def2-QZVP' , 'cc-pCVTZ',  'cc-pVXZ' , '6-31g' ]

listBasisSet = [   'cc-pVQZ' , 'def2-QZVP' , 'cc-pCVQZ'  ]

listBasisSet = [   'cc-pVQZ' , 'cc-pVTZ', 'cc-pVDZ',  'cc-pCVQZ', 'cc-pCV5Z',  'def2-QZVP', 'def2-TCVPPD', '6-31g' ,'STO-3G'   ]

listBasisSet = [   'cc-pVQZ', 'def2-QZVP']

listBasisSet = [  'cc-pV7Z', 'cc-pV6Z',  'cc-pVQZ' , 'cc-pVDZ' , 'cc-pCVQZ',    'def2-QZVP', 'def2-7CVPPD', '6-31g' ,'STO-3G'   ]


listBasisSet = [ 'cc-pVQZ' , 'cc-pVDZ' , "aug'-def2-QZVP", '6-31g' , 'aug-pcJ-4', 'cc-pCV(Q+d)Z']

listBasisSet = [ 'cc-pVQZ' , 'cc-pVDZ' , 'def2-QZVP', '6-31g' ]


listBasisSet = [   'cc-pVDZ' ]


#listBasisSet = [ 'cc-pVQZ' , "aug'-def2-QZVP"]

# %%
#dictPeriodicTable = {'H': 1, 'He': 2, 'Li': 3, 'Be': 4, 'B': 5, 'C': 6, 'N': 7, 'O': 8, 'F': 9, 'Ne': 10 }

#dictPeriodicTable = {'H': 1, 'He': 2, 'Li': 3, 'Be': 4, 'B': 5, 'C': 6, 'N': 7, 'O': 8, 'F': 9, 'Ne': 10 , 'Na':11, 'Mg':12 , 'Al':13, 'Si':14, 'P':15, 'S':16 , 'Cl':17, 'Ar':18}

 
dictPeriodicTableSpinValues = {'H': 1,  'He': 0, 'Li': 1, 'Be': 0, 'B': 1, 'C': 0, 'N': 1, 'O': 0, 'F': 1, 'Ne': 0 }



print(str( 'Weight'  + ' ' +   ' \t Element     \t  SPIN'    ))
# Out:
# Weight  	 Element     	  SPIN

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Step 1: Install

# %%
#!pip install git+git://github.com/deepmind/deepmind-research.git#subdirectory=density_functional_approximation_dm21

# %%
# !git clone https://github.com/deepmind/deepmind-research.git
# Out:
# Cloning into 'deepmind-research'...
# remote: Enumerating objects: 2581, done.
# remote: Counting objects: 100% (209/209), done.
# remote: Compressing objects: 100% (155/155), done.
# remote: Total 2581 (delta 55), reused 201 (delta 54), pack-reused 2372
# Receiving objects: 100% (2581/2581), 92.05 MiB | 34.38 MiB/s, done.
# Resolving deltas: 100% (1204/1204), done.

# %%
cd deepmind-research/density_functional_approximation_dm21
# Out:
# /content/deepmind-research/density_functional_approximation_dm21/deepmind-research/density_functional_approximation_dm21/deepmind-research/density_functional_approximation_dm21

# %%
pwd
# Out:
# '/content/deepmind-research/density_functional_approximation_dm21/deepmind-research/density_functional_approximation_dm21/deepmind-research/density_functional_approximation_dm21'

# %%
# !pip install .
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/deepmind-research/density_functional_approximation_dm21/deepmind-research/density_functional_approximation_dm21/deepmind-research/density_functional_approximation_dm21
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from density-functional-approximation-dm21==0.1) (1.1.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from density-functional-approximation-dm21==0.1) (21.4.0)
# Requirement already satisfied: h5py<3.3.0 in /usr/local/lib/python3.7/dist-packages (from density-functional-approximation-dm21==0.1) (3.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from density-functional-approximation-dm21==0.1) (1.21.6)
# Requirement already satisfied: pyscf in /usr/local/lib/python3.7/dist-packages (from density-functional-approximation-dm21==0.1) (2.0.1)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.7/dist-packages (from density-functional-approximation-dm21==0.1) (2.8.2+zzzcolab20220527125636)
# Requirement already satisfied: tensorflow_hub in /usr/local/lib/python3.7/dist-packages (from density-functional-approximation-dm21==0.1) (0.12.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py<3.3.0->density-functional-approximation-dm21==0.1) (1.5.2)
# Requirement already satisfied: scipy!=1.5.0,!=1.5.1 in /usr/local/lib/python3.7/dist-packages (from pyscf->density-functional-approximation-dm21==0.1) (1.4.1)
# Requirement already satisfied: tensorflow-estimator<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (2.8.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (4.2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (0.26.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (14.0.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (3.3.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (0.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (1.6.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (57.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (1.46.3)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (0.5.3)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (2.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (2.8.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (1.14.1)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (2.8.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (1.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (1.15.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (1.1.2)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (3.17.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow->density-functional-approximation-dm21==0.1) (0.37.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (0.4.6)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (3.3.7)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (1.35.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (2.23.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (2022.5.18.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (3.2.0)
# Building wheels for collected packages: density-functional-approximation-dm21
#   Building wheel for density-functional-approximation-dm21 (setup.py) ... done
#   Created wheel for density-functional-approximation-dm21: filename=density_functional_approximation_dm21-0.1-py3-none-any.whl size=6085418 sha256=e62d02a77ecaffc8f977781a6248e758b65c8b384c294ba1ba00535faddfb8f0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9e0iim3u/wheels/9a/c1/df/abc628eaa2dcdcd88b1d9b80e01e33872fee95d21f0501f1b3
# Successfully built density-functional-approximation-dm21
# Installing collected packages: density-functional-approximation-dm21
#   Attempting uninstall: density-functional-approximation-dm21
#     Found existing installation: density-functional-approximation-dm21 0.1
#     Uninstalling density-functional-approximation-dm21-0.1:
#       Successfully uninstalled density-functional-approximation-dm21-0.1
# Successfully installed density-functional-approximation-dm21-0.1

# %% [markdown]
# ## Step 2: Configure RAM optionally

# %%
from pyscf import gto
from pyscf import dft

from pyscf import __config__
MAX_MEMORY = getattr(__config__, 'MAX_MEMORY')
MAX_MEMORY
# Out:
# 100755

# %%
import psutil
systemresources = psutil.virtual_memory()

MAX_MEMORY = round( systemresources.available  * 0.000009)
PYSCF_MAX_MEMORY  = MAX_MEMORY

print('Configured to use max RAM resources of  ' + str(MAX_MEMORY))
# Out:
# Configured to use max RAM resources of  98880

# %%
setattr(__config__, 'MAX_MEMORY', PYSCF_MAX_MEMORY)

setattr(__config__, 'PYSCF_MAX_MEMORY', PYSCF_MAX_MEMORY)

# %%
MAX_MEMORY = getattr(__config__, 'MAX_MEMORY')
MAX_MEMORY
# Out:
# 98880

# %% [markdown]
# ## Step 3:
#
# ### 3.1 Define the periodic table (Define atomic weight and periodic weight for each element)
#
# ### 3.2 Define the spin value for each element
#
# ### 3.3 You can load any new basis function.  Just visit the Basics Exchange and get a new Basis Function URL .
# #### here we download a basis set full defintion file from an URL and then use it to construct a molecule
#
# #### To get a web URL, just visit https://www.basissetexchange.org/

# %% [markdown]
# http://vergil.chemistry.gatech.edu/courses/chem6485/pdf/basis-sets.pdf
#
# https://youtu.be/irQ_c_fW5f8?t=971
#
#
# 1.   cc-pCVXZ or aug-cc-pCVXZ basis sets;  you should use basis sets like this if you do not freeze core
# 2.   cc-pVQZ is great for CCSD(T)

# %%
def trydownloadingBasisSet(ElementsinMolecule, BasisSet, versionno):  
    target_url = 'https://www.basissetexchange.org/api/basis/' + str(BasisSet) +  '/format/nwchem/?version='+ str( versionno)+'&elements=' + str(ElementsinMolecule) 
    #print(target_url)
    try:
      textfile = urllib.request.urlopen(target_url)    
      mydownloadedfile = ""
      for line in textfile:
          #print(line.decode('utf-8')) #utf-8 or iso8859-1 or whatever the page encoding scheme is
          mydownloadedfile += line.decode('utf-8') 
      return True    
    except:
      return False

# %%
import urllib   # the lib that handles the url stuff
import urllib.request  # the lib that handles the url stuff


def getValidBasisSet(MoleculeList):
  ValidatedBasisSet = []
  ValBSSetVersionNumberDict = {}
  errorproneBasisSet = []
  for BasisSet in listBasisSet:
    didnotworkatallforanyversion = True
    for versionno in range(0,4):
      isworking = trydownloadingBasisSet(MoleculeList, BasisSet, versionno)
      if isworking == True:
        didnotworkatallforanyversion = False
        ValBSSetVersionNumberDict[BasisSet] = versionno
        ValidatedBasisSet.append(BasisSet)
        break
    if didnotworkatallforanyversion == True:
      errorproneBasisSet.append(BasisSet)
  return ValidatedBasisSet

# %%
def downloadBasisSetAutoVersion(ElementsinMolecule, BasisSet):  
    for versionumber in range (0,4):
      target_url = 'https://www.basissetexchange.org/api/basis/' + str(BasisSet) +  '/format/nwchem/?version='+ str( versionumber)+'&elements=' + str(ElementsinMolecule) 
      try:
        textfile = urllib.request.urlopen(target_url)    
        mydownloadedfile = ""
        for line in textfile:
            #print(line.decode('utf-8')) #utf-8 or iso8859-1 or whatever the page encoding scheme is
            mydownloadedfile += line.decode('utf-8') 
        return mydownloadedfile    
      except:
        return None

# %%
PerdiocTableNumber = dictPeriodicTable [elementname]
ValidatedBasisSet = getValidBasisSet(PerdiocTableNumber)
len(ValidatedBasisSet)
ValidatedBasisSet
# Out:
# ['cc-pVDZ']

# %%
basisSethandpicked =[  ]

# %%
#listBasisSet = basisSet652

# %%
try:
  print("Hello")
except:
  print("Something went wrong")
else:
  print("Nothing went wrong")
# Out:
# Hello
# Nothing went wrong

# %%
#downloadBasisSetAutoVersion(1,'3-21G')

# %% [markdown]
# geomtery optimization

# %%
!	pip install -U pyberny
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyberny in /usr/local/lib/python3.7/dist-packages (0.6.3)
# Requirement already satisfied: numpy<2.0,>=1.15 in /usr/local/lib/python3.7/dist-packages (from pyberny) (1.21.6)

# %%
from pyscf import gto
from pyscf import scf
from pyscf import cc
from pyscf.cc import ccsd_t_lambda_slow as ccsd_t_lambda
from pyscf.grad import ccsd_t as ccsd_t_grad
from pyscf.geomopt import berny_solver

def f_usefforberny_solver(mol):
    # Compute CCSD(T) energy
    mf = scf.RHF(mol).run()
    mycc = cc.CCSD(mf).run()
    et_correction = mycc.ccsd_t()
    e_tot = mycc.e_tot + et_correction

    # Compute CCSD(T) gradients
    g = ccsd_t_grad.Gradients(mycc).kernel()
    print('CCSD(T) nuclear gradients:')
    print(g)
    return e_tot, g

# %%
 hashLookUpMolecules = dict()

# %%
def GetoptimizedMolecule(randomMol):
  global hashLookUpMolecules
  print('****************************************************************GEOMENTRY OPTIMIZATION Starts***********************************************')  
  print('MOLECULE KEY is')
  print([randomMol.basis])
  if randomMol in hashLookUpMolecules:
    saved_mol = hashLookUpMolecules[randomMol]
    print('****************************************************************GEOMENTRY looked up from Hashtable***********************************************')  
    return saved_mol
  fake_method = berny_solver.as_pyscf_method(randomMol, f_usefforberny_solver)
  new_mol = berny_solver.optimize(fake_method , maxsteps=400)
  print('Old geometry (Bohr)')
  print(randomMol.atom_coords())  
  print('New geometry (Bohr)')
  print(new_mol.atom_coords())  
  hashLookUpMolecules[randomMol] = new_mol
  print('****************************************************************GEOMENTRY OPTIMIZATION Ends***********************************************')  
  return new_mol

# %% [markdown]
# DM21

# %%
import density_functional_approximation_dm21 as dm21
from pyscf import gto
from pyscf import dft

# %%
import pandas as pd
import numpy as np

# %%
GlobalBONDLENGTH = 0.0001

# %%
def buildaMoleculeSpin(elementname, elementname2, mydownloadedfile, mydownloadedfile2, trythisspin ):
      global GlobalBONDLENGTH
      mol = gto.Mole()

      #mol.unit = 'B'
      mol.unit = 'Angstrom'
      
      mol.atom = [[elementname, ( 0, 0, GlobalBONDLENGTH)], [elementname2, (0, 0, -1* GlobalBONDLENGTH)] ]
      mol.spin =  trythisspin
      mol.symmetry = True
      mol.basis = { elementname: gto.parse(mydownloadedfile)  ,     elementname2: gto.parse(mydownloadedfile2)        }
      #mol.max_memory = PYSCF_MAX_MEMORY
      mol.build()
      return mol

# %% [markdown]
# Geometry for C2 (Carbon diatomic) 1Σg+ D*H
#
#
# https://cccbdb.nist.gov/geom3x.asp?method=63&basis=25
# ```
# CCSD(T)=FULL/cc-pVQZ
#
# Atom	X	Y	Z
# C	0.0000000	0.0000000	0.6210880
# C	0.0000000	0.0000000	-0.6210880
#
#
#
# CCSD(T)=FULL/cc-pVDZ
#
# Atom	Internal
# x (Å)	y (Å)	z (Å)
# C1	0.0000	0.0000	0.6211
# C2	0.0000	0.0000	-0.6211

# %%
def buildaMoleculeTryMOLECULEELEMENTCOUNT2(elementname, elementname2, mydownloadedfile , mydownloadedfile2 ):
  molecule = None 
  for spinvaluecheckthis in range(5):
    try:
      molecule = buildaMoleculeSpin(elementname,elementname2, mydownloadedfile, mydownloadedfile2, spinvaluecheckthis )      
      return molecule, spinvaluecheckthis
      break
    except:
      tempexcept = True
      #print('SPIN is not correct. Auto matically trying another spin value...')
    else:
      tempelse = True
      #print('TRYING SPIN')
  return molecule, spinvaluecheckthis

# %%
def buildaMoleculeSpinMOLECULEELEMENTCOUNT1(elementname, mydownloadedfile,  trythisspin ):
      mol = gto.Mole()
      #mol.atom = '''H 0 0 0'''
      mol.atom = [[elementname, (0, 0, 0)] ]
      mol.spin =  trythisspin
      mol.basis = { elementname: gto.parse(mydownloadedfile)       }
      mol.build()
      return mol

# %%
def buildaMoleculeTryMOLECULEELEMENTCOUNT1(elementname,  mydownloadedfile ):
  molecule = None 
  for spinvaluecheckthis in range(5):
    try:
      molecule = buildaMoleculeSpinMOLECULEELEMENTCOUNT1(elementname, mydownloadedfile, spinvaluecheckthis )      
      return molecule, spinvaluecheckthis
      break
    except:
      tempexcept = True
      #print('SPIN is not correct. Auto matically trying another spin value...')
    else:
      tempelse = True
      #print('TRYING SPIN')
  return molecule, spinvaluecheckthis

# %% [markdown]
# ## Step 4: Expected format of output table

# %% [markdown]
# ## Step 5. Input values to be considered in this computation

# %% [markdown]
# ## Step 6. Compute Results
# ## Run the computation for the above input values

# %%
functionalsList = ['b3lyp','M06-2X' , 'SCAN'    ,'wB97X-V',  'PW6B95' , 'pbe']

functionalsList = ['b3lyp','M06-2X' , 'SCAN'    ,'wB97X-V',  'PW6B95' ,  'pbe' ,  'pbe0']

functionalsList = [ 'b3lyp', 'SCAN'  , 'wB97X-V'  , 'pbe']

# %%
from pyscf import dft

# DFT computation of SCF energy  
def SCFenergyFunctionalsbasedonDFTGOLD(mol , functionals ):
  if mol.spin == 0:
    mf = dft.RKS(mol)
  else:
    mf = dft.UKS(mol)
  # functional.
  #mf.xc = 'B3LYP'
  mf.max_memory = PYSCF_MAX_MEMORY
  mf.xc = functionals
  # Run the DFT calculation.
  answerDFT = mf.kernel()
  return answerDFT

# %%
# DFT computation of SCF energy  
def SCFenergyFunctionalsbasedonDFT(mol , functionals ):
    mf = mol.KS()
   # mf.xc = 'b3lyp'
   # mf.xc = 'pbe0'
   # mf.xc = 'M06-2X'
   # mf.xc = 'SCAN'    
   # mf.xc = 'wB97X-V'
   # mf.xc = 'PW6B95'
    mf.xc = functionals
    # Run the DFT calculation.
    answerDFT = mf.kernel()
    return answerDFT

# %%
def SCFenergyFunctionalsbasedonNNGOLD(mol,  NNfunctionals ):
    if mol.spin == 0:
      mf = dft.RKS(mol)
    else:
      mf = dft.UKS(mol)
    #mf._numint = dm21.NeuralNumInt(dm21.Functional.DM21m )
    mf._numint = dm21.NeuralNumInt(NNfunctionals)
    mf.max_memory = PYSCF_MAX_MEMORY
    # Run the DFT calculation.
    answerNN = mf.kernel()
    return answerNN

# %%
def SCFenergyFunctionalsbasedonNN(mol,  NNfunctionals, functionals='b3lyp'):
    mf = mol.KS()
    mf.xc = functionals
    #mf._numint = dm21.NeuralNumInt(dm21.Functional.DM21m )
    mf._numint = dm21.NeuralNumInt(NNfunctionals)
    # Run the DFT calculation.
    answerNN = mf.kernel()
    return answerNN

# %%
# DFT computation of SCF energy  
def SCFenergybasedonDFT(mol):
    mf = dft.RKS(mol)
    # Run the DFT calculation.
    answerDFT = mf.kernel()
    return answerDFT

# %%
# Neural network based prediction of SCF energy   
def SCFenergybasedonNN(mol):
    mf = dft.RKS(mol)
    mf._numint = dm21.NeuralNumInt(dm21.Functional.DM21)
    # Run the DFT calculation.
    answerNN = mf.kernel()
    return answerNN

# %%
# CCSD computation 
def SCFenergybasedonCCSD(mol):
  ccsdanswer = mol.apply('CCSD').run().e_tot
  return ccsdanswer

# %%
from pyscf import  scf, cc

# CCSD-T computation 
def SCFenergybasedonCCSDTGOLD(mol):
  try:
    mf = scf.HF(mol).run()
    mf.max_memory = PYSCF_MAX_MEMORY
    mycc = cc.CCSD(mf).run()
    #print('CCSD  energy', mycc.e_tot)
    et = mycc.ccsd_t()
    CCSDTotal = mycc.e_tot + et
  except ZeroDivisionError:
    print('000000000000000000000000000000000000000-------CCSDT Error------------00000000000000000000000. Using CCSD')
    return SCFenergybasedonCCSD(mol)
  #print('CCSD(T) total energy', mycc.e_tot + et)
  return CCSDTotal

# %%
import urllib   # the lib that handles the url stuff
import urllib.request  # the lib that handles the url stuff
import numpy
from google.colab import files


print( 'No'  + '        ' + 'Element' + '    \t  \t \t ' +  'Basis Set')
# Out:
# No        Element    	  	 	 Basis Set

# %%
ValidatedBasisSetSOURCE = getValidBasisSet(PerdiocTableNumber)

# %%
def compute1Mol1BasisSet(elementname, ValidatedBasisSetStart , df):
  if True:
    PerdiocTableNumber = dictPeriodicTable [elementname]
    ValidatedBasisSet = ValidatedBasisSetSOURCE[ValidatedBasisSetStart:ValidatedBasisSetStart+1]
    for BasisSet in ValidatedBasisSet:    
      print('***********************************************************')
      print('***********************************************************')
      print('***********************************************************')

      mydownloadedfile = downloadBasisSetAutoVersion(PerdiocTableNumber,BasisSet)      
      molUnoptimized, myspin = buildaMoleculeTryMOLECULEELEMENTCOUNT2(elementname, elementname, mydownloadedfile , mydownloadedfile )
      if molUnoptimized == None:
        return df

      print('.............................................Molecule details......................................................')
      print(molUnoptimized)
      print('In Bohr')
      print(molUnoptimized.atom_coords(unit='Bohr'))
      print('In angstrom')
      print(molUnoptimized.atom_coords(unit='ANG'))


     # mol = GetoptimizedMolecule(molUnoptimized)
      mol = molUnoptimized
        
      print(mol.atom)
      print(mol.atom_coords(unit='Bohr'))
      print(mol.basis)
      print(str( PerdiocTableNumber)  + '        ' + str(elementname) + '    \t  \t \t ' + str(BasisSet))     
      print('.............................................COMPUTING SCF energy......................................................')

      aResultDict = computePart(mol )


      aResultDict['BasisSet'] = [BasisSet]

      dfforOneElement = pd.DataFrame(aResultDict )
      df = df.append(dfforOneElement, ignore_index = True)

      return df


    #  files.download('ComputedEnergy'+str(ValidatedBasisSetStart)+'.csv')

# %%
def computePart(mol):
  global DFT_energies 
  global NN_engeries 
  global CCSD_energies 
  global CCSD_Tenergies 
  global fci_energies 
  global bond_lengths 
  global Mole_bond_defintions 


  if True:
      aResultDict = {}
      aResultDict['bond_lenght'] = GlobalBONDLENGTH * 2.0
      aResultDict['Weight'] = PerdiocTableNumber
      aResultDict['Element'] = [elementname]
      aResultDict['Molecule'] = [mol.atom]
      aResultDict['Spin'] = [mol.spin]
      aResultDict['BuiltMolecule'] = [  mol.basis   ]

      print('++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++')
      # Run the CCSD calculation.
     # CCSDenergy = SCFenergybasedonCCSD(mol)
     # print('ENERGY Computing using CCSD appoach is = ' + str(CCSDenergy ))
      print('++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++')
      CCSDTenergy = SCFenergybasedonCCSDTGOLD(mol)
      print('ENERGY Computing using CCSD T appoach is = ' + str(CCSDTenergy ))


      #aResultDict['DFTApproach'] = answerDFT
      #aResultDict['NNApproach'] = answerNN
     # aResultDict['CCSD'] = CCSDenergy
      aResultDict['CCSDT'] = CCSDTenergy
     # CCSD_energies += [CCSDenergy]
      CCSD_Tenergies += [CCSDTenergy]

      print('++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++')
      for afunctionals in functionalsList:
        ans = SCFenergyFunctionalsbasedonDFTGOLD(mol, afunctionals)
        aResultDict['DFT-'+str(afunctionals)] = ans    
        DFT_energies += [ans]


      print('++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++')
      for aDMFunctionalvalue in dm21.Functional:
        if str(aDMFunctionalvalue) ==  'Functional.DM21m' :           
        #if True:
          ans = SCFenergyFunctionalsbasedonNNGOLD(mol, aDMFunctionalvalue)
          aResultDict['NN-'+str(aDMFunctionalvalue)] = ans    
          NN_engeries += [ans]


      return aResultDict

# %%
if firstTimeorRestart == True:
  df = pd.DataFrame(columns = ['Weight', 'Element', 'Molecule', 'BasisSet','Spin', 'BuiltMolecule' ])

# %%
DFT_energies = []
NN_engeries = []
CCSD_energies = []
CCSD_Tenergies = []
fci_energies = []
bond_lengths = []
Mole_bond_defintions = []

# %%
n_points = 44
bond_length_interval = 2.6 / n_points

# %%
for i in range(0, len(ValidatedBasisSetSOURCE)):
  try:
    for elementname in dictPeriodicTable.keys():
      for point in range(1, n_points + 1):
        print('************************************##############################################*############################### ' + str(point))
        bond_length = bond_length_interval * float(point) + 0.2
        bond_lengths += [bond_length]
        GlobalBONDLENGTH = bond_length/2.0
        df = compute1Mol1BasisSet(elementname, ValidatedBasisSetStart=i , df=df)
  except:
    print('Exception.. continuing')
# Out:
# ************************************##############################################*############################### 1
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7fe34a199990>
# In Bohr
# [[ 0.          0.          0.24480543]
#  [ 0.          0.         -0.24480543]]
# In angstrom
# [[ 0.          0.          0.12954545]
#  [ 0.          0.         -0.12954545]]
# [['O', (0, 0, 0.12954545454545455)], ['O', (0, 0, -0.12954545454545455)]]
# [[ 0.          0.          0.24480543]
#  [ 0.          0.         -0.24480543]]
# {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], [1759.0, 0.00547, -0.001263, 0.0], [400.8, 0.027837, -0.006267, 0.0], [113.7, 0.1048, -0.025716, 0.0], [37.03, 0.283062, -0.070924, 0.0], [13.27, 0.448719, -0.165411, 0.0], [5.025, 0.270952, -0.116955, 0.0], [1.013, 0.015458, 0.557368, 0.0], [0.3023, -0.002585, 0.572759, 1.0]], [1, [17.7, 0.043018, 0.0], [3.854, 0.228913, 0.0], [1.046, 0.508728, 0.0], [0.2753, 0.460531, 1.0]], [2, [1.185, 1.0]]]}
# 8        O    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -110.822517027442
# E(CCSD) = -111.0644913062097  E_corr = -0.241974278767893
# CCSD(T) correction = -0.00923926188835436
# ENERGY Computing using CCSD T appoach is = -111.0737305680981
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -111.471196537929
# SCF not converged.
# SCF energy = -111.480127047664
# SCF not converged.
# SCF energy = -111.507334338432
# SCF not converged.
# SCF energy = -111.375395530293
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -111.543450426081
# ************************************##############################################*############################### 2
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7fe441651850>
# In Bohr
# [[ 0.          0.          0.30063825]
#  [ 0.          0.         -0.30063825]]
# In angstrom
# [[ 0.          0.          0.15909091]
#  [ 0.          0.         -0.15909091]]
# [['O', (0, 0, 0.1590909090909091)], ['O', (0, 0, -0.1590909090909091)]]
# [[ 0.          0.          0.30063825]
#  [ 0.          0.         -0.30063825]]
# {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], [1759.0, 0.00547, -0.001263, 0.0], [400.8, 0.027837, -0.006267, 0.0], [113.7, 0.1048, -0.025716, 0.0], [37.03, 0.283062, -0.070924, 0.0], [13.27, 0.448719, -0.165411, 0.0], [5.025, 0.270952, -0.116955, 0.0], [1.013, 0.015458, 0.557368, 0.0], [0.3023, -0.002585, 0.572759, 1.0]], [1, [17.7, 0.043018, 0.0], [3.854, 0.228913, 0.0], [1.046, 0.508728, 0.0], [0.2753, 0.460531, 1.0]], [2, [1.185, 1.0]]]}
# 8        O    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -124.46983494119
# E(CCSD) = -124.7086349839581  E_corr = -0.2388000427682311
# CCSD(T) correction = -0.0100576456214166
# ENERGY Computing using CCSD T appoach is = -124.71869262957955
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -125.143240641537
# SCF not converged.
# SCF energy = -125.138118059014
# SCF not converged.
# SCF energy = -125.18094845166
# SCF not converged.
# SCF energy = -125.046992649831
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -125.208715751926
# ************************************##############################################*############################### 3
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7fe3c714a410>
# In Bohr
# [[ 0.          0.          0.35647106]
#  [ 0.          0.         -0.35647106]]
# In angstrom
# [[ 0.          0.          0.18863636]
#  [ 0.          0.         -0.18863636]]
# [['O', (0, 0, 0.18863636363636366)], ['O', (0, 0, -0.18863636363636366)]]
# [[ 0.          0.          0.35647106]
#  [ 0.          0.         -0.35647106]]
# {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], [1759.0, 0.00547, -0.001263, 0.0], [400.8, 0.027837, -0.006267, 0.0], [113.7, 0.1048, -0.025716, 0.0], [37.03, 0.283062, -0.070924, 0.0], [13.27, 0.448719, -0.165411, 0.0], [5.025, 0.270952, -0.116955, 0.0], [1.013, 0.015458, 0.557368, 0.0], [0.3023, -0.002585, 0.572759, 1.0]], [1, [17.7, 0.043018, 0.0], [3.854, 0.228913, 0.0], [1.046, 0.508728, 0.0], [0.2753, 0.460531, 1.0]], [2, [1.185, 1.0]]]}
# 8        O    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -132.981595504745
# E(CCSD) = -133.2472483377961  E_corr = -0.2656528330513821
# CCSD(T) correction = -0.0251614956647223
# ENERGY Computing using CCSD T appoach is = -133.2724098334608
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -133.66470420586
# SCF not converged.
# SCF energy = -133.632257038709
# SCF not converged.
# SCF energy = -133.678643278437
# SCF not converged.
# SCF energy = -133.565676336746
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -133.679277185447
# ************************************##############################################*############################### 4
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7fe34a4a5850>
# In Bohr
# [[ 0.          0.          0.41230388]
#  [ 0.          0.         -0.41230388]]
# In angstrom
# [[ 0.          0.          0.21818182]
#  [ 0.          0.         -0.21818182]]
# [['O', (0, 0, 0.2181818181818182)], ['O', (0, 0, -0.2181818181818182)]]
# [[ 0.          0.          0.41230388]
#  [ 0.          0.         -0.41230388]]
# {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], [1759.0, 0.00547, -0.001263, 0.0], [400.8, 0.027837, -0.006267, 0.0], [113.7, 0.1048, -0.025716, 0.0], [37.03, 0.283062, -0.070924, 0.0], [13.27, 0.448719, -0.165411, 0.0], [5.025, 0.270952, -0.116955, 0.0], [1.013, 0.015458, 0.557368, 0.0], [0.3023, -0.002585, 0.572759, 1.0]], [1, [17.7, 0.043018, 0.0], [3.854, 0.228913, 0.0], [1.046, 0.508728, 0.0], [0.2753, 0.460531, 1.0]], [2, [1.185, 1.0]]]}
# 8        O    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -138.651703777101
# E(CCSD) = -138.8963285454039  E_corr = -0.2446247683026147
# CCSD(T) correction = -0.00560694879911968
# ENERGY Computing using CCSD T appoach is = -138.901935494203
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -139.284175755496
# SCF not converged.
# SCF energy = -139.283486719217
# SCF not converged.
# SCF energy = -139.337208655555
# SCF not converged.
# SCF energy = -139.180666926587
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -139.327792465375
# ************************************##############################################*############################### 5
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7fe3c75d6990>
# In Bohr
# [[ 0.         0.         0.4681367]
#  [ 0.         0.        -0.4681367]]
# In angstrom
# [[ 0.          0.          0.24772727]
#  [ 0.          0.         -0.24772727]]
# [['O', (0, 0, 0.24772727272727274)], ['O', (0, 0, -0.24772727272727274)]]
# [[ 0.         0.         0.4681367]
#  [ 0.         0.        -0.4681367]]
# {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], [1759.0, 0.00547, -0.001263, 0.0], [400.8, 0.027837, -0.006267, 0.0], [113.7, 0.1048, -0.025716, 0.0], [37.03, 0.283062, -0.070924, 0.0], [13.27, 0.448719, -0.165411, 0.0], [5.025, 0.270952, -0.116955, 0.0], [1.013, 0.015458, 0.557368, 0.0], [0.3023, -0.002585, 0.572759, 1.0]], [1, [17.7, 0.043018, 0.0], [3.854, 0.228913, 0.0], [1.046, 0.508728, 0.0], [0.2753, 0.460531, 1.0]], [2, [1.185, 1.0]]]}
# 8        O    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -142.370178378205
# E(CCSD) = -142.6210996639202  E_corr = -0.2509212857147704
# CCSD(T) correction = -0.00474186666994654
# ENERGY Computing using CCSD T appoach is = -142.62584153059012
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -142.989331504
# SCF not converged.
# SCF energy = -142.987177350895
# SCF not converged.
# SCF energy = -143.048449311013
# SCF not converged.
# SCF energy = -142.885492100258
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -143.031205075995
# ************************************##############################################*############################### 6
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7fe34a14f550>
# In Bohr
# [[ 0.          0.          0.52396952]
#  [ 0.          0.         -0.52396952]]
# In angstrom
# [[ 0.          0.          0.27727273]
#  [ 0.          0.         -0.27727273]]
# [['O', (0, 0, 0.2772727272727273)], ['O', (0, 0, -0.2772727272727273)]]
# [[ 0.          0.          0.52396952]
#  [ 0.          0.         -0.52396952]]
# {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], [1759.0, 0.00547, -0.001263, 0.0], [400.8, 0.027837, -0.006267, 0.0], [113.7, 0.1048, -0.025716, 0.0], [37.03, 0.283062, -0.070924, 0.0], [13.27, 0.448719, -0.165411, 0.0], [5.025, 0.270952, -0.116955, 0.0], [1.013, 0.015458, 0.557368, 0.0], [0.3023, -0.002585, 0.572759, 1.0]], [1, [17.7, 0.043018, 0.0], [3.854, 0.228913, 0.0], [1.046, 0.508728, 0.0], [0.2753, 0.460531, 1.0]], [2, [1.185, 1.0]]]}
# 8        O    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -144.822958892508
# E(CCSD) = -145.0850994384735  E_corr = -0.2621405459650895
# CCSD(T) correction = -0.00474221452512028
# ENERGY Computing using CCSD T appoach is = -145.08984165299864
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -145.433541054751
# SCF not converged.
# SCF energy = -145.432527158603
# SCF not converged.
# SCF energy = -145.498656694083
# SCF not converged.
# SCF energy = -145.330548189036
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -145.469750422741
# ************************************##############################################*############################### 7
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7fe3c7a156d0>
# In Bohr
# [[ 0.          0.          0.57980233]
#  [ 0.          0.         -0.57980233]]
# In angstrom
# [[ 0.          0.          0.30681818]
#  [ 0.          0.         -0.30681818]]
# [['O', (0, 0, 0.3068181818181818)], ['O', (0, 0, -0.3068181818181818)]]
# [[ 0.          0.          0.57980233]
#  [ 0.          0.         -0.57980233]]
# {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], [1759.0, 0.00547, -0.001263, 0.0], [400.8, 0.027837, -0.006267, 0.0], [113.7, 0.1048, -0.025716, 0.0], [37.03, 0.283062, -0.070924, 0.0], [13.27, 0.448719, -0.165411, 0.0], [5.025, 0.270952, -0.116955, 0.0], [1.013, 0.015458, 0.557368, 0.0], [0.3023, -0.002585, 0.572759, 1.0]], [1, [17.7, 0.043018, 0.0], [3.854, 0.228913, 0.0], [1.046, 0.508728, 0.0], [0.2753, 0.460531, 1.0]], [2, [1.185, 1.0]]]}
# 8        O    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -146.454272376467
# E(CCSD) = -146.728445370089  E_corr = -0.2741729936221682
# CCSD(T) correction = -0.0049443923917432
# ENERGY Computing using CCSD T appoach is = -146.73338976248078
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -147.060015432728
# SCF not converged.
# SCF energy = -147.059741311743
# SCF not converged.
# SCF energy = -147.13042210607
# SCF not converged.
# SCF energy = -146.958340310852
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -147.077749594279
# ************************************##############################################*############################### 8
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7fe3cfa83f10>
# In Bohr
# [[ 0.          0.          0.63563515]
#  [ 0.          0.         -0.63563515]]
# In angstrom
# [[ 0.          0.          0.33636364]
#  [ 0.          0.         -0.33636364]]
# [['O', (0, 0, 0.33636363636363636)], ['O', (0, 0, -0.33636363636363636)]]
# [[ 0.          0.          0.63563515]
#  [ 0.          0.         -0.63563515]]
# {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], [1759.0, 0.00547, -0.001263, 0.0], [400.8, 0.027837, -0.006267, 0.0], [113.7, 0.1048, -0.025716, 0.0], [37.03, 0.283062, -0.070924, 0.0], [13.27, 0.448719, -0.165411, 0.0], [5.025, 0.270952, -0.116955, 0.0], [1.013, 0.015458, 0.557368, 0.0], [0.3023, -0.002585, 0.572759, 1.0]], [1, [17.7, 0.043018, 0.0], [3.854, 0.228913, 0.0], [1.046, 0.508728, 0.0], [0.2753, 0.460531, 1.0]], [2, [1.185, 1.0]]]}
# 8        O    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -147.546477863901
# E(CCSD) = -147.8321712067811  E_corr = -0.285693342880162
# CCSD(T) correction = -0.00524601955408201
# ENERGY Computing using CCSD T appoach is = -147.83741722633522
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -148.150307148056
# SCF not converged.
# SCF energy = -148.150608959425
# SCF not converged.
# SCF energy = -148.225141713676
# SCF not converged.
# SCF energy = -148.05026603147
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -148.168020773146
# ************************************##############################################*############################### 9
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7fe3d2605e90>
# In Bohr
# [[ 0.          0.          0.69146797]
#  [ 0.          0.         -0.69146797]]
# In angstrom
# [[ 0.          0.          0.36590909]
#  [ 0.          0.         -0.36590909]]
# [['O', (0, 0, 0.36590909090909096)], ['O', (0, 0, -0.36590909090909096)]]
# [[ 0.          0.          0.69146797]
#  [ 0.          0.         -0.69146797]]
# {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], [1759.0, 0.00547, -0.001263, 0.0], [400.8, 0.027837, -0.006267, 0.0], [113.7, 0.1048, -0.025716, 0.0], [37.03, 0.283062, -0.070924, 0.0], [13.27, 0.448719, -0.165411, 0.0], [5.025, 0.270952, -0.116955, 0.0], [1.013, 0.015458, 0.557368, 0.0], [0.3023, -0.002585, 0.572759, 1.0]], [1, [17.7, 0.043018, 0.0], [3.854, 0.228913, 0.0], [1.046, 0.508728, 0.0], [0.2753, 0.460531, 1.0]], [2, [1.185, 1.0]]]}
# 8        O    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -148.278927214322
# E(CCSD) = -148.5753486412897  E_corr = -0.2964214269680067
# CCSD(T) correction = -0.00563764853376613
# ENERGY Computing using CCSD T appoach is = -148.58098628982341
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -148.883306229287
# SCF not converged.
# SCF energy = -148.883371663759
# SCF not converged.
# SCF energy = -148.9616800681
# SCF not converged.
# SCF energy = -148.785007396542
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -148.907197987378
# ************************************##############################################*############################### 10
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7fe3c7482fd0>
# In Bohr
# [[ 0.          0.          0.74730079]
#  [ 0.          0.         -0.74730079]]
# In angstrom
# [[ 0.          0.          0.39545455]
#  [ 0.          0.         -0.39545455]]
# [['O', (0, 0, 0.3954545454545455)], ['O', (0, 0, -0.3954545454545455)]]
# [[ 0.          0.          0.74730079]
#  [ 0.          0.         -0.74730079]]
# {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], [1759.0, 0.00547, -0.001263, 0.0], [400.8, 0.027837, -0.006267, 0.0], [113.7, 0.1048, -0.025716, 0.0], [37.03, 0.283062, -0.070924, 0.0], [13.27, 0.448719, -0.165411, 0.0], [5.025, 0.270952, -0.116955, 0.0], [1.013, 0.015458, 0.557368, 0.0], [0.3023, -0.002585, 0.572759, 1.0]], [1, [17.7, 0.043018, 0.0], [3.854, 0.228913, 0.0], [1.046, 0.508728, 0.0], [0.2753, 0.460531, 1.0]], [2, [1.185, 1.0]]]}
# 8        O    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -148.767474019065
# E(CCSD) = -149.0741324195665  E_corr = -0.3066584005013733
# CCSD(T) correction = -0.00609900893571439
# ENERGY Computing using CCSD T appoach is = -149.08023142850223
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -149.374650215692
# SCF not converged.
# SCF energy = -149.374665130796
# SCF not converged.
# SCF energy = -149.455669171454
# SCF not converged.
# SCF energy = -149.278228142092
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -149.398536031119
# ************************************##############################################*############################### 11
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7fe3c7041c50>
# In Bohr
# [[ 0.         0.         0.8031336]
#  [ 0.         0.        -0.8031336]]
# In angstrom
# [[ 0.     0.     0.425]
#  [ 0.     0.    -0.425]]
# [['O', (0, 0, 0.42500000000000004)], ['O', (0, 0, -0.42500000000000004)]]
# [[ 0.         0.         0.8031336]
#  [ 0.         0.        -0.8031336]]
# {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], [1759.0, 0.00547, -0.001263, 0.0], [400.8, 0.027837, -0.006267, 0.0], [113.7, 0.1048, -0.025716, 0.0], [37.03, 0.283062, -0.070924, 0.0], [13.27, 0.448719, -0.165411, 0.0], [5.025, 0.270952, -0.116955, 0.0], [1.013, 0.015458, 0.557368, 0.0], [0.3023, -0.002585, 0.572759, 1.0]], [1, [17.7, 0.043018, 0.0], [3.854, 0.228913, 0.0], [1.046, 0.508728, 0.0], [0.2753, 0.460531, 1.0]], [2, [1.185, 1.0]]]}
# 8        O    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -149.089014312924
# E(CCSD) = -149.4057005180836  E_corr = -0.3166862051600225
# CCSD(T) correction = -0.0066529572854095
# ENERGY Computing using CCSD T appoach is = -149.41235347536903
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -149.700939888741
# SCF not converged.
# SCF energy = -149.70084105473
# SCF not converged.
# SCF energy = -149.783796747682
# SCF not converged.
# SCF energy = -149.606530985145
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -149.722828061713
# ************************************##############################################*############################### 12
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7fe3347504d0>
# In Bohr
# [[ 0.          0.          0.85896642]
#  [ 0.          0.         -0.85896642]]
# In angstrom
# [[ 0.          0.          0.45454545]
#  [ 0.          0.         -0.45454545]]
# [['O', (0, 0, 0.4545454545454546)], ['O', (0, 0, -0.4545454545454546)]]
# [[ 0.          0.          0.85896642]
#  [ 0.          0.         -0.85896642]]
# {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], [1759.0, 0.00547, -0.001263, 0.0], [400.8, 0.027837, -0.006267, 0.0], [113.7, 0.1048, -0.025716, 0.0], [37.03, 0.283062, -0.070924, 0.0], [13.27, 0.448719, -0.165411, 0.0], [5.025, 0.270952, -0.116955, 0.0], [1.013, 0.015458, 0.557368, 0.0], [0.3023, -0.002585, 0.572759, 1.0]], [1, [17.7, 0.043018, 0.0], [3.854, 0.228913, 0.0], [1.046, 0.508728, 0.0], [0.2753, 0.460531, 1.0]], [2, [1.185, 1.0]]]}
# 8        O    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -149.295764830329
# E(CCSD) = -149.6225343863323  E_corr = -0.3267695560033139
# CCSD(T) correction = -0.00732912444224007
# ENERGY Computing using CCSD T appoach is = -149.62986351077453
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -149.914161215104
# SCF not converged.
# SCF energy = -149.914400064477
# SCF not converged.
# SCF energy = -149.99809006364
# SCF not converged.
# SCF energy = -149.821851601482
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -149.929862488431
# ************************************##############################################*############################### 13
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7fe3b05e52d0>
# In Bohr
# [[ 0.          0.          0.91479924]
#  [ 0.          0.         -0.91479924]]
# In angstrom
# [[ 0.          0.          0.48409091]
#  [ 0.          0.         -0.48409091]]
# [['O', (0, 0, 0.4840909090909091)], ['O', (0, 0, -0.4840909090909091)]]
# [[ 0.          0.          0.91479924]
#  [ 0.          0.         -0.91479924]]
# {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], [1759.0, 0.00547, -0.001263, 0.0], [400.8, 0.027837, -0.006267, 0.0], [113.7, 0.1048, -0.025716, 0.0], [37.03, 0.283062, -0.070924, 0.0], [13.27, 0.448719, -0.165411, 0.0], [5.025, 0.270952, -0.116955, 0.0], [1.013, 0.015458, 0.557368, 0.0], [0.3023, -0.002585, 0.572759, 1.0]], [1, [17.7, 0.043018, 0.0], [3.854, 0.228913, 0.0], [1.046, 0.508728, 0.0], [0.2753, 0.460531, 1.0]], [2, [1.185, 1.0]]]}
# 8        O    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -149.423693019726
# E(CCSD) = -149.7608058258257  E_corr = -0.3371128060998616
# CCSD(T) correction = -0.00816125541478496
# ENERGY Computing using CCSD T appoach is = -149.76896708124053
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -150.049987965886
# SCF not converged.
# SCF energy = -150.050699541585
# SCF not converged.
# SCF energy = -150.13432915962
# SCF not converged.
# SCF energy = -149.959935843028
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -150.05777883526
# ************************************##############################################*############################### 14
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7fe3c7a50250>
# In Bohr
# [[ 0.          0.          0.97063205]
#  [ 0.          0.         -0.97063205]]
# In angstrom
# [[ 0.          0.          0.51363636]
#  [ 0.          0.         -0.51363636]]
# [['O', (0, 0, 0.5136363636363637)], ['O', (0, 0, -0.5136363636363637)]]
# [[ 0.          0.          0.97063205]
#  [ 0.          0.         -0.97063205]]
# {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], [1759.0, 0.00547, -0.001263, 0.0], [400.8, 0.027837, -0.006267, 0.0], [113.7, 0.1048, -0.025716, 0.0], [37.03, 0.283062, -0.070924, 0.0], [13.27, 0.448719, -0.165411, 0.0], [5.025, 0.270952, -0.116955, 0.0], [1.013, 0.015458, 0.557368, 0.0], [0.3023, -0.002585, 0.572759, 1.0]], [1, [17.7, 0.043018, 0.0], [3.854, 0.228913, 0.0], [1.046, 0.508728, 0.0], [0.2753, 0.460531, 1.0]], [2, [1.185, 1.0]]]}
# 8        O    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -149.497684887207
# E(CCSD) = -149.8455271939063  E_corr = -0.3478423066993307
# CCSD(T) correction = -0.00919095833456605
# ENERGY Computing using CCSD T appoach is = -149.85471815224082
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -150.13306397277
# SCF not converged.
# SCF energy = -150.134215554722
# SCF not converged.
# SCF energy = -150.217210814427
# SCF not converged.
# SCF energy = -150.045355255673
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -150.134338662653
# ************************************##############################################*############################### 15
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7fe3d692ae90>
# In Bohr
# [[ 0.          0.          1.02646487]
#  [ 0.          0.         -1.02646487]]
# In angstrom
# [[ 0.          0.          0.54318182]
#  [ 0.          0.         -0.54318182]]
# [['O', (0, 0, 0.5431818181818182)], ['O', (0, 0, -0.5431818181818182)]]
# [[ 0.          0.          1.02646487]
#  [ 0.          0.         -1.02646487]]
# {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], [1759.0, 0.00547, -0.001263, 0.0], [400.8, 0.027837, -0.006267, 0.0], [113.7, 0.1048, -0.025716, 0.0], [37.03, 0.283062, -0.070924, 0.0], [13.27, 0.448719, -0.165411, 0.0], [5.025, 0.270952, -0.116955, 0.0], [1.013, 0.015458, 0.557368, 0.0], [0.3023, -0.002585, 0.572759, 1.0]], [1, [17.7, 0.043018, 0.0], [3.854, 0.228913, 0.0], [1.046, 0.508728, 0.0], [0.2753, 0.460531, 1.0]], [2, [1.185, 1.0]]]}
# 8        O    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -149.534953960654
# E(CCSD) = -149.8939811832473  E_corr = -0.3590272225931761
# CCSD(T) correction = -0.0104545297376942
# ENERGY Computing using CCSD T appoach is = -149.90443571298505
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -150.180355576377
# SCF not converged.
# SCF energy = -150.182017916071
# SCF not converged.
# SCF energy = -150.263753172888
# SCF not converged.
# SCF energy = -150.095069493232
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -150.178168407807
# ************************************##############################################*############################### 16
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7fe3b0041950>
# In Bohr
# [[ 0.          0.          1.08229769]
#  [ 0.          0.         -1.08229769]]
# In angstrom
# [[ 0.          0.          0.57272727]
#  [ 0.          0.         -0.57272727]]
# [['O', (0, 0, 0.5727272727272728)], ['O', (0, 0, -0.5727272727272728)]]
# [[ 0.          0.          1.08229769]
#  [ 0.          0.         -1.08229769]]
# {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], [1759.0, 0.00547, -0.001263, 0.0], [400.8, 0.027837, -0.006267, 0.0], [113.7, 0.1048, -0.025716, 0.0], [37.03, 0.283062, -0.070924, 0.0], [13.27, 0.448719, -0.165411, 0.0], [5.025, 0.270952, -0.116955, 0.0], [1.013, 0.015458, 0.557368, 0.0], [0.3023, -0.002585, 0.572759, 1.0]], [1, [17.7, 0.043018, 0.0], [3.854, 0.228913, 0.0], [1.046, 0.508728, 0.0], [0.2753, 0.460531, 1.0]], [2, [1.185, 1.0]]]}
# 8        O    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -149.547418771647
# E(CCSD) = -149.91810072095  E_corr = -0.3706819493027141
# CCSD(T) correction = -0.0119812348409082
# ENERGY Computing using CCSD T appoach is = -149.93008195579088
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -150.20352490343
# SCF not converged.
# SCF energy = -150.205822877072
# SCF not converged.
# SCF energy = -150.285685982195
# SCF not converged.
# SCF energy = -150.12071178038
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -150.199974159584
# ************************************##############################################*############################### 17
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7fe3346f4ad0>
# In Bohr
# [[ 0.          0.          1.13813051]
#  [ 0.          0.         -1.13813051]]
# In angstrom
# [[ 0.          0.          0.60227273]
#  [ 0.          0.         -0.60227273]]
# [['O', (0, 0, 0.6022727272727273)], ['O', (0, 0, -0.6022727272727273)]]
# [[ 0.          0.          1.13813051]
#  [ 0.          0.         -1.13813051]]
# {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], [1759.0, 0.00547, -0.001263, 0.0], [400.8, 0.027837, -0.006267, 0.0], [113.7, 0.1048, -0.025716, 0.0], [37.03, 0.283062, -0.070924, 0.0], [13.27, 0.448719, -0.165411, 0.0], [5.025, 0.270952, -0.116955, 0.0], [1.013, 0.015458, 0.557368, 0.0], [0.3023, -0.002585, 0.572759, 1.0]], [1, [17.7, 0.043018, 0.0], [3.854, 0.228913, 0.0], [1.046, 0.508728, 0.0], [0.2753, 0.460531, 1.0]], [2, [1.185, 1.0]]]}
# 8        O    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -149.543350562672
# E(CCSD) = -149.9261234369702  E_corr = -0.3827728742977301
# CCSD(T) correction = -0.0137901742692262
# ENERGY Computing using CCSD T appoach is = -149.93991361123943
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -150.210588631962
# SCF not converged.
# SCF energy = -150.213613697587
# SCF not converged.
# SCF energy = -150.291097156822
# SCF not converged.
# SCF energy = -150.130274531847
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -150.206841829684
# ************************************##############################################*############################### 18
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7fe3d692ae90>
# In Bohr
# [[ 0.          0.          1.19396332]
#  [ 0.          0.         -1.19396332]]
# In angstrom
# [[ 0.          0.          0.63181818]
#  [ 0.          0.         -0.63181818]]
# [['O', (0, 0, 0.6318181818181818)], ['O', (0, 0, -0.6318181818181818)]]
# [[ 0.          0.          1.19396332]
#  [ 0.          0.         -1.19396332]]
# {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], [1759.0, 0.00547, -0.001263, 0.0], [400.8, 0.027837, -0.006267, 0.0], [113.7, 0.1048, -0.025716, 0.0], [37.03, 0.283062, -0.070924, 0.0], [13.27, 0.448719, -0.165411, 0.0], [5.025, 0.270952, -0.116955, 0.0], [1.013, 0.015458, 0.557368, 0.0], [0.3023, -0.002585, 0.572759, 1.0]], [1, [17.7, 0.043018, 0.0], [3.854, 0.228913, 0.0], [1.046, 0.508728, 0.0], [0.2753, 0.460531, 1.0]], [2, [1.185, 1.0]]]}
# 8        O    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -149.528486828852
# E(CCSD) = -149.923725039997  E_corr = -0.3952382111450884
# CCSD(T) correction = -0.0158859859458695
# ENERGY Computing using CCSD T appoach is = -149.9396110259429
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -150.207045557769
# SCF not converged.
# SCF energy = -150.21076302255
# SCF not converged.
# SCF energy = -150.285564294323
# SCF not converged.
# SCF energy = -150.129229862475
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -150.202787387653
# ************************************##############################################*############################### 19
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7fe3b046cd50>
# In Bohr
# [[ 0.          0.          1.24979614]
#  [ 0.          0.         -1.24979614]]
# In angstrom
# [[ 0.          0.          0.66136364]
#  [ 0.          0.         -0.66136364]]
# [['O', (0, 0, 0.6613636363636364)], ['O', (0, 0, -0.6613636363636364)]]
# [[ 0.          0.          1.24979614]
#  [ 0.          0.         -1.24979614]]
# {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], [1759.0, 0.00547, -0.001263, 0.0], [400.8, 0.027837, -0.006267, 0.0], [113.7, 0.1048, -0.025716, 0.0], [37.03, 0.283062, -0.070924, 0.0], [13.27, 0.448719, -0.165411, 0.0], [5.025, 0.270952, -0.116955, 0.0], [1.013, 0.015458, 0.557368, 0.0], [0.3023, -0.002585, 0.572759, 1.0]], [1, [17.7, 0.043018, 0.0], [3.854, 0.228913, 0.0], [1.046, 0.508728, 0.0], [0.2753, 0.460531, 1.0]], [2, [1.185, 1.0]]]}
# 8        O    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -149.506779923677
# E(CCSD) = -149.9147786178785  E_corr = -0.4079986942013157
# CCSD(T) correction = -0.0182651582867374
# ENERGY Computing using CCSD T appoach is = -149.9330437761652
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -150.196642599999
# SCF not converged.
# SCF energy = -150.201131380397
# SCF not converged.
# SCF energy = -150.272910876871
# SCF not converged.
# SCF energy = -150.121308070456
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -150.191043651123
# ************************************##############################################*############################### 20
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7fe441632810>
# In Bohr
# [[ 0.          0.          1.30562896]
#  [ 0.          0.         -1.30562896]]
# In angstrom
# [[ 0.          0.          0.69090909]
#  [ 0.          0.         -0.69090909]]
# [['O', (0, 0, 0.6909090909090909)], ['O', (0, 0, -0.6909090909090909)]]
# [[ 0.          0.          1.30562896]
#  [ 0.          0.         -1.30562896]]
# {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], [1759.0, 0.00547, -0.001263, 0.0], [400.8, 0.027837, -0.006267, 0.0], [113.7, 0.1048, -0.025716, 0.0], [37.03, 0.283062, -0.070924, 0.0], [13.27, 0.448719, -0.165411, 0.0], [5.025, 0.270952, -0.116955, 0.0], [1.013, 0.015458, 0.557368, 0.0], [0.3023, -0.002585, 0.572759, 1.0]], [1, [17.7, 0.043018, 0.0], [3.854, 0.228913, 0.0], [1.046, 0.508728, 0.0], [0.2753, 0.460531, 1.0]], [2, [1.185, 1.0]]]}
# 8        O    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -149.480921890611
# E(CCSD) = -149.9019039764183  E_corr = -0.4209820858074754
# CCSD(T) correction = -0.0209193972442347
# ENERGY Computing using CCSD T appoach is = -149.92282337366248
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -150.181912857248
# SCF not converged.
# SCF energy = -150.187271366715
# SCF not converged.
# SCF energy = -150.255737323504
# SCF not converged.
# SCF energy = -150.109023463179
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -150.174926242694
# ************************************##############################################*############################### 21
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7fe3d229ec90>
# In Bohr
# [[ 0.          0.          1.36146178]
#  [ 0.          0.         -1.36146178]]
# In angstrom
# [[ 0.          0.          0.72045455]
#  [ 0.          0.         -0.72045455]]
# [['O', (0, 0, 0.7204545454545455)], ['O', (0, 0, -0.7204545454545455)]]
# [[ 0.          0.          1.36146178]
#  [ 0.          0.         -1.36146178]]
# {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], [1759.0, 0.00547, -0.001263, 0.0], [400.8, 0.027837, -0.006267, 0.0], [113.7, 0.1048, -0.025716, 0.0], [37.03, 0.283062, -0.070924, 0.0], [13.27, 0.448719, -0.165411, 0.0], [5.025, 0.270952, -0.116955, 0.0], [1.013, 0.015458, 0.557368, 0.0], [0.3023, -0.002585, 0.572759, 1.0]], [1, [17.7, 0.043018, 0.0], [3.854, 0.228913, 0.0], [1.046, 0.508728, 0.0], [0.2753, 0.460531, 1.0]], [2, [1.185, 1.0]]]}
# 8        O    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ...
# <pyscf.gto.mole.Mole object at 0x7fe3b021f290>
# In Bohr
# [[ 0.          0.          2.31061967]
#  [ 0.          0.         -2.31061967]]
# In angstrom
# [[ 0.          0.          1.22272727]
#  [ 0.          0.         -1.22272727]]
# [['O', (0, 0, 1.2227272727272729)], ['O', (0, 0, -1.2227272727272729)]]
# [[ 0.          0.          2.31061967]
#  [ 0.          0.         -2.31061967]]
# {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], [1759.0, 0.00547, -0.001263, 0.0], [400.8, 0.027837, -0.006267, 0.0], [113.7, 0.1048, -0.025716, 0.0], [37.03, 0.283062, -0.070924, 0.0], [13.27, 0.448719, -0.165411, 0.0], [5.025, 0.270952, -0.116955, 0.0], [1.013, 0.015458, 0.557368, 0.0], [0.3023, -0.002585, 0.572759, 1.0]], [1, [17.7, 0.043018, 0.0], [3.854, 0.228913, 0.0], [1.046, 0.508728, 0.0], [0.2753, 0.460531, 1.0]], [2, [1.185, 1.0]]]}
# 8        O    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -149.064265972636
# E(CCSD) = -149.7603384070583  E_corr = -0.6960724344226032
# CCSD(T) correction = -0.144575151144069
# ENERGY Computing using CCSD T appoach is = -149.90491355820234
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -149.910687403038
# SCF not converged.
# SCF energy = -149.932831487589
# SCF not converged.
# SCF energy = -149.933770234761
# SCF not converged.
# SCF energy = -149.872365430082
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -149.893662992082
# ************************************##############################################*############################### 39
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7fe3b0658490>
# In Bohr
# [[ 0.          0.          2.36645249]
#  [ 0.          0.         -2.36645249]]
# In angstrom
# [[ 0.          0.          1.25227273]
#  [ 0.          0.         -1.25227273]]
# [['O', (0, 0, 1.2522727272727274)], ['O', (0, 0, -1.2522727272727274)]]
# [[ 0.          0.          2.36645249]
#  [ 0.          0.         -2.36645249]]
# {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], [1759.0, 0.00547, -0.001263, 0.0], [400.8, 0.027837, -0.006267, 0.0], [113.7, 0.1048, -0.025716, 0.0], [37.03, 0.283062, -0.070924, 0.0], [13.27, 0.448719, -0.165411, 0.0], [5.025, 0.270952, -0.116955, 0.0], [1.013, 0.015458, 0.557368, 0.0], [0.3023, -0.002585, 0.572759, 1.0]], [1, [17.7, 0.043018, 0.0], [3.854, 0.228913, 0.0], [1.046, 0.508728, 0.0], [0.2753, 0.460531, 1.0]], [2, [1.185, 1.0]]]}
# 8        O    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -149.050616093376
# E(CCSD) = -149.7604429441023  E_corr = -0.7098268507261208
# CCSD(T) correction = -0.152680154893592
# ENERGY Computing using CCSD T appoach is = -149.91312309899592
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -149.902659969659
# SCF not converged.
# SCF energy = -149.92566457376
# SCF not converged.
# SCF energy = -149.92294145231
# SCF not converged.
# SCF energy = -149.865729053877
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -149.884634810712
# ************************************##############################################*############################### 40
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7fe444807750>
# In Bohr
# [[ 0.          0.          2.42228531]
#  [ 0.          0.         -2.42228531]]
# In angstrom
# [[ 0.          0.          1.28181818]
#  [ 0.          0.         -1.28181818]]
# [['O', (0, 0, 1.281818181818182)], ['O', (0, 0, -1.281818181818182)]]
# [[ 0.          0.          2.42228531]
#  [ 0.          0.         -2.42228531]]
# {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], [1759.0, 0.00547, -0.001263, 0.0], [400.8, 0.027837, -0.006267, 0.0], [113.7, 0.1048, -0.025716, 0.0], [37.03, 0.283062, -0.070924, 0.0], [13.27, 0.448719, -0.165411, 0.0], [5.025, 0.270952, -0.116955, 0.0], [1.013, 0.015458, 0.557368, 0.0], [0.3023, -0.002585, 0.572759, 1.0]], [1, [17.7, 0.043018, 0.0], [3.854, 0.228913, 0.0], [1.046, 0.508728, 0.0], [0.2753, 0.460531, 1.0]], [2, [1.185, 1.0]]]}
# 8        O    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -149.037782276882
# CCSD not converged
# E(CCSD) = -149.4638558531322  E_corr = -0.4260735762504959
# CCSD(T) correction = -0.0628946960194902
# ENERGY Computing using CCSD T appoach is = -149.52675054915173
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -149.89524045969
# SCF not converged.
# SCF energy = -149.919113207875
# SCF not converged.
# SCF energy = -149.912741359008
# SCF not converged.
# SCF energy = -149.859644785799
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -149.876207173534
# ************************************##############################################*############################### 41
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7fe3b0567f90>
# In Bohr
# [[ 0.          0.          2.47811812]
#  [ 0.          0.         -2.47811812]]
# In angstrom
# [[ 0.          0.          1.31136364]
#  [ 0.          0.         -1.31136364]]
# [['O', (0, 0, 1.3113636363636365)], ['O', (0, 0, -1.3113636363636365)]]
# [[ 0.          0.          2.47811812]
#  [ 0.          0.         -2.47811812]]
# {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], [1759.0, 0.00547, -0.001263, 0.0], [400.8, 0.027837, -0.006267, 0.0], [113.7, 0.1048, -0.025716, 0.0], [37.03, 0.283062, -0.070924, 0.0], [13.27, 0.448719, -0.165411, 0.0], [5.025, 0.270952, -0.116955, 0.0], [1.013, 0.015458, 0.557368, 0.0], [0.3023, -0.002585, 0.572759, 1.0]], [1, [17.7, 0.043018, 0.0], [3.854, 0.228913, 0.0], [1.046, 0.508728, 0.0], [0.2753, 0.460531, 1.0]], [2, [1.185, 1.0]]]}
# 8        O    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -149.025718880092
# CCSD not converged
# E(CCSD) = -149.5742199439032  E_corr = -0.5485010638110883
# CCSD(T) correction = -0.128112347371104
# ENERGY Computing using CCSD T appoach is = -149.7023322912743
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -149.888391486902
# SCF not converged.
# SCF energy = -149.913133457147
# SCF not converged.
# SCF energy = -149.903135462375
# SCF not converged.
# SCF energy = -149.854081776977
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -149.868360063043
# ************************************##############################################*############################### 42
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7fe3c6d41690>
# In Bohr
# [[ 0.          0.          2.53395094]
#  [ 0.          0.         -2.53395094]]
# In angstrom
# [[ 0.          0.          1.34090909]
#  [ 0.          0.         -1.34090909]]
# [['O', (0, 0, 1.340909090909091)], ['O', (0, 0, -1.340909090909091)]]
# [[ 0.          0.          2.53395094]
#  [ 0.          0.         -2.53395094]]
# {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], [1759.0, 0.00547, -0.001263, 0.0], [400.8, 0.027837, -0.006267, 0.0], [113.7, 0.1048, -0.025716, 0.0], [37.03, 0.283062, -0.070924, 0.0], [13.27, 0.448719, -0.165411, 0.0], [5.025, 0.270952, -0.116955, 0.0], [1.013, 0.015458, 0.557368, 0.0], [0.3023, -0.002585, 0.572759, 1.0]], [1, [17.7, 0.043018, 0.0], [3.854, 0.228913, 0.0], [1.046, 0.508728, 0.0], [0.2753, 0.460531, 1.0]], [2, [1.185, 1.0]]]}
# 8        O    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -149.014382113721
# E(CCSD) = -149.7611479425865  E_corr = -0.7467658288658158
# CCSD(T) correction = -0.173697026673101
# ENERGY Computing using CCSD T appoach is = -149.9348449692596
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -149.882077070313
# SCF not converged.
# SCF energy = -149.907685916299
# SCF not converged.
# SCF energy = -149.894091191942
# SCF not converged.
# SCF energy = -149.849006885743
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -149.861041966673
# ************************************##############################################*############################### 43
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7fe3d2fa7810>
# In Bohr
# [[ 0.          0.          2.58978376]
#  [ 0.          0.         -2.58978376]]
# In angstrom
# [[ 0.          0.          1.37045455]
#  [ 0.          0.         -1.37045455]]
# [['O', (0, 0, 1.3704545454545456)], ['O', (0, 0, -1.3704545454545456)]]
# [[ 0.          0.          2.58978376]
#  [ 0.          0.         -2.58978376]]
# {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], [1759.0, 0.00547, -0.001263, 0.0], [400.8, 0.027837, -0.006267, 0.0], [113.7, 0.1048, -0.025716, 0.0], [37.03, 0.283062, -0.070924, 0.0], [13.27, 0.448719, -0.165411, 0.0], [5.025, 0.270952, -0.116955, 0.0], [1.013, 0.015458, 0.557368, 0.0], [0.3023, -0.002585, 0.572759, 1.0]], [1, [17.7, 0.043018, 0.0], [3.854, 0.228913, 0.0], [1.046, 0.508728, 0.0], [0.2753, 0.460531, 1.0]], [2, [1.185, 1.0]]]}
# 8        O    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -149.003730146456
# CCSD not converged
# E(CCSD) = -149.4292159949344  E_corr = -0.42548584847787
# CCSD(T) correction = -0.136907777306672
# ENERGY Computing using CCSD T appoach is = -149.56612377224107
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -149.876260984335
# SCF not converged.
# SCF energy = -149.902728176935
# SCF not converged.
# SCF energy = -149.885576287725
# SCF not converged.
# SCF energy = -149.73420105871
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -149.854221505276
# ************************************##############################################*############################### 44
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7fe3b00e2390>
# In Bohr
# [[ 0.          0.          2.64561657]
#  [ 0.          0.         -2.64561657]]
# In angstrom
# [[ 0.   0.   1.4]
#  [ 0.   0.  -1.4]]
# [['O', (0, 0, 1.4000000000000001)], ['O', (0, 0, -1.4000000000000001)]]
# [[ 0.          0.          2.64561657]
#  [ 0.          0.         -2.64561657]]
# {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], [1759.0, 0.00547, -0.001263, 0.0], [400.8, 0.027837, -0.006267, 0.0], [113.7, 0.1048, -0.025716, 0.0], [37.03, 0.283062, -0.070924, 0.0], [13.27, 0.448719, -0.165411, 0.0], [5.025, 0.270952, -0.116955, 0.0], [1.013, 0.015458, 0.557368, 0.0], [0.3023, -0.002585, 0.572759, 1.0]], [1, [17.7, 0.043018, 0.0], [3.854, 0.228913, 0.0], [1.046, 0.508728, 0.0], [0.2753, 0.460531, 1.0]], [2, [1.185, 1.0]]]}
# 8        O    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -148.993722898618
# CCSD not converged
# E(CCSD) = -149.7015839588367  E_corr = -0.7078610602186317
# CCSD(T) correction = -0.236524801766635
# ENERGY Computing using CCSD T appoach is = -149.9381087606033
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -149.870907928065
# SCF not converged.
# SCF energy = -149.898224149355
# SCF not converged.
# SCF energy = -149.877559427884
# SCF not converged.
# SCF energy = -149.735117773493
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -149.847879196157

# %%
df
# Out:
#    Weight Element                                           Molecule BasisSet  \
# 0       8       O  [[O, (0, 0, 0.12954545454545455)], [O, (0, 0, ...  cc-pVDZ
# 1       8       O  [[O, (0, 0, 0.1590909090909091)], [O, (0, 0, -...  cc-pVDZ
# 2       8       O  [[O, (0, 0, 0.18863636363636366)], [O, (0, 0, ...  cc-pVDZ
# 3       8       O  [[O, (0, 0, 0.2181818181818182)], [O, (0, 0, -...  cc-pVDZ
# 4       8       O  [[O, (0, 0, 0.24772727272727274)], [O, (0, 0, ...  cc-pVDZ
# 5       8       O  [[O, (0, 0, 0.2772727272727273)], [O, (0, 0, -...  cc-pVDZ
# 6       8       O  [[O, (0, 0, 0.3068181818181818)], [O, (0, 0, -...  cc-pVDZ
# 7       8       O  [[O, (0, 0, 0.33636363636363636)], [O, (0, 0, ...  cc-pVDZ
# 8       8       O  [[O, (0, 0, 0.36590909090909096)], [O, (0, 0, ...  cc-pVDZ
# 9       8       O  [[O, (0, 0, 0.3954545454545455)], [O, (0, 0, -...  cc-pVDZ
# 10      8       O  [[O, (0, 0, 0.42500000000000004)], [O, (0, 0, ...  cc-pVDZ
# 11      8       O  [[O, (0, 0, 0.4545454545454546)], [O, (0, 0, -...  cc-pVDZ
# 12      8       O  [[O, (0, 0, 0.4840909090909091)], [O, (0, 0, -...  cc-pVDZ
# 13      8       O  [[O, (0, 0, 0.5136363636363637)], [O, (0, 0, -...  cc-pVDZ
# 14      8       O  [[O, (0, 0, 0.5431818181818182)], [O, (0, 0, -...  cc-pVDZ
# 15      8       O  [[O, (0, 0, 0.5727272727272728)], [O, (0, 0, -...  cc-pVDZ
# 16      8       O  [[O, (0, 0, 0.6022727272727273)], [O, (0, 0, -...  cc-pVDZ
# 17      8       O  [[O, (0, 0, 0.6318181818181818)], [O, (0, 0, -...  cc-pVDZ
# 18      8       O  [[O, (0, 0, 0.6613636363636364)], [O, (0, 0, -...  cc-pVDZ
# 19      8       O  [[O, (0, 0, 0.6909090909090909)], [O, (0, 0, -...  cc-pVDZ
# 20      8       O  [[O, (0, 0, 0.7204545454545455)], [O, (0, 0, -...  cc-pVDZ
# 21      8       O            [[O, (0, 0, 0.75)], [O, (0, 0, -0.75)]]  cc-pVDZ
# 22      8       O  [[O, (0, 0, 0.7795454545454545)], [O, (0, 0, -...  cc-pVDZ
# 23      8       O  [[O, (0, 0, 0.8090909090909091)], [O, (0, 0, -...  cc-pVDZ
# 24      8       O  [[O, (0, 0, 0.8386363636363636)], [O, (0, 0, -...  cc-pVDZ
# 25      8       O  [[O, (0, 0, 0.8681818181818182)], [O, (0, 0, -...  cc-pVDZ
# 26      8       O  [[O, (0, 0, 0.8977272727272727)], [O, (0, 0, -...  cc-pVDZ
# 27      8       O  [[O, (0, 0, 0.9272727272727272)], [O, (0, 0, -...  cc-pVDZ
# 28      8       O  [[O, (0, 0, 0.9568181818181818)], [O, (0, 0, -...  cc-pVDZ
# 29      8       O  [[O, (0, 0, 0.9863636363636363)], [O, (0, 0, -...  cc-pVDZ
# 30      8       O  [[O, (0, 0, 1.0159090909090909)], [O, (0, 0, -...  cc-pVDZ
# 31      8       O  [[O, (0, 0, 1.0454545454545454)], [O, (0, 0, -...  cc-pVDZ
# 32      8       O          [[O, (0, 0, 1.075)], [O, (0, 0, -1.075)]]  cc-pVDZ
# 33      8       O  [[O, (0, 0, 1.1045454545454547)], [O, (0, 0, -...  cc-pVDZ
# 34      8       O  [[O, (0, 0, 1.1340909090909093)], [O, (0, 0, -...  cc-pVDZ
# 35      8       O  [[O, (0, 0, 1.1636363636363638)], [O, (0, 0, -...  cc-pVDZ
# 36      8       O  [[O, (0, 0, 1.1931818181818183)], [O, (0, 0, -...  cc-pVDZ
# 37      8       O  [[O, (0, 0, 1.2227272727272729)], [O, (0, 0, -...  cc-pVDZ
# 38      8       O  [[O, (0, 0, 1.2522727272727274)], [O, (0, 0, -...  cc-pVDZ
# 39      8       O  [[O, (0, 0, 1.281818181818182)], [O, (0, 0, -1...  cc-pVDZ
# 40      8       O  [[O, (0, 0, 1.3113636363636365)], [O, (0, 0, -...  cc-pVDZ
# 41      8       O  [[O, (0, 0, 1.340909090909091)], [O, (0, 0, -1...  cc-pVDZ
# 42      8       O  [[O, (0, 0, 1.3704545454545456)], [O, (0, 0, -...  cc-pVDZ
# 43      8       O  [[O, (0, 0, 1.4000000000000001)], [O, (0, 0, -...  cc-pVDZ
#
#    Spin                                      BuiltMolecule  bond_lenght  \
# 0     0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     0.259091
# 1     0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     0.318182
# 2     0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     0.377273
# 3     0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     0.436364
# 4     0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     0.495455
# 5     0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     0.554545
# 6     0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     0.613636
# 7     0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     0.672727
# 8     0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     0.731818
# 9     0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     0.790909
# 10    0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     0.850000
# 11    0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     0.909091
# 12    0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     0.968182
# 13    0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     1.027273
# 14    0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     1.086364
# 15    0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     1.145455
# 16    0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     1.204545
# 17    0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     1.263636
# 18    0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     1.322727
# 19    0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     1.381818
# 20    0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     1.440909
# 21    0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     1.500000
# 22    0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     1.559091
# 23    0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     1.618182
# 24    0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     1.677273
# 25    0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     1.736364
# 26    0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     1.795455
# 27    0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     1.854545
# 28    0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     1.913636
# 29    0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     1.972727
# 30    0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     2.031818
# 31    0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     2.090909
# 32    0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     2.150000
# 33    0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     2.209091
# 34    0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     2.268182
# 35    0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     2.327273
# 36    0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     2.386364
# 37    0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     2.445455
# 38    0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     2.504545
# 39    0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     2.563636
# 40    0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     2.622727
# 41    0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     2.681818
# 42    0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     2.740909
# 43    0  {'O': [[0, [11720.0, 0.00071, -0.00016, 0.0], ...     2.800000
#
#          CCSDT   DFT-b3lyp    DFT-SCAN  DFT-wB97X-V     DFT-pbe  \
# 0  -111.073731 -111.471197 -111.480127  -111.507334 -111.375396
# 1  -124.718693 -125.143241 -125.138118  -125.180948 -125.046993
# 2  -133.272410 -133.664704 -133.632257  -133.678643 -133.565676
# 3  -138.901935 -139.284176 -139.283487  -139.337209 -139.180667
# 4  -142.625842 -142.989332 -142.987177  -143.048449 -142.885492
# 5  -145.089842 -145.433541 -145.432527  -145.498657 -145.330548
# 6  -146.733390 -147.060015 -147.059741  -147.130422 -146.958340
# 7  -147.837417 -148.150307 -148.150609  -148.225142 -148.050266
# 8  -148.580986 -148.883306 -148.883372  -148.961680 -148.785007
# 9  -149.080231 -149.374650 -149.374665  -149.455669 -149.278228
# 10 -149.412353 -149.700940 -149.700841  -149.783797 -149.606531
# 11 -149.629864 -149.914161 -149.914400  -149.998090 -149.821852
# 12 -149.768967 -150.049988 -150.050700  -150.134329 -149.959936
# 13 -149.854718 -150.133064 -150.134216  -150.217211 -150.045355
# 14 -149.904436 -150.180356 -150.182018  -150.263753 -150.095069
# 15 -149.930082 -150.203525 -150.205823  -150.285686 -150.120712
# 16 -149.939914 -150.210589 -150.213614  -150.291097 -150.130275
# 17 -149.939611 -150.207046 -150.210763  -150.285564 -150.129230
# 18 -149.933044 -150.196643 -150.201131  -150.272911 -150.121308
# 19 -149.922823 -150.181913 -150.187271  -150.255737 -150.109023
# 20 -149.910711 -150.164561 -150.170903  -150.235802 -150.094073
# 21 -149.897918 -150.145741 -150.153148  -150.214302 -150.077604
# 22 -149.885318 -150.126249 -150.134763  -150.192064 -150.060406
# 23 -149.873584 -150.106644 -150.116266  -150.169667 -150.043038
# 24 -149.863260 -150.087320 -150.098034  -150.147522 -150.025893
# 25 -149.854805 -150.068549 -150.080291  -150.125910 -150.009243
# 26 -149.848588 -150.050516 -150.063217  -150.105023 -149.993271
# 27 -149.844875 -150.033334 -150.046944  -150.084979 -149.978093
# 28 -149.843784 -150.017069 -150.031551  -150.065846 -149.963773
# 29 -149.845255 -150.001747 -150.017079  -150.047654 -149.950340
# 30 -149.849038 -149.987371 -150.003552  -150.030407 -149.937796
# 31 -149.854735 -149.973924 -149.990950  -150.014090 -149.926124
# 32 -149.861877 -149.961375 -149.979248  -149.998675 -149.915294
# 33 -149.869986 -149.949688 -149.968411  -149.984126 -149.905269
# 34 -149.878645 -149.938819 -149.958397  -149.970401 -149.896005
# 35 -149.887510 -149.928725 -149.949158  -149.957461 -149.887463
# 36 -150.123740 -149.919362 -149.940650  -149.945264 -149.879597
# 37 -149.904914 -149.910687 -149.932831  -149.933770 -149.872365
# 38 -149.913123 -149.902660 -149.925665  -149.922941 -149.865729
# 39 -149.526751 -149.895240 -149.919113  -149.912741 -149.859645
# 40 -149.702332 -149.888391 -149.913133  -149.903135 -149.854082
# 41 -149.934845 -149.882077 -149.907686  -149.894091 -149.849007
# 42 -149.566124 -149.876261 -149.902728  -149.885576 -149.734201
# 43 -149.938109 -149.870908 -149.898224  -149.877559 -149.735118
#
#     NN-Functional.DM21m
# 0           -111.543450
# 1           -125.208716
# 2           -133.679277
# 3           -139.327792
# 4           -143.031205
# 5           -145.469750
# 6           -147.077750
# 7           -148.168021
# 8           -148.907198
# 9           -149.398536
# 10          -149.722828
# 11          -149.929862
# 12          -150.057779
# 13          -150.134339
# 14          -150.178168
# 15          -150.199974
# 16          -150.206842
# 17          -150.202787
# 18          -150.191044
# 19          -150.174926
# 20          -150.156653
# 21          -150.137350
# 22          -150.117648
# 23          -150.097981
# 24          -150.078634
# 25          -150.059698
# 26          -150.041411
# 27          -150.023896
# 28          -150.007221
# 29          -149.991429
# 30          -149.976506
# 31          -149.962398
# 32          -149.949082
# 33          -149.936546
# 34          -149.924759
# 35          -149.913683
# 36          -149.903341
# 37          -149.893663
# 38          -149.884635
# 39          -149.876207
# 40          -149.868360
# 41          -149.861042
# 42          -149.854222
# 43          -149.847879

# %%
df.to_csv('/content/drive/My Drive/DeepMind' + EXPNO+ 'CE-Final-.csv' )

# %%
df2 = df.copy()

# %%
df.drop(columns=['Weight', 'Element', 'Molecule', 'BasisSet', 'Spin','BuiltMolecule'])
# Out:
#     bond_lenght       CCSDT   DFT-b3lyp    DFT-SCAN  DFT-wB97X-V     DFT-pbe  \
# 0      0.259091 -111.073731 -111.471197 -111.480127  -111.507334 -111.375396
# 1      0.318182 -124.718693 -125.143241 -125.138118  -125.180948 -125.046993
# 2      0.377273 -133.272410 -133.664704 -133.632257  -133.678643 -133.565676
# 3      0.436364 -138.901935 -139.284176 -139.283487  -139.337209 -139.180667
# 4      0.495455 -142.625842 -142.989332 -142.987177  -143.048449 -142.885492
# 5      0.554545 -145.089842 -145.433541 -145.432527  -145.498657 -145.330548
# 6      0.613636 -146.733390 -147.060015 -147.059741  -147.130422 -146.958340
# 7      0.672727 -147.837417 -148.150307 -148.150609  -148.225142 -148.050266
# 8      0.731818 -148.580986 -148.883306 -148.883372  -148.961680 -148.785007
# 9      0.790909 -149.080231 -149.374650 -149.374665  -149.455669 -149.278228
# 10     0.850000 -149.412353 -149.700940 -149.700841  -149.783797 -149.606531
# 11     0.909091 -149.629864 -149.914161 -149.914400  -149.998090 -149.821852
# 12     0.968182 -149.768967 -150.049988 -150.050700  -150.134329 -149.959936
# 13     1.027273 -149.854718 -150.133064 -150.134216  -150.217211 -150.045355
# 14     1.086364 -149.904436 -150.180356 -150.182018  -150.263753 -150.095069
# 15     1.145455 -149.930082 -150.203525 -150.205823  -150.285686 -150.120712
# 16     1.204545 -149.939914 -150.210589 -150.213614  -150.291097 -150.130275
# 17     1.263636 -149.939611 -150.207046 -150.210763  -150.285564 -150.129230
# 18     1.322727 -149.933044 -150.196643 -150.201131  -150.272911 -150.121308
# 19     1.381818 -149.922823 -150.181913 -150.187271  -150.255737 -150.109023
# 20     1.440909 -149.910711 -150.164561 -150.170903  -150.235802 -150.094073
# 21     1.500000 -149.897918 -150.145741 -150.153148  -150.214302 -150.077604
# 22     1.559091 -149.885318 -150.126249 -150.134763  -150.192064 -150.060406
# 23     1.618182 -149.873584 -150.106644 -150.116266  -150.169667 -150.043038
# 24     1.677273 -149.863260 -150.087320 -150.098034  -150.147522 -150.025893
# 25     1.736364 -149.854805 -150.068549 -150.080291  -150.125910 -150.009243
# 26     1.795455 -149.848588 -150.050516 -150.063217  -150.105023 -149.993271
# 27     1.854545 -149.844875 -150.033334 -150.046944  -150.084979 -149.978093
# 28     1.913636 -149.843784 -150.017069 -150.031551  -150.065846 -149.963773
# 29     1.972727 -149.845255 -150.001747 -150.017079  -150.047654 -149.950340
# 30     2.031818 -149.849038 -149.987371 -150.003552  -150.030407 -149.937796
# 31     2.090909 -149.854735 -149.973924 -149.990950  -150.014090 -149.926124
# 32     2.150000 -149.861877 -149.961375 -149.979248  -149.998675 -149.915294
# 33     2.209091 -149.869986 -149.949688 -149.968411  -149.984126 -149.905269
# 34     2.268182 -149.878645 -149.938819 -149.958397  -149.970401 -149.896005
# 35     2.327273 -149.887510 -149.928725 -149.949158  -149.957461 -149.887463
# 36     2.386364 -150.123740 -149.919362 -149.940650  -149.945264 -149.879597
# 37     2.445455 -149.904914 -149.910687 -149.932831  -149.933770 -149.872365
# 38     2.504545 -149.913123 -149.902660 -149.925665  -149.922941 -149.865729
# 39     2.563636 -149.526751 -149.895240 -149.919113  -149.912741 -149.859645
# 40     2.622727 -149.702332 -149.888391 -149.913133  -149.903135 -149.854082
# 41     2.681818 -149.934845 -149.882077 -149.907686  -149.894091 -149.849007
# 42     2.740909 -149.566124 -149.876261 -149.902728  -149.885576 -149.734201
# 43     2.800000 -149.938109 -149.870908 -149.898224  -149.877559 -149.735118
#
#     NN-Functional.DM21m
# 0           -111.543450
# 1           -125.208716
# 2           -133.679277
# 3           -139.327792
# 4           -143.031205
# 5           -145.469750
# 6           -147.077750
# 7           -148.168021
# 8           -148.907198
# 9           -149.398536
# 10          -149.722828
# 11          -149.929862
# 12          -150.057779
# 13          -150.134339
# 14          -150.178168
# 15          -150.199974
# 16          -150.206842
# 17          -150.202787
# 18          -150.191044
# 19          -150.174926
# 20          -150.156653
# 21          -150.137350
# 22          -150.117648
# 23          -150.097981
# 24          -150.078634
# 25          -150.059698
# 26          -150.041411
# 27          -150.023896
# 28          -150.007221
# 29          -149.991429
# 30          -149.976506
# 31          -149.962398
# 32          -149.949082
# 33          -149.936546
# 34          -149.924759
# 35          -149.913683
# 36          -149.903341
# 37          -149.893663
# 38          -149.884635
# 39          -149.876207
# 40          -149.868360
# 41          -149.861042
# 42          -149.854222
# 43          -149.847879

# %%
type(df['bond_lenght'].to_numpy() )
# Out:
# numpy.ndarray

# %%
df['bond_lenght'].to_numpy()
# Out:
# array([0.25909091, 0.31818182, 0.37727273, 0.43636364, 0.49545455,
#        0.55454545, 0.61363636, 0.67272727, 0.73181818, 0.79090909,
#        0.85      , 0.90909091, 0.96818182, 1.02727273, 1.08636364,
#        1.14545455, 1.20454545, 1.26363636, 1.32272727, 1.38181818,
#        1.44090909, 1.5       , 1.55909091, 1.61818182, 1.67727273,
#        1.73636364, 1.79545455, 1.85454545, 1.91363636, 1.97272727,
#        2.03181818, 2.09090909, 2.15      , 2.20909091, 2.26818182,
#        2.32727273, 2.38636364, 2.44545455, 2.50454545, 2.56363636,
#        2.62272727, 2.68181818, 2.74090909, 2.8       ])

# %%
import  matplotlib.font_manager

flist = matplotlib.font_manager.get_fontconfig_fonts()
names = [matplotlib.font_manager.FontProperties(fname=fname).get_name() for fname in flist]
print(names)
# Out:
# ['Liberation Sans', 'Liberation Mono', 'Liberation Sans Narrow', 'Liberation Sans Narrow', 'Liberation Sans', 'Liberation Mono', 'Liberation Serif', 'Liberation Sans', 'Liberation Serif', 'Liberation Sans', 'Liberation Sans Narrow', 'Liberation Serif', 'Liberation Sans Narrow', 'Humor Sans', 'Liberation Mono', 'Liberation Serif', 'Liberation Mono']

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def plotNand(choiceDFT , myfigsize=(12, 10), myfontsize=20):
  plt.figure(0)


  plt.figure(figsize=myfigsize)
  plt.rcParams["font.family"] = "Liberation Serif"



  lengendlist =[]

  if 'CCSDT' in choiceDFT:
    plt.plot(df['bond_lenght'].to_numpy() , df['CCSDT'].to_numpy()  , 'o-')
    lengendlist.append('CCSD(T)')



  for afunctionals in functionalsList:
    if afunctionals in choiceDFT:
      plt.plot(df['bond_lenght'].to_numpy() , df['DFT-'+str(afunctionals)].to_numpy() , 'x-' )
      lengendlist.append(str(afunctionals))

  for aDMFunctionalvalue in dm21.Functional:
    if str(aDMFunctionalvalue) in choiceDFT:
      plt.plot(df['bond_lenght'].to_numpy() , df['NN-'+str(aDMFunctionalvalue)].to_numpy()  )
      lengendlist.append(str(aDMFunctionalvalue))



  plt.legend(lengendlist,  fontsize = myfontsize)
  plt.rc('xtick',labelsize=myfontsize-1)
  plt.rc('ytick',labelsize=myfontsize-2)
  plt.ylabel('Energy in Hartree', fontsize = myfontsize)
  plt.xlabel('Bond length in angstrom', fontsize = myfontsize)
  #plt.title(ValidatedBasisSet, fontsize = myfontsize)
  plt.show()

# %%
choiceDFT = ['CCSDT', 'b3lyp' , 'Functional.DM21m']
plotNand(choiceDFT , myfigsize=(12, 10), myfontsize=20)

# %%
choiceDFT = ['CCSDT', 'b3lyp' , 'Functional.DM21m']
plotNandZOOM(choiceDFT , myfigsize=(12, 10), myfontsize=20, ylimits=[-151,-145], xlimits=[0, 3])

# %%
choiceDFT = ['CCSDT', 'b3lyp' , 'Functional.DM21m']
plotNandZOOM(choiceDFT , myfigsize=(12, 10), myfontsize=20, ylimits=[-151,-148], xlimits=[0, 2.3])

# %%
choiceDFT = ['CCSDT', 'b3lyp' , 'Functional.DM21m']
plotNandZOOM(choiceDFT , myfigsize=(12, 10), myfontsize=20, ylimits=[-150.3,-149], xlimits=[0, 2.8])

# %%
choiceDFT = ['CCSDT', 'b3lyp' , 'Functional.DM21m']
plotNandZOOM(choiceDFT , myfigsize=(12, 10), myfontsize=20, ylimits=[-150.3,-149], xlimits=[0.5, 2.3])

# %%
choiceDFT = ['CCSDT', 'SCAN' , 'Functional.DM21m']
plotNandZOOM(choiceDFT , myfigsize=(12, 10), myfontsize=20, ylimits=[-150.3,-149], xlimits=[0.5, 2.3])

# %%
choiceDFT = ['CCSDT', 'b3lyp' , 'Functional.DM21m']
plotNandZOOM(choiceDFT , myfigsize=(12, 10), myfontsize=20, ylimits=[-150.3,-149], xlimits=[0.5, 2.3])

# %%
choiceDFT = ['CCSDT', 'wB97X-V' , 'Functional.DM21m']
plotNandZOOM(choiceDFT , myfigsize=(20, 18), myfontsize=20, ylimits=[-150.3,-148.7], xlimits=[0.5, 2.32])

# %%
choiceDFT = ['CCSDT', 'wB97X-V' , 'Functional.DM21m']
plotNandZOOM(choiceDFT , myfigsize=(20, 18), myfontsize=20, ylimits=[-150.3,-149], xlimits=[0.5, 2.3])

# %%
choiceDFT = ['CCSDT', 'wB97X-V' , 'Functional.DM21m']
plotNandZOOM(choiceDFT , myfigsize=(16, 14), myfontsize=20, ylimits=[-150.3,-149], xlimits=[0.5, 2.3])

# %%
def plotNandZOOM(choiceDFT , myfigsize=(12, 10), myfontsize=20, ylimits=[-170,-10], xlimits=[0, 4]):
  plt.figure(0)


  plt.figure(figsize=myfigsize)
  plt.rcParams["font.family"] = "Liberation Serif"

  axes = plt.axes()
  axes.set_ylim(ylimits  )
  axes.set_xlim(xlimits )

  lengendlist =[]

  if 'CCSDT' in choiceDFT:
    plt.plot(df['bond_lenght'].to_numpy() , df['CCSDT'].to_numpy()  , 'o-')
    lengendlist.append('CCSD(T)')



  for afunctionals in functionalsList:
    if afunctionals in choiceDFT:
      plt.plot(df['bond_lenght'].to_numpy() , df['DFT-'+str(afunctionals)].to_numpy() , 'x-' )
      lengendlist.append(str(afunctionals))

  for aDMFunctionalvalue in dm21.Functional:
    if str(aDMFunctionalvalue) in choiceDFT:
      plt.plot(df['bond_lenght'].to_numpy() , df['NN-'+str(aDMFunctionalvalue)].to_numpy()  )
      lengendlist.append(str(aDMFunctionalvalue))



  plt.legend(lengendlist,  fontsize = myfontsize)
  plt.rc('xtick',labelsize=myfontsize-1)
  plt.rc('ytick',labelsize=myfontsize-2)
  plt.ylabel('Energy in Hartree', fontsize = myfontsize)
  plt.xlabel('Bond length in angstrom', fontsize = myfontsize)
 # plt.title(ValidatedBasisSet, fontsize = myfontsize)
  plt.show()

# %%
choiceDFT = ['CCSDT', 'SCAN' , 'Functional.DM21m']
plotNandZOOM(choiceDFT , myfigsize=(12, 10), myfontsize=20, ylimits=[-153,-145], xlimits=[0, 2.6])

# %%
choiceDFT = ['CCSDT', 'b3lyp' , 'Functional.DM21m']
plotNandZOOM(choiceDFT , myfigsize=(12, 10), myfontsize=20, ylimits=[-151,-146], xlimits=[0, 2.4])

# %%
choiceDFT = ['CCSDT', 'b3lyp' , 'SCAN' , 'wB97X-V', 'pbe' , 'Functional.DM21m', 'Functional.DM21mc' , 'Functional.DM21mu']
plotNand(choiceDFT , myfigsize=(12, 10), myfontsize=20)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'NN-Functional.DM21mc'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-211-1baa6ec4719c> in <module>()
#       1
#       2 choiceDFT = ['CCSDT', 'b3lyp' , 'SCAN' , 'wB97X-V', 'pbe' , 'Functional.DM21m', 'Functional.DM21mc' , 'Functional.DM21mu']
# ----> 3 plotNand(choiceDFT , myfigsize=(12, 10), myfontsize=20)
#
# <ipython-input-199-b55511855787> in plotNand(choiceDFT, myfigsize, myfontsize)
#      27   for aDMFunctionalvalue in dm21.Functional:
#      28     if str(aDMFunctionalvalue) in choiceDFT:
# ---> 29       plt.plot(df['bond_lenght'].to_numpy() , df['NN-'+str(aDMFunctionalvalue)].to_numpy()  )
#      30       lengendlist.append(str(aDMFunctionalvalue))
#      31
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'NN-Functional.DM21mc'

# %%
choiceDFT = ['CCSDT',   'SCAN' , 'Functional.DM21m',  'Functional.DM21mu']
plotNand(choiceDFT , myfigsize=(20, 20), myfontsize=20)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'NN-Functional.DM21mu'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-205-85bae9ca5a0a> in <module>()
#       1 choiceDFT = ['CCSDT',   'SCAN' , 'Functional.DM21m',  'Functional.DM21mu']
# ----> 2 plotNand(choiceDFT , myfigsize=(20, 20), myfontsize=20)
#
# <ipython-input-199-b55511855787> in plotNand(choiceDFT, myfigsize, myfontsize)
#      27   for aDMFunctionalvalue in dm21.Functional:
#      28     if str(aDMFunctionalvalue) in choiceDFT:
# ---> 29       plt.plot(df['bond_lenght'].to_numpy() , df['NN-'+str(aDMFunctionalvalue)].to_numpy()  )
#      30       lengendlist.append(str(aDMFunctionalvalue))
#      31
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'NN-Functional.DM21mu'

# %%
choiceDFT = ['CCSDT',   'b3lyp' ,    'Functional.DM21m']
plotNand(choiceDFT , myfigsize=(20, 20), myfontsize=20)

# %%
choiceDFT = ['CCSDT',   'pbe' ,    'Functional.DM21m']
plotNand(choiceDFT , myfigsize=(20, 20), myfontsize=20)

# %%
choiceDFT = ['CCSDT',   'pbe' ,    'Functional.DM21m']
plotNand(choiceDFT , myfigsize=(20, 20), myfontsize=20)

# %%
choiceDFT = ['CCSDT', 'b3lyp' , 'Functional.DM21m']
plotNand(choiceDFT , myfigsize=(20, 16), myfontsize=20)

# %%
choiceDFT = ['CCSDT', 'wB97X-V' , 'Functional.DM21m']
plotNand(choiceDFT , myfigsize=(20, 16), myfontsize=20)

# %% [markdown]
# #validate the energy against NIST bechmarks ..
# manually just the ball park number some be matcoed
#
# https://cccbdb.nist.gov/bseenergy2x.asp shows
# or  http://www.begdb.org/index.php
#
# For C,
# *   CCSD = -75.7656956
# *   CCST(T)/cc-pVQZ is -75.8552316
