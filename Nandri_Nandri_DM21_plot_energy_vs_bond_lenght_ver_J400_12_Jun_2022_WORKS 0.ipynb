# %% [markdown]
# <a href="https://colab.research.google.com/github/rajagopalmotivate/MLinQuantamScience/blob/main/Nandri_Nandri_DM21_plot_energy_vs_bond_lenght_ver_J400_12_Jun_2022_WORKS%200.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Simple comparision of DFT vs NN
# ## Hypothesis: NN performs as good as DFT
# ## Experiment: Compare

# %%
EXPNO ='ENERGYVsBOND_0003_N'

dictPeriodicTable = {'N': 7}
 
elementname ='N'

# %%
firstTimeorRestart = True

# %% [markdown]
# #  basis set and as per DM21 authors
# For all benchmarking, we use the large aug'-def2-QZVP basis set
#
# During training,
# For all the atoms and diatomic molecules in the regression set we generate the features for
# the SCF loss at PySCF grid level 2 and use the largest basis set in the aug-pc-X family such
# that the number of basis functions is less than 128.
# For larger neutral molecules we use grid
# level 1 and the largest basis set with less than 128 basis functions from cc-pCV(Q+d)Z, ccpCV(T+d)Z, cc-pV(T+d)Z or cc-pV(D+d)Z

# %%
listBasisSet = ['6-21g' , 'cc-pvqz' , 'def2-qzvp'  ]

listBasisSet = ['def2-QZVP' , 'cc-pCVTZ' ,  'aug-pc-3' , 'aug-cc-pV(Q+d)Z', 'aug-cc-pCV5Z', 'aug-ccpwCV5Z', '6-21g']

listBasisSet = ['cc-pCVDZ' , 'def2-QZVP' , 'cc-pCVTZ' ,  'aug-pc-3' , 'aug-cc-pV(Q+d)Z', 'aug-cc-pCV5Z', 'aug-ccpwCV5Z', '6-31g', 'STO-3G' , 'def2-QZVPPD' ]

listBasisSet = ['def2-QZVP' , 'cc-pCVTZ', 'cc-pVQZ' , 'cc-pVXZ', 'aug-cc-pV(Q+d)Z' , '6-31g' ]

listBasisSet = [   'cc-pVQZ' , 'def2-QZVP' , 'cc-pCVTZ',  'cc-pVXZ' , '6-31g' ]

listBasisSet = [   'cc-pVQZ' , 'def2-QZVP' , 'cc-pCVQZ'  ]

listBasisSet = [   'cc-pVQZ' , 'cc-pVTZ', 'cc-pVDZ',  'cc-pCVQZ', 'cc-pCV5Z',  'def2-QZVP', 'def2-TCVPPD', '6-31g' ,'STO-3G'   ]

listBasisSet = [   'cc-pVQZ', 'def2-QZVP']

listBasisSet = [  'cc-pV7Z', 'cc-pV6Z',  'cc-pVQZ' , 'cc-pVDZ' , 'cc-pCVQZ',    'def2-QZVP', 'def2-7CVPPD', '6-31g' ,'STO-3G'   ]


listBasisSet = [ 'cc-pVQZ' , 'cc-pVDZ' , "aug'-def2-QZVP", '6-31g' , 'aug-pcJ-4', 'cc-pCV(Q+d)Z']

listBasisSet = [ 'cc-pVQZ' , 'cc-pVDZ' , 'def2-QZVP', '6-31g' ]


listBasisSet = [   'cc-pVDZ' ]


#listBasisSet = [ 'cc-pVQZ' , "aug'-def2-QZVP"]

# %%
#dictPeriodicTable = {'H': 1, 'He': 2, 'Li': 3, 'Be': 4, 'B': 5, 'C': 6, 'N': 7, 'O': 8, 'F': 9, 'Ne': 10 }

#dictPeriodicTable = {'H': 1, 'He': 2, 'Li': 3, 'Be': 4, 'B': 5, 'C': 6, 'N': 7, 'O': 8, 'F': 9, 'Ne': 10 , 'Na':11, 'Mg':12 , 'Al':13, 'Si':14, 'P':15, 'S':16 , 'Cl':17, 'Ar':18}

 
dictPeriodicTableSpinValues = {'H': 1,  'He': 0, 'Li': 1, 'Be': 0, 'B': 1, 'C': 0, 'N': 1, 'O': 0, 'F': 1, 'Ne': 0 }



print(str( 'Weight'  + ' ' +   ' \t Element     \t  SPIN'    ))
# Out:
# Weight  	 Element     	  SPIN

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Step 1: Install

# %%
#!pip install git+git://github.com/deepmind/deepmind-research.git#subdirectory=density_functional_approximation_dm21

# %%
# !git clone https://github.com/deepmind/deepmind-research.git
# Out:
# Cloning into 'deepmind-research'...
# remote: Enumerating objects: 2581, done.
# remote: Counting objects: 100% (209/209), done.
# remote: Compressing objects: 100% (155/155), done.
# remote: Total 2581 (delta 55), reused 201 (delta 54), pack-reused 2372
# Receiving objects: 100% (2581/2581), 92.05 MiB | 29.37 MiB/s, done.
# Resolving deltas: 100% (1204/1204), done.

# %%
cd deepmind-research/density_functional_approximation_dm21
# Out:
# /content/deepmind-research/density_functional_approximation_dm21

# %%
pwd
# Out:
# '/content/deepmind-research/density_functional_approximation_dm21'

# %%
# !pip install .
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/deepmind-research/density_functional_approximation_dm21
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from density-functional-approximation-dm21==0.1) (1.1.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from density-functional-approximation-dm21==0.1) (21.4.0)
# Requirement already satisfied: h5py<3.3.0 in /usr/local/lib/python3.7/dist-packages (from density-functional-approximation-dm21==0.1) (3.1.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from density-functional-approximation-dm21==0.1) (1.21.6)
# Collecting pyscf
#   Downloading pyscf-2.0.1-cp37-cp37m-manylinux1_x86_64.whl (37.5 MB)
#      |████████████████████████████████| 37.5 MB 320 kB/s
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.7/dist-packages (from density-functional-approximation-dm21==0.1) (2.8.2+zzzcolab20220527125636)
# Requirement already satisfied: tensorflow_hub in /usr/local/lib/python3.7/dist-packages (from density-functional-approximation-dm21==0.1) (0.12.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py<3.3.0->density-functional-approximation-dm21==0.1) (1.5.2)
# Requirement already satisfied: scipy!=1.5.0,!=1.5.1 in /usr/local/lib/python3.7/dist-packages (from pyscf->density-functional-approximation-dm21==0.1) (1.4.1)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (0.2.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (1.14.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (1.1.2)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (2.8.0)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (1.15.0)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (0.5.3)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (1.1.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (14.0.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (3.17.3)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (1.6.3)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (2.8.0)
# Requirement already satisfied: tensorflow-estimator<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (2.8.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (57.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (4.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (1.46.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (3.3.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->density-functional-approximation-dm21==0.1) (0.26.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow->density-functional-approximation-dm21==0.1) (0.37.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (2.23.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (1.0.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (1.35.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (3.3.7)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (2022.5.18.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow->density-functional-approximation-dm21==0.1) (3.2.0)
# Building wheels for collected packages: density-functional-approximation-dm21
#   Building wheel for density-functional-approximation-dm21 (setup.py) ... done
#   Created wheel for density-functional-approximation-dm21: filename=density_functional_approximation_dm21-0.1-py3-none-any.whl size=6085418 sha256=ccf5acc7a4cb3993ff63692f8d88d86bff72ad16dabaa0f1a954469a158529b3
#   Stored in directory: /tmp/pip-ephem-wheel-cache-yqk19mh4/wheels/3b/c5/70/0200d858561857222265157381fd4ad73ce078117b4821cd36
# Successfully built density-functional-approximation-dm21
# Installing collected packages: pyscf, density-functional-approximation-dm21
# Successfully installed density-functional-approximation-dm21-0.1 pyscf-2.0.1

# %% [markdown]
# ## Step 2: Configure RAM optionally

# %%
from pyscf import gto
from pyscf import dft

from pyscf import __config__
MAX_MEMORY = getattr(__config__, 'MAX_MEMORY')
MAX_MEMORY
# Out:
# 4000

# %%
import psutil
systemresources = psutil.virtual_memory()

MAX_MEMORY = round( systemresources.available  * 0.000009)
PYSCF_MAX_MEMORY  = MAX_MEMORY

print('Configured to use max RAM resources of  ' + str(MAX_MEMORY))
# Out:
# Configured to use max RAM resources of  111381

# %%
setattr(__config__, 'MAX_MEMORY', PYSCF_MAX_MEMORY)

setattr(__config__, 'PYSCF_MAX_MEMORY', PYSCF_MAX_MEMORY)

# %%
MAX_MEMORY = getattr(__config__, 'MAX_MEMORY')
MAX_MEMORY
# Out:
# 111381

# %% [markdown]
# ## Step 3:
#
# ### 3.1 Define the periodic table (Define atomic weight and periodic weight for each element)
#
# ### 3.2 Define the spin value for each element
#
# ### 3.3 You can load any new basis function.  Just visit the Basics Exchange and get a new Basis Function URL .
# #### here we download a basis set full defintion file from an URL and then use it to construct a molecule
#
# #### To get a web URL, just visit https://www.basissetexchange.org/

# %% [markdown]
# http://vergil.chemistry.gatech.edu/courses/chem6485/pdf/basis-sets.pdf
#
# https://youtu.be/irQ_c_fW5f8?t=971
#
#
# 1.   cc-pCVXZ or aug-cc-pCVXZ basis sets;  you should use basis sets like this if you do not freeze core
# 2.   cc-pVQZ is great for CCSD(T)

# %%
def trydownloadingBasisSet(ElementsinMolecule, BasisSet, versionno):  
    target_url = 'https://www.basissetexchange.org/api/basis/' + str(BasisSet) +  '/format/nwchem/?version='+ str( versionno)+'&elements=' + str(ElementsinMolecule) 
    #print(target_url)
    try:
      textfile = urllib.request.urlopen(target_url)    
      mydownloadedfile = ""
      for line in textfile:
          #print(line.decode('utf-8')) #utf-8 or iso8859-1 or whatever the page encoding scheme is
          mydownloadedfile += line.decode('utf-8') 
      return True    
    except:
      return False

# %%
import urllib   # the lib that handles the url stuff
import urllib.request  # the lib that handles the url stuff


def getValidBasisSet(MoleculeList):
  ValidatedBasisSet = []
  ValBSSetVersionNumberDict = {}
  errorproneBasisSet = []
  for BasisSet in listBasisSet:
    didnotworkatallforanyversion = True
    for versionno in range(0,4):
      isworking = trydownloadingBasisSet(MoleculeList, BasisSet, versionno)
      if isworking == True:
        didnotworkatallforanyversion = False
        ValBSSetVersionNumberDict[BasisSet] = versionno
        ValidatedBasisSet.append(BasisSet)
        break
    if didnotworkatallforanyversion == True:
      errorproneBasisSet.append(BasisSet)
  return ValidatedBasisSet

# %%
def downloadBasisSetAutoVersion(ElementsinMolecule, BasisSet):  
    for versionumber in range (0,4):
      target_url = 'https://www.basissetexchange.org/api/basis/' + str(BasisSet) +  '/format/nwchem/?version='+ str( versionumber)+'&elements=' + str(ElementsinMolecule) 
      try:
        textfile = urllib.request.urlopen(target_url)    
        mydownloadedfile = ""
        for line in textfile:
            #print(line.decode('utf-8')) #utf-8 or iso8859-1 or whatever the page encoding scheme is
            mydownloadedfile += line.decode('utf-8') 
        return mydownloadedfile    
      except:
        return None

# %%
PerdiocTableNumber = dictPeriodicTable [elementname]
ValidatedBasisSet = getValidBasisSet(PerdiocTableNumber)
len(ValidatedBasisSet)
ValidatedBasisSet
# Out:
# ['cc-pVDZ']

# %%
basisSethandpicked =[  ]

# %%
#listBasisSet = basisSet652

# %%
try:
  print("Hello")
except:
  print("Something went wrong")
else:
  print("Nothing went wrong")
# Out:
# Hello
# Nothing went wrong

# %%
#downloadBasisSetAutoVersion(1,'3-21G')

# %% [markdown]
# geomtery optimization

# %%
!	pip install -U pyberny
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyberny
#   Downloading pyberny-0.6.3-py3-none-any.whl (27 kB)
# Requirement already satisfied: numpy<2.0,>=1.15 in /usr/local/lib/python3.7/dist-packages (from pyberny) (1.21.6)
# Installing collected packages: pyberny
# Successfully installed pyberny-0.6.3

# %%
from pyscf import gto
from pyscf import scf
from pyscf import cc
from pyscf.cc import ccsd_t_lambda_slow as ccsd_t_lambda
from pyscf.grad import ccsd_t as ccsd_t_grad
from pyscf.geomopt import berny_solver

def f_usefforberny_solver(mol):
    # Compute CCSD(T) energy
    mf = scf.RHF(mol).run()
    mycc = cc.CCSD(mf).run()
    et_correction = mycc.ccsd_t()
    e_tot = mycc.e_tot + et_correction

    # Compute CCSD(T) gradients
    g = ccsd_t_grad.Gradients(mycc).kernel()
    print('CCSD(T) nuclear gradients:')
    print(g)
    return e_tot, g

# %%
 hashLookUpMolecules = dict()

# %%
def GetoptimizedMolecule(randomMol):
  global hashLookUpMolecules
  print('****************************************************************GEOMENTRY OPTIMIZATION Starts***********************************************')  
  print('MOLECULE KEY is')
  print([randomMol.basis])
  if randomMol in hashLookUpMolecules:
    saved_mol = hashLookUpMolecules[randomMol]
    print('****************************************************************GEOMENTRY looked up from Hashtable***********************************************')  
    return saved_mol
  fake_method = berny_solver.as_pyscf_method(randomMol, f_usefforberny_solver)
  new_mol = berny_solver.optimize(fake_method , maxsteps=400)
  print('Old geometry (Bohr)')
  print(randomMol.atom_coords())  
  print('New geometry (Bohr)')
  print(new_mol.atom_coords())  
  hashLookUpMolecules[randomMol] = new_mol
  print('****************************************************************GEOMENTRY OPTIMIZATION Ends***********************************************')  
  return new_mol

# %% [markdown]
# DM21

# %%
import density_functional_approximation_dm21 as dm21
from pyscf import gto
from pyscf import dft
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
import pandas as pd
import numpy as np

# %%
GlobalBONDLENGTH = 0.0001

# %%
def buildaMoleculeSpin(elementname, elementname2, mydownloadedfile, mydownloadedfile2, trythisspin ):
      global GlobalBONDLENGTH
      mol = gto.Mole()

      #mol.unit = 'B'
      mol.unit = 'Angstrom'
      
      mol.atom = [[elementname, ( 0, 0, GlobalBONDLENGTH)], [elementname2, (0, 0, -1* GlobalBONDLENGTH)] ]
      mol.spin =  trythisspin
      mol.symmetry = True
      mol.basis = { elementname: gto.parse(mydownloadedfile)  ,     elementname2: gto.parse(mydownloadedfile2)        }
      #mol.max_memory = PYSCF_MAX_MEMORY
      mol.build()
      return mol

# %% [markdown]
# Geometry for C2 (Carbon diatomic) 1Σg+ D*H
#
#
# https://cccbdb.nist.gov/geom3x.asp?method=63&basis=25
# ```
# CCSD(T)=FULL/cc-pVQZ
#
# Atom	X	Y	Z
# C	0.0000000	0.0000000	0.6210880
# C	0.0000000	0.0000000	-0.6210880
#
#
#
# CCSD(T)=FULL/cc-pVDZ
#
# Atom	Internal
# x (Å)	y (Å)	z (Å)
# C1	0.0000	0.0000	0.6211
# C2	0.0000	0.0000	-0.6211

# %%
def buildaMoleculeTryMOLECULEELEMENTCOUNT2(elementname, elementname2, mydownloadedfile , mydownloadedfile2 ):
  molecule = None 
  for spinvaluecheckthis in range(5):
    try:
      molecule = buildaMoleculeSpin(elementname,elementname2, mydownloadedfile, mydownloadedfile2, spinvaluecheckthis )      
      return molecule, spinvaluecheckthis
      break
    except:
      tempexcept = True
      #print('SPIN is not correct. Auto matically trying another spin value...')
    else:
      tempelse = True
      #print('TRYING SPIN')
  return molecule, spinvaluecheckthis

# %%
def buildaMoleculeSpinMOLECULEELEMENTCOUNT1(elementname, mydownloadedfile,  trythisspin ):
      mol = gto.Mole()
      #mol.atom = '''H 0 0 0'''
      mol.atom = [[elementname, (0, 0, 0)] ]
      mol.spin =  trythisspin
      mol.basis = { elementname: gto.parse(mydownloadedfile)       }
      mol.build()
      return mol

# %%
def buildaMoleculeTryMOLECULEELEMENTCOUNT1(elementname,  mydownloadedfile ):
  molecule = None 
  for spinvaluecheckthis in range(5):
    try:
      molecule = buildaMoleculeSpinMOLECULEELEMENTCOUNT1(elementname, mydownloadedfile, spinvaluecheckthis )      
      return molecule, spinvaluecheckthis
      break
    except:
      tempexcept = True
      #print('SPIN is not correct. Auto matically trying another spin value...')
    else:
      tempelse = True
      #print('TRYING SPIN')
  return molecule, spinvaluecheckthis

# %% [markdown]
# ## Step 4: Expected format of output table

# %% [markdown]
# ## Step 5. Input values to be considered in this computation

# %% [markdown]
# ## Step 6. Compute Results
# ## Run the computation for the above input values

# %%
functionalsList = ['b3lyp','M06-2X' , 'SCAN'    ,'wB97X-V',  'PW6B95' , 'pbe']

functionalsList = ['b3lyp','M06-2X' , 'SCAN'    ,'wB97X-V',  'PW6B95' ,  'pbe' ,  'pbe0']

functionalsList = [ 'b3lyp', 'SCAN'  , 'wB97X-V'  , 'pbe']


#functionalsList = ['b3lyp']

# %%
from pyscf import dft

# DFT computation of SCF energy  
def SCFenergyFunctionalsbasedonDFTGOLD(mol , functionals ):
  if mol.spin == 0:
    mf = dft.RKS(mol)
  else:
    mf = dft.UKS(mol)
  # functional.
  #mf.xc = 'B3LYP'
  mf.max_memory = PYSCF_MAX_MEMORY
  mf.xc = functionals
  # Run the DFT calculation.
  answerDFT = mf.kernel()
  return answerDFT

# %%
# DFT computation of SCF energy  
def SCFenergyFunctionalsbasedonDFT(mol , functionals ):
    mf = mol.KS()
   # mf.xc = 'b3lyp'
   # mf.xc = 'pbe0'
   # mf.xc = 'M06-2X'
   # mf.xc = 'SCAN'    
   # mf.xc = 'wB97X-V'
   # mf.xc = 'PW6B95'
    mf.xc = functionals
    # Run the DFT calculation.
    answerDFT = mf.kernel()
    return answerDFT

# %%
def SCFenergyFunctionalsbasedonNNGOLD(mol,  NNfunctionals ):
    if mol.spin == 0:
      mf = dft.RKS(mol)
    else:
      mf = dft.UKS(mol)
    #mf._numint = dm21.NeuralNumInt(dm21.Functional.DM21m )
    mf._numint = dm21.NeuralNumInt(NNfunctionals)
    mf.max_memory = PYSCF_MAX_MEMORY
    # Run the DFT calculation.
    answerNN = mf.kernel()
    return answerNN

# %%
def SCFenergyFunctionalsbasedonNN(mol,  NNfunctionals, functionals='b3lyp'):
    mf = mol.KS()
    mf.xc = functionals
    #mf._numint = dm21.NeuralNumInt(dm21.Functional.DM21m )
    mf._numint = dm21.NeuralNumInt(NNfunctionals)
    # Run the DFT calculation.
    answerNN = mf.kernel()
    return answerNN

# %%
# DFT computation of SCF energy  
def SCFenergybasedonDFT(mol):
    mf = dft.RKS(mol)
    # Run the DFT calculation.
    answerDFT = mf.kernel()
    return answerDFT

# %%
# Neural network based prediction of SCF energy   
def SCFenergybasedonNN(mol):
    mf = dft.RKS(mol)
    mf._numint = dm21.NeuralNumInt(dm21.Functional.DM21)
    # Run the DFT calculation.
    answerNN = mf.kernel()
    return answerNN

# %%
# CCSD computation 
def SCFenergybasedonCCSD(mol):
  ccsdanswer = mol.apply('CCSD').run().e_tot
  return ccsdanswer

# %%
from pyscf import  scf, cc

# CCSD-T computation 
def SCFenergybasedonCCSDTGOLD(mol):
  try:
    mf = scf.HF(mol).run()
    mf.max_memory = PYSCF_MAX_MEMORY
    mycc = cc.CCSD(mf).run()
    #print('CCSD  energy', mycc.e_tot)
    et = mycc.ccsd_t()
    CCSDTotal = mycc.e_tot + et
  except ZeroDivisionError:
    print('000000000000000000000000000000000000000-------CCSDT Error------------00000000000000000000000. Using CCSD')
    return SCFenergybasedonCCSD(mol)
  #print('CCSD(T) total energy', mycc.e_tot + et)
  return CCSDTotal

# %%
import urllib   # the lib that handles the url stuff
import urllib.request  # the lib that handles the url stuff
import numpy
from google.colab import files


print( 'No'  + '        ' + 'Element' + '    \t  \t \t ' +  'Basis Set')
# Out:
# No        Element    	  	 	 Basis Set

# %%
ValidatedBasisSetSOURCE = getValidBasisSet(PerdiocTableNumber)

# %%
def compute1Mol1BasisSet(elementname, ValidatedBasisSetStart , df):
  if True:
    PerdiocTableNumber = dictPeriodicTable [elementname]
    ValidatedBasisSet = ValidatedBasisSetSOURCE[ValidatedBasisSetStart:ValidatedBasisSetStart+1]
    for BasisSet in ValidatedBasisSet:    
      print('***********************************************************')
      print('***********************************************************')
      print('***********************************************************')

      mydownloadedfile = downloadBasisSetAutoVersion(PerdiocTableNumber,BasisSet)      
      molUnoptimized, myspin = buildaMoleculeTryMOLECULEELEMENTCOUNT2(elementname, elementname, mydownloadedfile , mydownloadedfile )
      if molUnoptimized == None:
        return df

      print('.............................................Molecule details......................................................')
      print(molUnoptimized)
      print('In Bohr')
      print(molUnoptimized.atom_coords(unit='Bohr'))
      print('In angstrom')
      print(molUnoptimized.atom_coords(unit='ANG'))


     # mol = GetoptimizedMolecule(molUnoptimized)
      mol = molUnoptimized
        
      print(mol.atom)
      print(mol.atom_coords(unit='Bohr'))
      print(mol.basis)
      print(str( PerdiocTableNumber)  + '        ' + str(elementname) + '    \t  \t \t ' + str(BasisSet))     
      print('.............................................COMPUTING SCF energy......................................................')

      aResultDict = computePart(mol )


      aResultDict['BasisSet'] = [BasisSet]

      dfforOneElement = pd.DataFrame(aResultDict )
      df = df.append(dfforOneElement, ignore_index = True)

      return df


    #  files.download('ComputedEnergy'+str(ValidatedBasisSetStart)+'.csv')

# %%
def computePart(mol):
  global DFT_energies 
  global NN_engeries 
  global CCSD_energies 
  global CCSD_Tenergies 
  global fci_energies 
  global bond_lengths 
  global Mole_bond_defintions 


  if True:
      aResultDict = {}
      aResultDict['bond_lenght'] = GlobalBONDLENGTH * 2.0
      aResultDict['Weight'] = PerdiocTableNumber
      aResultDict['Element'] = [elementname]
      aResultDict['Molecule'] = [mol.atom]
      aResultDict['Spin'] = [mol.spin]
      aResultDict['BuiltMolecule'] = [  mol.basis   ]

      print('++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++')
      # Run the CCSD calculation.
     # CCSDenergy = SCFenergybasedonCCSD(mol)
     # print('ENERGY Computing using CCSD appoach is = ' + str(CCSDenergy ))
      print('++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++')
      CCSDTenergy = SCFenergybasedonCCSDTGOLD(mol)
      print('ENERGY Computing using CCSD T appoach is = ' + str(CCSDTenergy ))


      #aResultDict['DFTApproach'] = answerDFT
      #aResultDict['NNApproach'] = answerNN
     # aResultDict['CCSD'] = CCSDenergy
      aResultDict['CCSDT'] = CCSDTenergy
     # CCSD_energies += [CCSDenergy]
      CCSD_Tenergies += [CCSDTenergy]

      print('++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++')
      for afunctionals in functionalsList:
        ans = SCFenergyFunctionalsbasedonDFTGOLD(mol, afunctionals)
        aResultDict['DFT-'+str(afunctionals)] = ans    
        DFT_energies += [ans]


      print('++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++')
      for aDMFunctionalvalue in dm21.Functional:
        #if str(aDMFunctionalvalue) ==  'Functional.DM21m' :           
        if True:
          ans = SCFenergyFunctionalsbasedonNNGOLD(mol, aDMFunctionalvalue)
          aResultDict['NN-'+str(aDMFunctionalvalue)] = ans    
          NN_engeries += [ans]


      return aResultDict

# %%
if firstTimeorRestart == True:
  df = pd.DataFrame(columns = ['Weight', 'Element', 'Molecule', 'BasisSet','Spin', 'BuiltMolecule' ])

# %%
DFT_energies = []
NN_engeries = []
CCSD_energies = []
CCSD_Tenergies = []
fci_energies = []
bond_lengths = []
Mole_bond_defintions = []

# %%
n_points = 48
bond_length_interval = 3.0 / n_points

# %%
for i in range(0, len(ValidatedBasisSetSOURCE)):
  try:
    for elementname in dictPeriodicTable.keys():
      for point in range(1, n_points + 1):
        print('************************************##############################################*############################### ' + str(point))
        bond_length = bond_length_interval * float(point) + 0.2
        bond_lengths += [bond_length]
        GlobalBONDLENGTH = bond_length/2.0
        df = compute1Mol1BasisSet(elementname, ValidatedBasisSetStart=i , df=df)
  except:
    print('Exception.. continuing')
# Out:
# ************************************##############################################*############################### 1
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f183e6bb350>
# In Bohr
# [[ 0.          0.          0.24802655]
#  [ 0.          0.         -0.24802655]]
# In angstrom
# [[ 0.       0.       0.13125]
#  [ 0.       0.      -0.13125]]
# [['N', (0, 0, 0.13125)], ['N', (0, 0, -0.13125)]]
# [[ 0.          0.          0.24802655]
#  [ 0.          0.         -0.24802655]]
# {'N': [[0, [9046.0, 0.0007, -0.000153, 0.0], [1357.0, 0.005389, -0.001208, 0.0], [309.3, 0.027406, -0.005992, 0.0], [87.73, 0.103207, -0.024544, 0.0], [28.56, 0.278723, -0.067459, 0.0], [10.21, 0.44854, -0.158078, 0.0], [3.838, 0.278238, -0.121831, 0.0], [0.7466, 0.01544, 0.549003, 0.0], [0.2248, -0.002864, 0.578815, 1.0]], [1, [13.55, 0.039919, 0.0], [2.917, 0.217169, 0.0], [0.7973, 0.510319, 0.0], [0.2185, 0.462214, 1.0]], [2, [0.817, 1.0]]]}
# 7        N    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# SCF not converged.
# SCF energy = -79.7280619548647
# E(CCSD) = -79.94137978003573  E_corr = -0.2133178251710877
# CCSD(T) correction = -0.0737684577550691
# ENERGY Computing using CCSD T appoach is = -80.0151482377908
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -80.2405046038044
# converged SCF energy = -80.2521463349854
# SCF not converged.
# SCF energy = -80.2688028957911
# SCF not converged.
# SCF energy = -80.1515457484172
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow_hub/saved_model_lib.py:111: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# converged SCF energy = -80.2797201456557
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -80.2984635310883
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -80.3229431635201
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -80.3061948537881
# ************************************##############################################*############################### 2
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f17b6639550>
# In Bohr
# [[ 0.         0.         0.3070805]
#  [ 0.         0.        -0.3070805]]
# In angstrom
# [[ 0.      0.      0.1625]
#  [ 0.      0.     -0.1625]]
# [['N', (0, 0, 0.1625)], ['N', (0, 0, -0.1625)]]
# [[ 0.         0.         0.3070805]
#  [ 0.         0.        -0.3070805]]
# {'N': [[0, [9046.0, 0.0007, -0.000153, 0.0], [1357.0, 0.005389, -0.001208, 0.0], [309.3, 0.027406, -0.005992, 0.0], [87.73, 0.103207, -0.024544, 0.0], [28.56, 0.278723, -0.067459, 0.0], [10.21, 0.44854, -0.158078, 0.0], [3.838, 0.278238, -0.121831, 0.0], [0.7466, 0.01544, 0.549003, 0.0], [0.2248, -0.002864, 0.578815, 1.0]], [1, [13.55, 0.039919, 0.0], [2.917, 0.217169, 0.0], [0.7973, 0.510319, 0.0], [0.2185, 0.462214, 1.0]], [2, [0.817, 1.0]]]}
# 7        N    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -90.2611285568148
# E(CCSD) = -90.45391456477275  E_corr = -0.1927860079579471
# CCSD(T) correction = -0.00309843602493701
# ENERGY Computing using CCSD T appoach is = -90.45701300079769
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -90.7431509443263
# converged SCF energy = -90.7651029872743
# converged SCF energy = -90.7961005771624
# converged SCF energy = -90.6492212678683
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -90.7777629707031
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -90.7973342425707
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -90.8027540609933
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -90.7913357530017
# ************************************##############################################*############################### 3
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f17b63a5f10>
# In Bohr
# [[ 0.          0.          0.36613444]
#  [ 0.          0.         -0.36613444]]
# In angstrom
# [[ 0.       0.       0.19375]
#  [ 0.       0.      -0.19375]]
# [['N', (0, 0, 0.19375)], ['N', (0, 0, -0.19375)]]
# [[ 0.          0.          0.36613444]
#  [ 0.          0.         -0.36613444]]
# {'N': [[0, [9046.0, 0.0007, -0.000153, 0.0], [1357.0, 0.005389, -0.001208, 0.0], [309.3, 0.027406, -0.005992, 0.0], [87.73, 0.103207, -0.024544, 0.0], [28.56, 0.278723, -0.067459, 0.0], [10.21, 0.44854, -0.158078, 0.0], [3.838, 0.278238, -0.121831, 0.0], [0.7466, 0.01544, 0.549003, 0.0], [0.2248, -0.002864, 0.578815, 1.0]], [1, [13.55, 0.039919, 0.0], [2.917, 0.217169, 0.0], [0.7973, 0.510319, 0.0], [0.2185, 0.462214, 1.0]], [2, [0.817, 1.0]]]}
# 7        N    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -96.4781008607114
# E(CCSD) = -96.68017400215508  E_corr = -0.2020731414436998
# CCSD(T) correction = -0.00264260394212269
# ENERGY Computing using CCSD T appoach is = -96.6828166060972
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -96.9866498427125
# converged SCF energy = -96.9970551884512
# converged SCF energy = -97.0453614858671
# converged SCF energy = -96.8948245169973
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -97.0116101421428
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -97.0327077818968
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -97.0442707440582
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -97.0244812481771
# ************************************##############################################*############################### 4
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f1832e33510>
# In Bohr
# [[ 0.          0.          0.42518838]
#  [ 0.          0.         -0.42518838]]
# In angstrom
# [[ 0.     0.     0.225]
#  [ 0.     0.    -0.225]]
# [['N', (0, 0, 0.225)], ['N', (0, 0, -0.225)]]
# [[ 0.          0.          0.42518838]
#  [ 0.          0.         -0.42518838]]
# {'N': [[0, [9046.0, 0.0007, -0.000153, 0.0], [1357.0, 0.005389, -0.001208, 0.0], [309.3, 0.027406, -0.005992, 0.0], [87.73, 0.103207, -0.024544, 0.0], [28.56, 0.278723, -0.067459, 0.0], [10.21, 0.44854, -0.158078, 0.0], [3.838, 0.278238, -0.121831, 0.0], [0.7466, 0.01544, 0.549003, 0.0], [0.2248, -0.002864, 0.578815, 1.0]], [1, [13.55, 0.039919, 0.0], [2.917, 0.217169, 0.0], [0.7973, 0.510319, 0.0], [0.2185, 0.462214, 1.0]], [2, [0.817, 1.0]]]}
# 7        N    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -100.664033652286
# E(CCSD) = -100.8658413205557  E_corr = -0.2018076682697069
# CCSD(T) correction = -0.00278877037619923
# ENERGY Computing using CCSD T appoach is = -100.86863009093193
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -101.174325549232
# converged SCF energy = -101.175621643973
# converged SCF energy = -101.233598069849
# converged SCF energy = -101.079615296754
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -101.191587768369
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -101.21207631932
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -101.211487721799
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -101.206486394898
# ************************************##############################################*############################### 5
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f183e684d50>
# In Bohr
# [[ 0.          0.          0.48424232]
#  [ 0.          0.         -0.48424232]]
# In angstrom
# [[ 0.       0.       0.25625]
#  [ 0.       0.      -0.25625]]
# [['N', (0, 0, 0.25625)], ['N', (0, 0, -0.25625)]]
# [[ 0.          0.          0.48424232]
#  [ 0.          0.         -0.48424232]]
# {'N': [[0, [9046.0, 0.0007, -0.000153, 0.0], [1357.0, 0.005389, -0.001208, 0.0], [309.3, 0.027406, -0.005992, 0.0], [87.73, 0.103207, -0.024544, 0.0], [28.56, 0.278723, -0.067459, 0.0], [10.21, 0.44854, -0.158078, 0.0], [3.838, 0.278238, -0.121831, 0.0], [0.7466, 0.01544, 0.549003, 0.0], [0.2248, -0.002864, 0.578815, 1.0]], [1, [13.55, 0.039919, 0.0], [2.917, 0.217169, 0.0], [0.7973, 0.510319, 0.0], [0.2185, 0.462214, 1.0]], [2, [0.817, 1.0]]]}
# 7        N    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -103.531478171754
# E(CCSD) = -103.7365444426824  E_corr = -0.2050662709285366
# CCSD(T) correction = -0.00298983072639374
# ENERGY Computing using CCSD T appoach is = -103.7395342734088
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -104.032379317915
# converged SCF energy = -104.031726088116
# converged SCF energy = -104.093936228967
# converged SCF energy = -103.936111370119
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -104.045445423739
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -104.058709316429
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -104.050441798788
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -104.059357752463
# ************************************##############################################*############################### 6
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f17b67b8210>
# In Bohr
# [[ 0.          0.          0.54329626]
#  [ 0.          0.         -0.54329626]]
# In angstrom
# [[ 0.      0.      0.2875]
#  [ 0.      0.     -0.2875]]
# [['N', (0, 0, 0.2875)], ['N', (0, 0, -0.2875)]]
# [[ 0.          0.          0.54329626]
#  [ 0.          0.         -0.54329626]]
# {'N': [[0, [9046.0, 0.0007, -0.000153, 0.0], [1357.0, 0.005389, -0.001208, 0.0], [309.3, 0.027406, -0.005992, 0.0], [87.73, 0.103207, -0.024544, 0.0], [28.56, 0.278723, -0.067459, 0.0], [10.21, 0.44854, -0.158078, 0.0], [3.838, 0.278238, -0.121831, 0.0], [0.7466, 0.01544, 0.549003, 0.0], [0.2248, -0.002864, 0.578815, 1.0]], [1, [13.55, 0.039919, 0.0], [2.917, 0.217169, 0.0], [0.7973, 0.510319, 0.0], [0.2185, 0.462214, 1.0]], [2, [0.817, 1.0]]]}
# 7        N    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -105.466611137313
# E(CCSD) = -105.6792229958518  E_corr = -0.2126118585386766
# CCSD(T) correction = -0.00330832890000719
# ENERGY Computing using CCSD T appoach is = -105.68253132475184
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -105.959123136629
# converged SCF energy = -105.958118894366
# converged SCF energy = -106.024399861716
# converged SCF energy = -105.863535760392
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -105.970438204478
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -105.980485567999
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -105.967790631528
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -105.979876910333
# ************************************##############################################*############################### 7
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f1832f90d90>
# In Bohr
# [[ 0.         0.         0.6023502]
#  [ 0.         0.        -0.6023502]]
# In angstrom
# [[ 0.       0.       0.31875]
#  [ 0.       0.      -0.31875]]
# [['N', (0, 0, 0.31875)], ['N', (0, 0, -0.31875)]]
# [[ 0.         0.         0.6023502]
#  [ 0.         0.        -0.6023502]]
# {'N': [[0, [9046.0, 0.0007, -0.000153, 0.0], [1357.0, 0.005389, -0.001208, 0.0], [309.3, 0.027406, -0.005992, 0.0], [87.73, 0.103207, -0.024544, 0.0], [28.56, 0.278723, -0.067459, 0.0], [10.21, 0.44854, -0.158078, 0.0], [3.838, 0.278238, -0.121831, 0.0], [0.7466, 0.01544, 0.549003, 0.0], [0.2248, -0.002864, 0.578815, 1.0]], [1, [13.55, 0.039919, 0.0], [2.917, 0.217169, 0.0], [0.7973, 0.510319, 0.0], [0.2185, 0.462214, 1.0]], [2, [0.817, 1.0]]]}
# 7        N    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -106.75840915224
# E(CCSD) = -106.9810213683555  E_corr = -0.2226122161155362
# CCSD(T) correction = -0.00374301664420993
# ENERGY Computing using CCSD T appoach is = -106.98476438499969
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -107.246130833528
# converged SCF energy = -107.24561215314
# converged SCF energy = -107.315331146924
# converged SCF energy = -107.152617490983
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -107.257090249341
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -107.26953230244
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -107.252810530806
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -107.261712555923
# ************************************##############################################*############################### 8
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f183355f9d0>
# In Bohr
# [[ 0.          0.          0.66140414]
#  [ 0.          0.         -0.66140414]]
# In angstrom
# [[ 0.    0.    0.35]
#  [ 0.    0.   -0.35]]
# [['N', (0, 0, 0.35)], ['N', (0, 0, -0.35)]]
# [[ 0.          0.          0.66140414]
#  [ 0.          0.         -0.66140414]]
# {'N': [[0, [9046.0, 0.0007, -0.000153, 0.0], [1357.0, 0.005389, -0.001208, 0.0], [309.3, 0.027406, -0.005992, 0.0], [87.73, 0.103207, -0.024544, 0.0], [28.56, 0.278723, -0.067459, 0.0], [10.21, 0.44854, -0.158078, 0.0], [3.838, 0.278238, -0.121831, 0.0], [0.7466, 0.01544, 0.549003, 0.0], [0.2248, -0.002864, 0.578815, 1.0]], [1, [13.55, 0.039919, 0.0], [2.917, 0.217169, 0.0], [0.7973, 0.510319, 0.0], [0.2185, 0.462214, 1.0]], [2, [0.817, 1.0]]]}
# 7        N    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -107.613566881789
# E(CCSD) = -107.8473417911117  E_corr = -0.2337749093226042
# CCSD(T) correction = -0.00429793490670925
# ENERGY Computing using CCSD T appoach is = -107.85163972601838
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -108.099867644523
# converged SCF energy = -108.100779556183
# converged SCF energy = -108.172656501043
# converged SCF energy = -108.00918772682
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -108.110284345825
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -108.125696154551
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -108.103684574725
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -108.111667367939
# ************************************##############################################*############################### 9
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f18ad7d80d0>
# In Bohr
# [[ 0.          0.          0.72045808]
#  [ 0.          0.         -0.72045808]]
# In angstrom
# [[ 0.       0.       0.38125]
#  [ 0.       0.      -0.38125]]
# [['N', (0, 0, 0.38125)], ['N', (0, 0, -0.38125)]]
# [[ 0.          0.          0.72045808]
#  [ 0.          0.         -0.72045808]]
# {'N': [[0, [9046.0, 0.0007, -0.000153, 0.0], [1357.0, 0.005389, -0.001208, 0.0], [309.3, 0.027406, -0.005992, 0.0], [87.73, 0.103207, -0.024544, 0.0], [28.56, 0.278723, -0.067459, 0.0], [10.21, 0.44854, -0.158078, 0.0], [3.838, 0.278238, -0.121831, 0.0], [0.7466, 0.01544, 0.549003, 0.0], [0.2248, -0.002864, 0.578815, 1.0]], [1, [13.55, 0.039919, 0.0], [2.917, 0.217169, 0.0], [0.7973, 0.510319, 0.0], [0.2185, 0.462214, 1.0]], [2, [0.817, 1.0]]]}
# 7        N    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -108.172976044092
# E(CCSD) = -108.4183791071511  E_corr = -0.2454030630591001
# CCSD(T) correction = -0.00498603176237487
# ENERGY Computing using CCSD T appoach is = -108.4233651389135
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -108.660620167135
# converged SCF energy = -108.662654398683
# converged SCF energy = -108.736459377174
# converged SCF energy = -108.573178576342
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -108.670600080466
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -108.688235648774
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -108.662843696271
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -108.670127741823
# ************************************##############################################*############################### 10
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f18329fce90>
# In Bohr
# [[ 0.          0.          0.77951203]
#  [ 0.          0.         -0.77951203]]
# In angstrom
# [[ 0.      0.      0.4125]
#  [ 0.      0.     -0.4125]]
# [['N', (0, 0, 0.4125)], ['N', (0, 0, -0.4125)]]
# [[ 0.          0.          0.77951203]
#  [ 0.          0.         -0.77951203]]
# {'N': [[0, [9046.0, 0.0007, -0.000153, 0.0], [1357.0, 0.005389, -0.001208, 0.0], [309.3, 0.027406, -0.005992, 0.0], [87.73, 0.103207, -0.024544, 0.0], [28.56, 0.278723, -0.067459, 0.0], [10.21, 0.44854, -0.158078, 0.0], [3.838, 0.278238, -0.121831, 0.0], [0.7466, 0.01544, 0.549003, 0.0], [0.2248, -0.002864, 0.578815, 1.0]], [1, [13.55, 0.039919, 0.0], [2.917, 0.217169, 0.0], [0.7973, 0.510319, 0.0], [0.2185, 0.462214, 1.0]], [2, [0.817, 1.0]]]}
# 7        N    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -108.53102571625
# E(CCSD) = -108.7882940028014  E_corr = -0.2572682865514032
# CCSD(T) correction = -0.00582732431988873
# ENERGY Computing using CCSD T appoach is = -108.79412132712129
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -109.022288836826
# converged SCF energy = -109.025555871385
# converged SCF energy = -109.100587718862
# converged SCF energy = -108.938328347101
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -109.031686333034
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -109.048378801368
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -109.022443597115
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -109.03168138841
# ************************************##############################################*############################### 11
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f18330e1d50>
# In Bohr
# [[ 0.          0.          0.83856597]
#  [ 0.          0.         -0.83856597]]
# In angstrom
# [[ 0.       0.       0.44375]
#  [ 0.       0.      -0.44375]]
# [['N', (0, 0, 0.44375)], ['N', (0, 0, -0.44375)]]
# [[ 0.          0.          0.83856597]
#  [ 0.          0.         -0.83856597]]
# {'N': [[0, [9046.0, 0.0007, -0.000153, 0.0], [1357.0, 0.005389, -0.001208, 0.0], [309.3, 0.027406, -0.005992, 0.0], [87.73, 0.103207, -0.024544, 0.0], [28.56, 0.278723, -0.067459, 0.0], [10.21, 0.44854, -0.158078, 0.0], [3.838, 0.278238, -0.121831, 0.0], [0.7466, 0.01544, 0.549003, 0.0], [0.2248, -0.002864, 0.578815, 1.0]], [1, [13.55, 0.039919, 0.0], [2.917, 0.217169, 0.0], [0.7973, 0.510319, 0.0], [0.2185, 0.462214, 1.0]], [2, [0.817, 1.0]]]}
# 7        N    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -108.751221798724
# E(CCSD) = -109.0206003045341  E_corr = -0.2693785058098205
# CCSD(T) correction = -0.00684677145143893
# ENERGY Computing using CCSD T appoach is = -109.02744707598552
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -109.248051282925
# converged SCF energy = -109.252711105062
# converged SCF energy = -109.328178071805
# converged SCF energy = -109.167716858536
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -109.257190554454
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -109.269651345863
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -109.247728145621
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -109.258425900091
# ************************************##############################################*############################### 12
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f17b6302c10>
# In Bohr
# [[ 0.          0.          0.89761991]
#  [ 0.          0.         -0.89761991]]
# In angstrom
# [[ 0.     0.     0.475]
#  [ 0.     0.    -0.475]]
# [['N', (0, 0, 0.475)], ['N', (0, 0, -0.475)]]
# [[ 0.          0.          0.89761991]
#  [ 0.          0.         -0.89761991]]
# {'N': [[0, [9046.0, 0.0007, -0.000153, 0.0], [1357.0, 0.005389, -0.001208, 0.0], [309.3, 0.027406, -0.005992, 0.0], [87.73, 0.103207, -0.024544, 0.0], [28.56, 0.278723, -0.067459, 0.0], [10.21, 0.44854, -0.158078, 0.0], [3.838, 0.278238, -0.121831, 0.0], [0.7466, 0.01544, 0.549003, 0.0], [0.2248, -0.002864, 0.578815, 1.0]], [1, [13.55, 0.039919, 0.0], [2.917, 0.217169, 0.0], [0.7973, 0.510319, 0.0], [0.2185, 0.462214, 1.0]], [2, [0.817, 1.0]]]}
# 7        N    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -108.876887446189
# E(CCSD) = -109.1587087851214  E_corr = -0.2818213389320955
# CCSD(T) correction = -0.00807162211061696
# ENERGY Computing using CCSD T appoach is = -109.16678040723204
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -109.380982320587
# converged SCF energy = -109.386733735706
# converged SCF energy = -109.462287829301
# converged SCF energy = -109.304364487809
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -109.389845543752
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -109.39799433871
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -109.382858603136
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -109.392145004471
# ************************************##############################################*############################### 13
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f17b62ab890>
# In Bohr
# [[ 0.          0.          0.95667385]
#  [ 0.          0.         -0.95667385]]
# In angstrom
# [[ 0.       0.       0.50625]
#  [ 0.       0.      -0.50625]]
# [['N', (0, 0, 0.50625)], ['N', (0, 0, -0.50625)]]
# [[ 0.          0.          0.95667385]
#  [ 0.          0.         -0.95667385]]
# {'N': [[0, [9046.0, 0.0007, -0.000153, 0.0], [1357.0, 0.005389, -0.001208, 0.0], [309.3, 0.027406, -0.005992, 0.0], [87.73, 0.103207, -0.024544, 0.0], [28.56, 0.278723, -0.067459, 0.0], [10.21, 0.44854, -0.158078, 0.0], [3.838, 0.278238, -0.121831, 0.0], [0.7466, 0.01544, 0.549003, 0.0], [0.2248, -0.002864, 0.578815, 1.0]], [1, [13.55, 0.039919, 0.0], [2.917, 0.217169, 0.0], [0.7973, 0.510319, 0.0], [0.2185, 0.462214, 1.0]], [2, [0.817, 1.0]]]}
# 7        N    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -108.938009600867
# E(CCSD) = -109.2327048186124  E_corr = -0.2946952177450177
# CCSD(T) correction = -0.00952914032742075
# ENERGY Computing using CCSD T appoach is = -109.2422339589398
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -109.450867221295
# converged SCF energy = -109.457451228033
# converged SCF energy = -109.53269989369
# converged SCF energy = -109.378024814467
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -109.459942795192
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -109.464327945006
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -109.457315396269
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -109.462128354157
# ************************************##############################################*############################### 14
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f18ac972fd0>
# In Bohr
# [[ 0.          0.          1.01572779]
#  [ 0.          0.         -1.01572779]]
# In angstrom
# [[ 0.      0.      0.5375]
#  [ 0.      0.     -0.5375]]
# [['N', (0, 0, 0.5375)], ['N', (0, 0, -0.5375)]]
# [[ 0.          0.          1.01572779]
#  [ 0.          0.         -1.01572779]]
# {'N': [[0, [9046.0, 0.0007, -0.000153, 0.0], [1357.0, 0.005389, -0.001208, 0.0], [309.3, 0.027406, -0.005992, 0.0], [87.73, 0.103207, -0.024544, 0.0], [28.56, 0.278723, -0.067459, 0.0], [10.21, 0.44854, -0.158078, 0.0], [3.838, 0.278238, -0.121831, 0.0], [0.7466, 0.01544, 0.549003, 0.0], [0.2248, -0.002864, 0.578815, 1.0]], [1, [13.55, 0.039919, 0.0], [2.917, 0.217169, 0.0], [0.7973, 0.510319, 0.0], [0.2185, 0.462214, 1.0]], [2, [0.817, 1.0]]]}
# 7        N    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -108.95553963208
# E(CCSD) = -109.2636215612743  E_corr = -0.3080819291943175
# CCSD(T) correction = -0.0112448378706312
# ENERGY Computing using CCSD T appoach is = -109.27486639914497
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -109.478479807483
# converged SCF energy = -109.485612302654
# converged SCF energy = -109.560191978592
# converged SCF energy = -109.409447773777
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -109.487974700439
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -109.489843729087
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -109.490131103239
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -109.489121498065
# ************************************##############################################*############################### 15
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f18330e7e90>
# In Bohr
# [[ 0.          0.          1.07478173]
#  [ 0.          0.         -1.07478173]]
# In angstrom
# [[ 0.       0.       0.56875]
#  [ 0.       0.      -0.56875]]
# [['N', (0, 0, 0.56875)], ['N', (0, 0, -0.56875)]]
# [[ 0.          0.          1.07478173]
#  [ 0.          0.         -1.07478173]]
# {'N': [[0, [9046.0, 0.0007, -0.000153, 0.0], [1357.0, 0.005389, -0.001208, 0.0], [309.3, 0.027406, -0.005992, 0.0], [87.73, 0.103207, -0.024544, 0.0], [28.56, 0.278723, -0.067459, 0.0], [10.21, 0.44854, -0.158078, 0.0], [3.838, 0.278238, -0.121831, 0.0], [0.7466, 0.01544, 0.549003, 0.0], [0.2248, -0.002864, 0.578815, 1.0]], [1, [13.55, 0.039919, 0.0], [2.917, 0.217169, 0.0], [0.7973, 0.510319, 0.0], [0.2185, 0.462214, 1.0]], [2, [0.817, 1.0]]]}
# 7        N    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -108.944143941618
# E(CCSD) = -109.2661774155309  E_corr = -0.3220334739128807
# CCSD(T) correction = -0.0132411556981614
# ENERGY Computing using CCSD T appoach is = -109.2794185712291
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -109.478316254903
# converged SCF energy = -109.485888140396
# converged SCF energy = -109.559269938354
# converged SCF energy = -109.413106462966
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -109.488605165278
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -109.488935591898
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -109.493927463109
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -109.488399815778
# ************************************##############################################*############################### 16
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f17b61adc90>
# In Bohr
# [[ 0.          0.          1.13383567]
#  [ 0.          0.         -1.13383567]]
# In angstrom
# [[ 0.   0.   0.6]
#  [ 0.   0.  -0.6]]
# [['N', (0, 0, 0.6)], ['N', (0, 0, -0.6)]]
# [[ 0.          0.          1.13383567]
#  [ 0.          0.         -1.13383567]]
# {'N': [[0, [9046.0, 0.0007, -0.000153, 0.0], [1357.0, 0.005389, -0.001208, 0.0], [309.3, 0.027406, -0.005992, 0.0], [87.73, 0.103207, -0.024544, 0.0], [28.56, 0.278723, -0.067459, 0.0], [10.21, 0.44854, -0.158078, 0.0], [3.838, 0.278238, -0.121831, 0.0], [0.7466, 0.01544, 0.549003, 0.0], [0.2248, -0.002864, 0.578815, 1.0]], [1, [13.55, 0.039919, 0.0], [2.917, 0.217169, 0.0], [0.7973, 0.510319, 0.0], [0.2185, 0.462214, 1.0]], [2, [0.817, 1.0]]]}
# 7        N    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -108.914051975052
# E(CCSD) = -109.2506188175005  E_corr = -0.3365668424486404
# CCSD(T) correction = -0.0155367856893734
# ENERGY Computing using CCSD T appoach is = -109.26615560318983
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -109.460429759863
# converged SCF energy = -109.468500594491
# converged SCF energy = -109.540004836578
# converged SCF energy = -109.399028296784
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -109.471880968371
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -109.471492873775
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -109.47779484368
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -109.470874367793
# ************************************##############################################*############################### 17
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f17b6563f50>
# In Bohr
# [[ 0.          0.          1.19288962]
#  [ 0.          0.         -1.19288962]]
# In angstrom
# [[ 0.       0.       0.63125]
#  [ 0.       0.      -0.63125]]
# [['N', (0, 0, 0.63125)], ['N', (0, 0, -0.63125)]]
# [[ 0.          0.          1.19288962]
#  [ 0.          0.         -1.19288962]]
# {'N': [[0, [9046.0, 0.0007, -0.000153, 0.0], [1357.0, 0.005389, -0.001208, 0.0], [309.3, 0.027406, -0.005992, 0.0], [87.73, 0.103207, -0.024544, 0.0], [28.56, 0.278723, -0.067459, 0.0], [10.21, 0.44854, -0.158078, 0.0], [3.838, 0.278238, -0.121831, 0.0], [0.7466, 0.01544, 0.549003, 0.0], [0.2248, -0.002864, 0.578815, 1.0]], [1, [13.55, 0.039919, 0.0], [2.917, 0.217169, 0.0], [0.7973, 0.510319, 0.0], [0.2185, 0.462214, 1.0]], [2, [0.817, 1.0]]]}
# 7        N    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -108.872360980052
# E(CCSD) = -109.2240268599288  E_corr = -0.3516658798762389
# CCSD(T) correction = -0.0181469573082488
# ENERGY Computing using CCSD T appoach is = -109.242173817237
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -109.431728724364
# converged SCF energy = -109.440411934086
# converged SCF energy = -109.50933555708
# converged SCF energy = -109.374094085848
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -109.444645747829
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -109.443896254809
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -109.449332147599
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -109.443365695092
# ************************************##############################################*############################### 18
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f1833268990>
# In Bohr
# [[ 0.          0.          1.25194356]
#  [ 0.          0.         -1.25194356]]
# In angstrom
# [[ 0.      0.      0.6625]
#  [ 0.      0.     -0.6625]]
# [['N', (0, 0, 0.6625)], ['N', (0, 0, -0.6625)]]
# [[ 0.          0.          1.25194356]
#  [ 0.          0.         -1.25194356]]
# {'N': [[0, [9046.0, 0.0007, -0.000153, 0.0], [1357.0, 0.005389, -0.001208, 0.0], [309.3, 0.027406, -0.005992, 0.0], [87.73, 0.103207, -0.024544, 0.0], [28.56, 0.278723, -0.067459, 0.0], [10.21, 0.44854, -0.158078, 0.0], [3.838, 0.278238, -0.121831, 0.0], [0.7466, 0.01544, 0.549003, 0.0], [0.2248, -0.002864, 0.578815, 1.0]], [1, [13.55, 0.039919, 0.0], [2.917, 0.217169, 0.0], [0.7973, 0.510319, 0.0], [0.2185, 0.462214, 1.0]], [2, [0.817, 1.0]]]}
# 7        N    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -108.823971699894
# E(CCSD) = -109.191262555161  E_corr = -0.3672908552665791
# CCSD(T) correction = -0.0210853523888512
# ENERGY Computing using CCSD T appoach is = -109.21234790754987
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -109.39691358106
# converged SCF energy = -109.406325730233
# converged SCF energy = -109.472008606161
# converged SCF energy = -109.342977978375
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -109.41158213115
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -109.411098009541
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -109.413628949238
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -109.410463807183
# ************************************##############################################*############################### 19
# ***********************************************************
# ***********************************************************
# ***********************************************************
# ...
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -108.868109519118
# ************************************##############################################*############################### 43
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f17b6158cd0>
# In Bohr
# [[ 0.          0.          2.72829209]
#  [ 0.          0.         -2.72829209]]
# In angstrom
# [[ 0.       0.       1.44375]
#  [ 0.       0.      -1.44375]]
# [['N', (0, 0, 1.44375)], ['N', (0, 0, -1.44375)]]
# [[ 0.          0.          2.72829209]
#  [ 0.          0.         -2.72829209]]
# {'N': [[0, [9046.0, 0.0007, -0.000153, 0.0], [1357.0, 0.005389, -0.001208, 0.0], [309.3, 0.027406, -0.005992, 0.0], [87.73, 0.103207, -0.024544, 0.0], [28.56, 0.278723, -0.067459, 0.0], [10.21, 0.44854, -0.158078, 0.0], [3.838, 0.278238, -0.121831, 0.0], [0.7466, 0.01544, 0.549003, 0.0], [0.2248, -0.002864, 0.578815, 1.0]], [1, [13.55, 0.039919, 0.0], [2.917, 0.217169, 0.0], [0.7973, 0.510319, 0.0], [0.2185, 0.462214, 1.0]], [2, [0.817, 1.0]]]}
# 7        N    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -108.017185074439
# CCSD not converged
# E(CCSD) = -108.5276239615035  E_corr = -0.5104388870641374
# CCSD(T) correction = -0.239585770355467
# ENERGY Computing using CCSD T appoach is = -108.76720973185893
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -108.851547240807
# converged SCF energy = -108.891103054623
# converged SCF energy = -108.820009803181
# converged SCF energy = -108.858339944319
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -108.944728278479
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -108.853059580886
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -108.803817172539
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -108.85958786768
# ************************************##############################################*############################### 44
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f17b658a950>
# In Bohr
# [[ 0.          0.          2.78734603]
#  [ 0.          0.         -2.78734603]]
# In angstrom
# [[ 0.     0.     1.475]
#  [ 0.     0.    -1.475]]
# [['N', (0, 0, 1.475)], ['N', (0, 0, -1.475)]]
# [[ 0.          0.          2.78734603]
#  [ 0.          0.         -2.78734603]]
# {'N': [[0, [9046.0, 0.0007, -0.000153, 0.0], [1357.0, 0.005389, -0.001208, 0.0], [309.3, 0.027406, -0.005992, 0.0], [87.73, 0.103207, -0.024544, 0.0], [28.56, 0.278723, -0.067459, 0.0], [10.21, 0.44854, -0.158078, 0.0], [3.838, 0.278238, -0.121831, 0.0], [0.7466, 0.01544, 0.549003, 0.0], [0.2248, -0.002864, 0.578815, 1.0]], [1, [13.55, 0.039919, 0.0], [2.917, 0.217169, 0.0], [0.7973, 0.510319, 0.0], [0.2185, 0.462214, 1.0]], [2, [0.817, 1.0]]]}
# 7        N    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -108.004037587156
# CCSD not converged
# E(CCSD) = -108.4915628705489  E_corr = -0.487525283393049
# CCSD(T) correction = -0.36506193928072
# ENERGY Computing using CCSD T appoach is = -108.85662480982958
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -108.844530099863
# converged SCF energy = -108.885088897402
# converged SCF energy = -108.80904444884
# converged SCF energy = -108.852761767265
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -108.973993364613
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -108.844559811368
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -108.793425558725
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -108.851675102109
# ************************************##############################################*############################### 45
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f1832e61ed0>
# In Bohr
# [[ 0.          0.          2.84639998]
#  [ 0.          0.         -2.84639998]]
# In angstrom
# [[ 0.       0.       1.50625]
#  [ 0.       0.      -1.50625]]
# [['N', (0, 0, 1.50625)], ['N', (0, 0, -1.50625)]]
# [[ 0.          0.          2.84639998]
#  [ 0.          0.         -2.84639998]]
# {'N': [[0, [9046.0, 0.0007, -0.000153, 0.0], [1357.0, 0.005389, -0.001208, 0.0], [309.3, 0.027406, -0.005992, 0.0], [87.73, 0.103207, -0.024544, 0.0], [28.56, 0.278723, -0.067459, 0.0], [10.21, 0.44854, -0.158078, 0.0], [3.838, 0.278238, -0.121831, 0.0], [0.7466, 0.01544, 0.549003, 0.0], [0.2248, -0.002864, 0.578815, 1.0]], [1, [13.55, 0.039919, 0.0], [2.917, 0.217169, 0.0], [0.7973, 0.510319, 0.0], [0.2185, 0.462214, 1.0]], [2, [0.817, 1.0]]]}
# 7        N    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -107.991663284451
# CCSD not converged
# E(CCSD) = -108.5089461134336  E_corr = -0.5172828289823101
# CCSD(T) correction = -0.0636284628830696
# ENERGY Computing using CCSD T appoach is = -108.57257457631671
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -108.838048582213
# converged SCF energy = -108.879602358142
# converged SCF energy = -108.798684037773
# converged SCF energy = -108.847664279378
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -108.910235851119
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -108.836619289358
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -108.783579043243
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -108.844317480337
# ************************************##############################################*############################### 46
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f1820099f50>
# In Bohr
# [[ 0.          0.          2.90545392]
#  [ 0.          0.         -2.90545392]]
# In angstrom
# [[ 0.      0.      1.5375]
#  [ 0.      0.     -1.5375]]
# [['N', (0, 0, 1.5375)], ['N', (0, 0, -1.5375)]]
# [[ 0.          0.          2.90545392]
#  [ 0.          0.         -2.90545392]]
# {'N': [[0, [9046.0, 0.0007, -0.000153, 0.0], [1357.0, 0.005389, -0.001208, 0.0], [309.3, 0.027406, -0.005992, 0.0], [87.73, 0.103207, -0.024544, 0.0], [28.56, 0.278723, -0.067459, 0.0], [10.21, 0.44854, -0.158078, 0.0], [3.838, 0.278238, -0.121831, 0.0], [0.7466, 0.01544, 0.549003, 0.0], [0.2248, -0.002864, 0.578815, 1.0]], [1, [13.55, 0.039919, 0.0], [2.917, 0.217169, 0.0], [0.7973, 0.510319, 0.0], [0.2185, 0.462214, 1.0]], [2, [0.817, 1.0]]]}
# 7        N    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -107.980011766511
# CCSD not converged
# E(CCSD) = -108.5989584688162  E_corr = -0.6189467023047217
# CCSD(T) correction = -0.110092120452732
# ENERGY Computing using CCSD T appoach is = -108.70905058926891
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -108.832061394146
# converged SCF energy = -108.87460193603
# converged SCF energy = -108.788890370515
# converged SCF energy = -108.843007932271
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -108.961483555847
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -108.829233217475
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -108.774298177527
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -108.837489193579
# ************************************##############################################*############################### 47
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f17b6422f10>
# In Bohr
# [[ 0.          0.          2.96450786]
#  [ 0.          0.         -2.96450786]]
# In angstrom
# [[ 0.       0.       1.56875]
#  [ 0.       0.      -1.56875]]
# [['N', (0, 0, 1.56875)], ['N', (0, 0, -1.56875)]]
# [[ 0.          0.          2.96450786]
#  [ 0.          0.         -2.96450786]]
# {'N': [[0, [9046.0, 0.0007, -0.000153, 0.0], [1357.0, 0.005389, -0.001208, 0.0], [309.3, 0.027406, -0.005992, 0.0], [87.73, 0.103207, -0.024544, 0.0], [28.56, 0.278723, -0.067459, 0.0], [10.21, 0.44854, -0.158078, 0.0], [3.838, 0.278238, -0.121831, 0.0], [0.7466, 0.01544, 0.549003, 0.0], [0.2248, -0.002864, 0.578815, 1.0]], [1, [13.55, 0.039919, 0.0], [2.917, 0.217169, 0.0], [0.7973, 0.510319, 0.0], [0.2185, 0.462214, 1.0]], [2, [0.817, 1.0]]]}
# 7        N    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -107.969036979933
# CCSD not converged
# E(CCSD) = -108.4948233309185  E_corr = -0.5257863509852509
# CCSD(T) correction = -0.0830051320972933
# ENERGY Computing using CCSD T appoach is = -108.57782846301579
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -108.826530549442
# converged SCF energy = -108.87004758858
# converged SCF energy = -108.779628163383
# converged SCF energy = -108.838756372265
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -108.91361789243
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -108.822327325848
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -108.765558480529
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -108.831139885708
# ************************************##############################################*############################### 48
# ***********************************************************
# ***********************************************************
# ***********************************************************
# .............................................Molecule details......................................................
# <pyscf.gto.mole.Mole object at 0x7f17b6786f50>
# In Bohr
# [[ 0.         0.         3.0235618]
#  [ 0.         0.        -3.0235618]]
# In angstrom
# [[ 0.   0.   1.6]
#  [ 0.   0.  -1.6]]
# [['N', (0, 0, 1.6)], ['N', (0, 0, -1.6)]]
# [[ 0.         0.         3.0235618]
#  [ 0.         0.        -3.0235618]]
# {'N': [[0, [9046.0, 0.0007, -0.000153, 0.0], [1357.0, 0.005389, -0.001208, 0.0], [309.3, 0.027406, -0.005992, 0.0], [87.73, 0.103207, -0.024544, 0.0], [28.56, 0.278723, -0.067459, 0.0], [10.21, 0.44854, -0.158078, 0.0], [3.838, 0.278238, -0.121831, 0.0], [0.7466, 0.01544, 0.549003, 0.0], [0.2248, -0.002864, 0.578815, 1.0]], [1, [13.55, 0.039919, 0.0], [2.917, 0.217169, 0.0], [0.7973, 0.510319, 0.0], [0.2185, 0.462214, 1.0]], [2, [0.817, 1.0]]]}
# 7        N    	  	 	 cc-pVDZ
# .............................................COMPUTING SCF energy......................................................
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD ++++++++++++++++++++++++++++++++++
# ++++++++++++++++++++++++++++++++++++++++++++++++++  CCSD(T) ++++++++++++++++++++++++++++++++++
# converged SCF energy = -107.958696795659
# CCSD not converged
# E(CCSD) = -108.4786115054454  E_corr = -0.5199147097864553
# CCSD(T) correction = -0.14693896828288
# ENERGY Computing using CCSD T appoach is = -108.62555047372827
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DFT Functionals ++++++++++++++++++++++++++++++++++
# converged SCF energy = -108.821421414547
# converged SCF energy = -108.865902456456
# converged SCF energy = -108.770865389891
# converged SCF energy = -108.834876605997
# ++++++++++++++++++++++++++++++++++++++++++++++++++  DM21 Functionals ++++++++++++++++++++++++++++++++++
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# SCF not converged.
# SCF energy = -108.849753412615
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -108.815909487037
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -108.757325151924
# INFO:tensorflow:Saver not created because there are no variables in the graph to restore
# converged SCF energy = -108.825243883271

# %%
df.to_csv('/content/drive/My Drive/DeepMind' + EXPNO+ 'CE-Final-.csv' )

# %%
df2

# %%
df2 = df.copy()

# %%
df.drop(columns=['Weight', 'Element', 'Molecule', 'BasisSet', 'Spin','BuiltMolecule'])
# Out:
#     bond_lenght       CCSDT   DFT-b3lyp    DFT-SCAN  DFT-wB97X-V     DFT-pbe  \
# 0        0.2625  -80.015148  -80.240505  -80.252146   -80.268803  -80.151546
# 1        0.3250  -90.457013  -90.743151  -90.765103   -90.796101  -90.649221
# 2        0.3875  -96.682817  -96.986650  -96.997055   -97.045361  -96.894825
# 3        0.4500 -100.868630 -101.174326 -101.175622  -101.233598 -101.079615
# 4        0.5125 -103.739534 -104.032379 -104.031726  -104.093936 -103.936111
# 5        0.5750 -105.682531 -105.959123 -105.958119  -106.024400 -105.863536
# 6        0.6375 -106.984764 -107.246131 -107.245612  -107.315331 -107.152617
# 7        0.7000 -107.851640 -108.099868 -108.100780  -108.172657 -108.009188
# 8        0.7625 -108.423365 -108.660620 -108.662654  -108.736459 -108.573179
# 9        0.8250 -108.794121 -109.022289 -109.025556  -109.100588 -108.938328
# 10       0.8875 -109.027447 -109.248051 -109.252711  -109.328178 -109.167717
# 11       0.9500 -109.166780 -109.380982 -109.386734  -109.462288 -109.304364
# 12       1.0125 -109.242234 -109.450867 -109.457451  -109.532700 -109.378025
# 13       1.0750 -109.274866 -109.478480 -109.485612  -109.560192 -109.409448
# 14       1.1375 -109.279419 -109.478316 -109.485888  -109.559270 -109.413106
# 15       1.2000 -109.266156 -109.460430 -109.468501  -109.540005 -109.399028
# 16       1.2625 -109.242174 -109.431729 -109.440412  -109.509336 -109.374094
# 17       1.3250 -109.212348 -109.396914 -109.406326  -109.472009 -109.342978
# 18       1.3875 -109.180007 -109.359143 -109.369398  -109.431244 -109.308817
# 19       1.4500 -109.147413 -109.320500 -109.331696  -109.389194 -109.273678
# 20       1.5125 -109.116097 -109.282312 -109.294545  -109.347263 -109.238880
# 21       1.5750 -109.087118 -109.245385 -109.258758  -109.306326 -109.205227
# 22       1.6375 -109.061262 -109.210174 -109.224788  -109.266903 -109.173172
# 23       1.7000 -109.039205 -109.176906 -109.192857  -109.229272 -109.142946
# 24       1.7625 -109.021666 -109.145669 -109.163045  -109.193566 -109.114641
# 25       1.8250 -109.009526 -109.116471 -109.135346  -109.159827 -109.088269
# 26       1.8875 -109.003944 -109.089273 -109.109695  -109.128043 -109.063797
# 27       1.9500 -109.006426 -109.064011 -109.085968  -109.098171 -109.041162
# 28       2.0125 -109.018704 -109.040600 -109.064037  -109.070143 -109.020284
# 29       2.0750 -109.042081 -109.018946 -109.043799  -109.043878 -109.001072
# 30       2.1375 -109.076137 -108.998946 -109.025143  -109.019281 -108.983425
# 31       2.2000 -109.117822 -108.980491 -109.007968  -108.996255 -108.967238
# 32       2.2625 -109.162608 -108.963474 -108.992176  -108.974697 -108.952406
# 33       2.3250 -109.206667 -108.947789 -108.977670  -108.954508 -108.938826
# 34       2.3875 -108.691106 -108.933331 -108.964363  -108.935589 -108.926395
# 35       2.4500 -108.661832 -108.920004 -108.952159  -108.917845 -108.915020
# 36       2.5125 -108.786661 -108.907716 -108.940976  -108.901191 -108.904613
# 37       2.5750 -108.660927 -108.896384 -108.930731  -108.885544 -108.895091
# 38       2.6375 -108.655576 -108.885929 -108.921348  -108.870829 -108.886379
# 39       2.7000 -109.396640 -108.876280 -108.912754  -108.856978 -108.878407
# 40       2.7625 -108.638583 -108.867371 -108.904886  -108.843928 -108.871114
# 41       2.8250 -109.435973 -108.859145 -108.897686  -108.831622 -108.864442
# 42       2.8875 -108.767210 -108.851547 -108.891103  -108.820010 -108.858340
# 43       2.9500 -108.856625 -108.844530 -108.885089  -108.809044 -108.852762
# 44       3.0125 -108.572575 -108.838049 -108.879602  -108.798684 -108.847664
# 45       3.0750 -108.709051 -108.832061 -108.874602  -108.788890 -108.843008
# 46       3.1375 -108.577828 -108.826531 -108.870048  -108.779628 -108.838756
# 47       3.2000 -108.625550 -108.821421 -108.865902  -108.770865 -108.834877
#
#     NN-Functional.DM21  NN-Functional.DM21m  NN-Functional.DM21mc  \
# 0           -80.279720           -80.298464            -80.322943
# 1           -90.777763           -90.797334            -90.802754
# 2           -97.011610           -97.032708            -97.044271
# 3          -101.191588          -101.212076           -101.211488
# 4          -104.045445          -104.058709           -104.050442
# 5          -105.970438          -105.980486           -105.967791
# 6          -107.257090          -107.269532           -107.252811
# 7          -108.110284          -108.125696           -108.103685
# 8          -108.670600          -108.688236           -108.662844
# 9          -109.031686          -109.048379           -109.022444
# 10         -109.257191          -109.269651           -109.247728
# 11         -109.389846          -109.397994           -109.382859
# 12         -109.459943          -109.464328           -109.457315
# 13         -109.487975          -109.489844           -109.490131
# 14         -109.488605          -109.488936           -109.493927
# 15         -109.471881          -109.471493           -109.477795
# 16         -109.444646          -109.443896           -109.449332
# 17         -109.411582          -109.411098           -109.413629
# 18         -109.375880          -109.375459           -109.374462
# 19         -109.339692          -109.338064           -109.334437
# 20         -109.304405          -109.300602           -109.294909
# 21         -109.270785          -109.264101           -109.256623
# 22         -109.239029          -109.229182           -109.220088
# 23         -109.209128          -109.196438           -109.185444
# 24         -109.180978          -109.166066           -109.152607
# 25         -109.154521          -109.137734           -109.121529
# 26         -109.129861          -109.111133           -109.092194
# 27         -109.107332          -109.085969           -109.064536
# 28         -109.087097          -109.062226           -109.038537
# 29         -108.887397          -109.039780           -109.014086
# 30         -108.884095          -109.018768           -108.991175
# 31         -108.881074          -108.999050           -108.969703
# 32         -108.625035          -108.980594           -108.949552
# 33         -109.012831          -108.963434           -108.930666
# 34         -108.729365          -108.947426           -108.912909
# 35         -108.871556          -108.932538           -108.896246
# 36         -108.867290          -108.918665           -108.880576
# 37         -109.004262          -108.905740           -108.865837
# 38         -108.978188          -108.893696           -108.851950
# 39         -108.875294          -108.882451           -108.838855
# 40         -108.925640          -108.871965           -108.826484
# 41         -108.824591          -108.862179           -108.814817
# 42         -108.944728          -108.853060           -108.803817
# 43         -108.973993          -108.844560           -108.793426
# 44         -108.910236          -108.836619           -108.783579
# 45         -108.961484          -108.829233           -108.774298
# 46         -108.913618          -108.822327           -108.765558
# 47         -108.849753          -108.815909           -108.757325
#
#     NN-Functional.DM21mu
# 0             -80.306195
# 1             -90.791336
# 2             -97.024481
# 3            -101.206486
# 4            -104.059358
# 5            -105.979877
# 6            -107.261713
# 7            -108.111667
# 8            -108.670128
# 9            -109.031681
# 10           -109.258426
# 11           -109.392145
# 12           -109.462128
# 13           -109.489121
# 14           -109.488400
# 15           -109.470874
# 16           -109.443366
# 17           -109.410464
# 18           -109.374074
# 19           -109.335958
# 20           -109.297695
# 21           -109.260384
# 22           -109.224866
# 23           -109.191548
# 24           -109.160680
# 25           -109.132051
# 26           -109.105346
# 27           -109.080641
# 28           -109.057541
# 29           -109.036142
# 30           -109.016119
# 31           -108.997516
# 32           -108.980115
# 33           -108.963943
# 34           -108.948846
# 35           -108.934774
# 36           -108.921621
# 37           -108.909351
# 38           -108.897893
# 39           -108.887233
# 40           -108.877315
# 41           -108.868110
# 42           -108.859588
# 43           -108.851675
# 44           -108.844317
# 45           -108.837489
# 46           -108.831140
# 47           -108.825244

# %%
type(df['bond_lenght'].to_numpy() )
# Out:
# numpy.ndarray

# %%
df['bond_lenght'].to_numpy()
# Out:
# array([0.2625, 0.325 , 0.3875, 0.45  , 0.5125, 0.575 , 0.6375, 0.7   ,
#        0.7625, 0.825 , 0.8875, 0.95  , 1.0125, 1.075 , 1.1375, 1.2   ,
#        1.2625, 1.325 , 1.3875, 1.45  , 1.5125, 1.575 , 1.6375, 1.7   ,
#        1.7625, 1.825 , 1.8875, 1.95  , 2.0125, 2.075 , 2.1375, 2.2   ,
#        2.2625, 2.325 , 2.3875, 2.45  , 2.5125, 2.575 , 2.6375, 2.7   ,
#        2.7625, 2.825 , 2.8875, 2.95  , 3.0125, 3.075 , 3.1375, 3.2   ])

# %%
import  matplotlib.font_manager

flist = matplotlib.font_manager.get_fontconfig_fonts()
names = [matplotlib.font_manager.FontProperties(fname=fname).get_name() for fname in flist]
print(names)
# Out:
# ['Liberation Sans', 'Liberation Mono', 'Liberation Sans Narrow', 'Liberation Sans Narrow', 'Liberation Sans', 'Liberation Mono', 'Liberation Serif', 'Liberation Sans', 'Liberation Serif', 'Liberation Sans', 'Liberation Sans Narrow', 'Liberation Serif', 'Liberation Sans Narrow', 'Humor Sans', 'Liberation Mono', 'Liberation Serif', 'Liberation Mono']

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def plotNand(choiceDFT , myfigsize=(12, 10), myfontsize=20):
  plt.figure(0)


  plt.figure(figsize=myfigsize)
  plt.rcParams["font.family"] = "Liberation Serif"



  lengendlist =[]

  if 'CCSDT' in choiceDFT:
    plt.plot(df['bond_lenght'].to_numpy() , df['CCSDT'].to_numpy()  , 'o-')
    lengendlist.append('CCSD(T)')



  for afunctionals in functionalsList:
    if afunctionals in choiceDFT:
      plt.plot(df['bond_lenght'].to_numpy() , df['DFT-'+str(afunctionals)].to_numpy() , 'x-' )
      lengendlist.append(str(afunctionals))

  for aDMFunctionalvalue in dm21.Functional:
    if str(aDMFunctionalvalue) in choiceDFT:
      plt.plot(df['bond_lenght'].to_numpy() , df['NN-'+str(aDMFunctionalvalue)].to_numpy()  )
      lengendlist.append(str(aDMFunctionalvalue))



  plt.legend(lengendlist,  fontsize = myfontsize)
  plt.rc('xtick',labelsize=myfontsize-1)
  plt.rc('ytick',labelsize=myfontsize-2)
  plt.ylabel('Energy in Hartree', fontsize = myfontsize)
  plt.xlabel('Bond length in angstrom', fontsize = myfontsize)
  plt.title(ValidatedBasisSet, fontsize = myfontsize)
  plt.show()

# %%
def plotNandZOOM(choiceDFT , myfigsize=(12, 10), myfontsize=20, ylimits=[-170,-10], xlimits=[0, 4]):
  plt.figure(0)


  plt.figure(figsize=myfigsize)
  plt.rcParams["font.family"] = "Liberation Serif"

  axes = plt.axes()
  axes.set_ylim(ylimits  )
  axes.set_xlim(xlimits )

  lengendlist =[]

  if 'CCSDT' in choiceDFT:
    plt.plot(df['bond_lenght'].to_numpy() , df['CCSDT'].to_numpy()  , 'o-')
    lengendlist.append('CCSD(T)')



  for afunctionals in functionalsList:
    if afunctionals in choiceDFT:
      plt.plot(df['bond_lenght'].to_numpy() , df['DFT-'+str(afunctionals)].to_numpy() , 'x-' )
      lengendlist.append(str(afunctionals))

  for aDMFunctionalvalue in dm21.Functional:
    if str(aDMFunctionalvalue) in choiceDFT:
      plt.plot(df['bond_lenght'].to_numpy() , df['NN-'+str(aDMFunctionalvalue)].to_numpy()  )
      lengendlist.append(str(aDMFunctionalvalue))



  plt.legend(lengendlist,  fontsize = myfontsize)
  plt.rc('xtick',labelsize=myfontsize-1)
  plt.rc('ytick',labelsize=myfontsize-2)
  plt.ylabel('Energy in Hartree', fontsize = myfontsize)
  plt.xlabel('Bond length in angstrom', fontsize = myfontsize)
  plt.title(ValidatedBasisSet, fontsize = myfontsize)
  plt.show()

# %%
choiceDFT = ['CCSDT', 'b3lyp' , 'Functional.DM21m']
plotNand(choiceDFT , myfigsize=(12, 10), myfontsize=20)

# %%
choiceDFT = ['CCSDT', 'b3lyp' , 'SCAN' , 'wB97X-V', 'pbe' , 'Functional.DM21m', 'Functional.DM21mc' , 'Functional.DM21mu']
plotNand(choiceDFT , myfigsize=(12, 10), myfontsize=20)

# %%
choiceDFT = ['CCSDT',   'SCAN' , 'Functional.DM21m',  'Functional.DM21mu']
plotNand(choiceDFT , myfigsize=(20, 20), myfontsize=20)

# %%
choiceDFT = ['CCSDT',   'b3lyp' ,    'Functional.DM21m']
plotNand(choiceDFT , myfigsize=(20, 20), myfontsize=20)

# %%
choiceDFT = ['CCSDT',   'pbe' ,    'Functional.DM21m']
plotNand(choiceDFT , myfigsize=(20, 20), myfontsize=20)

# %%
choiceDFT = ['CCSDT',   'pbe' ,    'Functional.DM21m']
plotNand(choiceDFT , myfigsize=(20, 20), myfontsize=20)

# %%
choiceDFT = ['CCSDT', 'b3lyp' , 'Functional.DM21m']
plotNand(choiceDFT , myfigsize=(20, 16), myfontsize=20)

# %%
choiceDFT = ['CCSDT', 'wB97X-V' , 'Functional.DM21m']
plotNand(choiceDFT , myfigsize=(20, 16), myfontsize=20)

# %%
choiceDFT = ['CCSDT', 'wB97X-V' , 'Functional.DM21' ]
plotNand(choiceDFT , myfigsize=(20, 16), myfontsize=20)

# %%
choiceDFT = ['CCSDT', 'b3lyp' ,  'Functional.DM21m' ]
plotNand(choiceDFT , myfigsize=(20, 16), myfontsize=20)

# %%
choiceDFT = ['CCSDT', 'b3lyp' ,  'Functional.DM21m' ]
plotNand(choiceDFT , myfigsize=(20, 16), myfontsize=20)

# %%
choiceDFT = ['CCSDT',   'wB97X-V' , 'Functional.DM21m' ]
plotNandZOOM(choiceDFT , myfigsize=(20, 16), myfontsize=20, ylimits = [-110, -105], xlimits = [0, 3.5])

# %%
choiceDFT = [ 'CCSDT',   'wB97X-V' , 'Functional.DM21m', 'Functional.DM21mc', 'Functional.DM21mu' ]
plotNandZOOM(choiceDFT , myfigsize=(20, 16), myfontsize=20, ylimits = [-109.8, -108], xlimits = [0, 2])

# %% [markdown]
# #validate the energy against NIST bechmarks ..
# manually just the ball park number some be matcoed
#
# https://cccbdb.nist.gov/bseenergy2x.asp shows
# or  http://www.begdb.org/index.php
#
# For C,
# *   CCSD = -75.7656956
# *   CCST(T)/cc-pVQZ is -75.8552316
